# %% [markdown]
# # ``mggg-states`` Data QA

# %%
# !pip install numpy
# !pip install pandas
# !pip install geopandas

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import json

import dataqa

# %% [markdown]
# ## Data Collection

# %%
# This is going to take a while to complete
dataqa.clone_repos(account='mggg-states', 
                   account_type='orgs', 
                   outpath='shps/')

# %%
mggg_shapefiles = dataqa.list_files_of_type('.zip', 'shps/')
# ^ used to see what shapefiles to work with

# %% [markdown]
# ## Data Standardization Check

# %% [markdown]
# ### Generate Standards

# %%
with open('naming_convention.json') as json_file:
    standards_raw = json.load(json_file)

# %%
geographies = dataqa.get_keys_by_category(standards_raw, 'geographies')
offices = dataqa.get_keys_by_category(standards_raw, 'offices')
parties = dataqa.get_keys_by_category(standards_raw, 'parties')
demographics = dataqa.get_keys_by_category(standards_raw, 'demographics')
districts = dataqa.get_keys_by_category(standards_raw, 'districts')
counts = dataqa.get_keys_by_category(standards_raw, 'counts')
other = dataqa.get_keys_by_category(standards_raw, 'other')

# %%
elections = []
# years = [18, 16, 14, 12, 10, 8, 4, 2]

elections = [office + format(year, '02') + party 
                 for office in offices
                 for year in range(0, 21)
                 for party in parties 
                 if not (office == 'PRES' and year % 4 != 0)]

counts = [count + format(year, '02') for count in counts 
                                     for year in range(0, 20)]

# %%
standards = geographies + elections + demographics + districts + counts + other

# %% [markdown]
# ### Compare Data with Standards

# %%
def gdf_from_zip(path: str) -> gpd.GeoDataFrame:
    return gpd.read_file('zip://' + path)

states_gdf = []
all_discrepancies = []

# %% [markdown]
# _Note:_ All states are compared manually below so that an individual can examine at state by itself if wanted

# %% [markdown]
# #### Alaska

# %%
ak_gdf = gdf_from_zip('shps/AK-shapefiles.git/AK_precincts.zip')

# %%
(ak_matches, ak_discrepancies) = dataqa.compare_column_names(ak_gdf, standards)
states_gdf.append(('AK', ak_gdf, ak_matches, None))
all_discrepancies.append(('AK', ak_discrepancies))

# %% [markdown]
# #### Arizona

# %%
az_gdf = gdf_from_zip('shps/AZ-shapefiles.git/az_precincts.zip')

# %%
(az_matches, az_discrepancies) = dataqa.compare_column_names(az_gdf, standards)
states_gdf.append(('AZ', az_gdf, az_matches, "Shapefile name does not fit convention."))
all_discrepancies.append(('AZ', az_discrepancies))

# %% [markdown]
# #### Colorado

# %%
co_gdf = gdf_from_zip('shps/CO-shapefiles.git/CO_precincts.zip')

# %%
(co_matches, co_discrepancies) = dataqa.compare_column_names(co_gdf, standards)
states_gdf.append(('CO', co_gdf, co_matches, None))
all_discrepancies.append(('CO', co_discrepancies))

# %% [markdown]
# #### Connecticut

# %%
ct_gdf = gdf_from_zip('shps/CT-shapefiles.git/CT_precincts.zip')

# %%
(ct_matches, ct_discrepancies) = dataqa.compare_column_names(ct_gdf, standards)
states_gdf.append(('CT', ct_gdf, ct_matches, None))
all_discrepancies.append(('CT', ct_discrepancies))

# %% [markdown]
# #### Delaware

# %%
de_gdf = gdf_from_zip('shps/DE-shapefiles.git/DE_precincts.zip')

# %%
(de_matches, de_discrepancies) = dataqa.compare_column_names(de_gdf, standards)
states_gdf.append(('DE', de_gdf, de_matches, None))
all_discrepancies.append(('DE', de_discrepancies))

# %% [markdown]
# #### Georgia

# %%
ga_gdf = gdf_from_zip('shps/GA-shapefiles.git/GA_precincts.zip')

# %%
(ga_matches, ga_discrepancies) = dataqa.compare_column_names(ga_gdf, standards)
states_gdf.append(('GA', ga_gdf, ga_matches, None))
all_discrepancies.append(('GA', ga_discrepancies))

# %% [markdown]
# #### Hawaii

# %%
hi_gdf = gdf_from_zip('shps/HI-shapefiles.git/HI_precincts.zip')

# %%
(hi_matches, hi_discrepancies) = dataqa.compare_column_names(hi_gdf, standards)
states_gdf.append(('HI', hi_gdf, hi_matches, None))
all_discrepancies.append(('HI', hi_discrepancies))

# %% [markdown]
# #### Indiana

# %%
ia_gdf = gdf_from_zip('shps/IA-shapefiles.git/IA_counties.zip')

# %%
(ia_matches, ia_discrepancies) = dataqa.compare_column_names(ia_gdf, standards)
states_gdf.append(('IA', ia_gdf, ia_matches, None))
all_discrepancies.append(('IA', ia_discrepancies))

# %% [markdown]
# #### Illinois
# _Note:_ Chicago only

# %%
il_gdf = gdf_from_zip('shps/IL-shapefiles.git/Chicago/Chicago_Precincts.zip')

# %%
(il_matches, il_discrepancies) = dataqa.compare_column_names(il_gdf, standards)
states_gdf.append(('IL', il_gdf, il_matches, 'Chicago only. Shapefile name does not fit convention.'))
all_discrepancies.append(('IL', il_discrepancies))

# %% [markdown]
# #### Massachusetts
# _Note:_ Multiple shapefiles exist. Includes (``'MA_no_islands*'``).

# %%
ma_gdf = gdf_from_zip('shps/MA-shapefiles.git/MA_precincts_12_16.zip')

# %%
(ma_matches, ma_discrepancies) = dataqa.compare_column_names(ma_gdf, standards)
states_gdf.append(('MA', ma_gdf, ma_matches, 'Multiple shapefiles. Using MA_precincts_12_16.zip. Shapefile name does not fit convention.'))
all_discrepancies.append(('MA', ma_discrepancies))

# %% [markdown]
# #### Maryland
# _Note:_ Not sure difference between ``MD_precincts`` and ``MD_precincts_abs``.

# %%
md_gdf = gdf_from_zip('shps/MD-shapefiles.git/MD_precincts.zip')

# %%
(md_matches, md_discrepancies) = dataqa.compare_column_names(md_gdf, standards)
states_gdf.append(('MD', md_gdf, md_matches, 'Multiple shapefiles. Using MD_precincts.zip'))
all_discrepancies.append(('MD', md_discrepancies))

# %% [markdown]
# #### Michigan

# %%
mi_gdf = gdf_from_zip('shps/MI-shapefiles.git/MI_precincts.zip')

# %%
(mi_matches, mi_discrepancies) = dataqa.compare_column_names(mi_gdf, standards)
states_gdf.append(('MI', mi_gdf, mi_matches, None))
all_discrepancies.append(('MI', mi_discrepancies))

# %% [markdown]
# #### Minnesota
# _Note:_ Multiple files exist. Assuming ``MN16`` is the most up-to-date.

# %%
mn_gdf = gdf_from_zip('shps/MN-shapefiles.git/MN16.zip')

# %%
(mn_matches, mn_discrepancies) = dataqa.compare_column_names(mn_gdf, standards)
states_gdf.append(('MN', mn_gdf, mn_matches, 'Multiple shapefiles. Using MN16.zip. Shapefile name does not fit convention.'))
all_discrepancies.append(('MN', mn_discrepancies))

# %% [markdown]
# #### North Carolina
# _Note:_ Unsure if VTDs in shapefile represent precincts accurately.

# %%
nc_gdf = gdf_from_zip('shps/NC-shapefiles.git/NC_VTD.zip')

# %%
(nc_matches, nc_discrepancies) = dataqa.compare_column_names(nc_gdf, standards)
states_gdf.append(('NC', nc_gdf, nc_matches, 'Multiple shapefiles. Using NC_VTD.zip. Shapefile name does not fit convention.'))
all_discrepancies.append(('NC', nc_discrepancies))

# %% [markdown]
# #### New Mexico

# %%
nm_gdf = gdf_from_zip('shps/NM-shapefiles.git/new_mexico_precincts.zip')

# %%
(nm_matches, nm_discrepancies) = dataqa.compare_column_names(nm_gdf, standards)
states_gdf.append(('NM', nm_gdf, nm_matches, "Shapefile name does not fit convention."))
all_discrepancies.append(('NM', nm_discrepancies))

# %% [markdown]
# #### Ohio

# %%
oh_gdf = gdf_from_zip('shps/OH-shapefiles.git/OH_precincts.zip')

# %%
(oh_matches, oh_discrepancies) = dataqa.compare_column_names(oh_gdf, standards)
states_gdf.append(('OH', oh_gdf, oh_matches, None))
all_discrepancies.append(('OH', oh_discrepancies))

# %% [markdown]
# #### Oklahoma

# %%
ok_gdf = gdf_from_zip('shps/OK-shapefiles.git/OK_precincts.zip')

# %%
(ok_matches, ok_discrepancies) = dataqa.compare_column_names(ok_gdf, standards)
states_gdf.append(('OK', ok_gdf, ok_matches, None))
all_discrepancies.append(('OK', ok_discrepancies))

# %% [markdown]
# #### Oregon

# %%
or_gdf = gdf_from_zip('shps/OR-shapefiles.git/OR_precincts.zip')

# %%
(or_matches, or_discrepancies) = dataqa.compare_column_names(or_gdf, standards)
states_gdf.append(('OR', or_gdf, or_matches, None))
all_discrepancies.append(('OR', or_discrepancies))

# %% [markdown]
# #### Pennsylvania
# _Note:_ Unsure of VTDs in shapefile accurately represent precincts.

# %%
pa_gdf = gdf_from_zip('shps/PA-shapefiles.git/PA_VTDs.zip')

# %%
(pa_matches, pa_discrepancies) = dataqa.compare_column_names(pa_gdf, standards)
states_gdf.append(('PA', pa_gdf, pa_matches, 'Shapefile uses VTDs. Shapefile name does not fit convention.'))
all_discrepancies.append(('PA', pa_discrepancies))

# %% [markdown]
# #### Rhode Island

# %%
ri_gdf = gdf_from_zip('shps/RI-shapefiles.git/RI_precincts.zip')

# %%
(ri_matches, ri_discrepancies) = dataqa.compare_column_names(ri_gdf, standards)
states_gdf.append(('RI', ri_gdf, ri_matches, None))
all_discrepancies.append(('RI', ri_discrepancies))

# %% [markdown]
# #### Texas
# _Note:_ Shapefile is stored externally at site: https://people.csail.mit.edu/ddeford/TX_vtds.zip

# %%
tx_gdf = gpd.read_file('https://people.csail.mit.edu/ddeford/TX_vtds.zip')

# %%
(tx_matches, tx_discrepancies) = dataqa.compare_column_names(tx_gdf, standards)
states_gdf.append(('TX', tx_gdf, tx_matches, 'Shapefile stored externally (MIT). Shapefile name does not fit convention.'))
all_discrepancies.append(('TX', tx_discrepancies))

# %% [markdown]
# #### Utah

# %%
ut_gdf = gdf_from_zip('shps/UT-shapefiles.git/UT_precincts.zip')

# %%
(ut_matches, ut_discrepancies) = dataqa.compare_column_names(ut_gdf, standards)
states_gdf.append(('UT', ut_gdf, ut_matches, None))
all_discrepancies.append(('UT', ut_discrepancies))

# %% [markdown]
# #### Virginia

# %%
va_gdf = gdf_from_zip('shps/VA-shapefiles.git/VA_precincts.zip')

# %%
(va_matches, va_discrepancies) = dataqa.compare_column_names(va_gdf, standards)
states_gdf.append(('VA', va_gdf, va_matches, None))
all_discrepancies.append(('VA', va_discrepancies))

# %% [markdown]
# #### Vermont
# _Note:_ Unsure if towns represent precincts.

# %%
vt_gdf = gdf_from_zip('shps/VT-shapefiles.git/VT_towns.zip')

# %%
(vt_matches, vt_discrepancies) = dataqa.compare_column_names(vt_gdf, standards)
states_gdf.append(('VT', vt_gdf, vt_matches, 'Uses towns as counting unit. Shapefile name does not fit convention.'))
all_discrepancies.append(('VT', vt_discrepancies))

# %% [markdown]
# #### Wisconsin

# %%
wi_gdf = gdf_from_zip('shps/WI-shapefiles.git/WI_wards_12_16.zip')

# %%
(wi_matches, wi_discrepancies) = dataqa.compare_column_names(wi_gdf, standards)
states_gdf.append(('WI', wi_gdf, wi_matches, 'Shapefile name does not fit convention.'))
all_discrepancies.append(('WI', wi_discrepancies))

# %% [markdown]
# ### Discrepancies Summary

# %%
print("======== List of Discrepancies by State ========")
print()

for state, discrs in all_discrepancies:
    print('{} : ---- \n{}\n'.format(state, discrs))
# Out:
# ======== List of Discrepancies by State ========
#
# AK : ----
# {'NAME', 'BLACK', 'DISTRICT', 'AMIN', 'OTHER', 'NHPI', 'AREA', 'PRES16C', 'POPULATION', 'ASIAN', 'WHITE', 'ID', '2MORE'}
#
# AZ : ----
# {'PCTNAME', 'CNTYABV'}
#
# CO : ----
# {'NAME', 'REG18R', 'SLDLST', 'VTDST', 'PRECID', 'REG18D', 'SLDUST', 'CD116FP'}
#
# CT : ----
# {'NAMELSAD10', 'COUNTYFP10', 'NAME10', 'STATEFP10'}
#
# DE : ----
# {'EDRD_2012', 'ID', 'District_1', 'POPULATION'}
#
# GA : ----
# {'DISTRICT', 'PRECINCT_I', 'FIPS1', 'CTYNAME', 'FIPS2', 'ID', 'PRECINCT_N'}
#
# HI : ----
# {'NAME', 'DPTYPE', 'ZEROPOP', 'BALLOTTYPE'}
#
# IA : ----
# {'GEOID10', 'NAMELSAD10', 'COUNTYFP10', 'AWATER10', 'NAME10', 'PRES04OTH', 'STATEFP10', 'INTPTLAT10', 'PRES00OTH', 'PRES08OTH', 'INTPTLON10', 'N_NHPI', 'ALAND10', 'PRES16OTH', 'PRES12OTH'}
#
# IL : ----
# {'20K_25K', 'JOYCE_19', 'MCCART_19', 'WILSON_19', 'FIORETTI_1', 'RO_E15', 'LHGTFT_19', 'ward', 'shape_len', 'full_text', 'SALGRIF_19', 'WILS_G15', '40K_45K', 'KOZLAR_19', 'FORD_19', 'WALLS_G15', 'JOINID', 'ENYIA_19', 'FIORET_G15', 'GARCIA_G15', 'LESS_10K', 'CHICO_19', '150K_200K', 'MEND_19', 'RO_G15', '45K_50K', '100K_125K', '50K_60K', 'EMAN_G15', 'DALEY_19', 'shape_area', '35K_40K', '60K_75K', 'VALLAS_19', '75K_100K', '125K_150K', '25K_30K', '10K_15K', 'TOTV_19', 'PRECK_19', 'TOTV_RO15', 'precinct', '200K_MORE', '15K_20K', 'TOTHH', 'TOTV_G15', '30K_35K'}
#
# MA : ----
# {'NAME', 'DISTRICT', 'WARD', 'GOV14U1', 'NAME10', 'Shape_Area', 'RSHARE', 'GOV14U2', 'Shape_Le_1', 'TOWN'}
#
# MD : ----
# {'ADJ_NHPI', 'ADJASNVAP', 'VTD_1', 'ADJ_2MORE', 'ADJ_POP', 'ADJNHPIVAP', 'ADJ_ASIAN', 'ADJAMINVAP', 'ADJ_BVAP', 'ADJ_BLACK', 'UNOCCUPIED', 'PLACE', 'OCCUPIED', 'LEG02', 'ADJ_WVAP', 'NAME', 'VTD', 'ADJ_WHITE', 'ADJOTHVAP', 'MCD', 'ADJ_AMIN', 'ADJ_VAP', 'CNG02', 'UNADJHISP', 'ADJ_OTHER', 'UNADJPOP'}
#
# MI : ----
# {'county_lon', 'Label', 'county_lat', 'VTD', 'county_nam', 'VTD2016_x', 'precinct', 'county_fip', 'ElectionYe', 'jurisdic_1', 'CountyFips', 'SENDIST', 'Jurisdicti', 'ShapeSTLen'}
#
# MN : ----
# {'PCTCODE', 'JUDDIST', 'CTYCOMDIST', 'CONGDIST', 'MCDCODE', 'CTU_TYPE', 'COUNTYFIPS', 'PCTNAME', 'COUNTYNAME', 'MNLEGDIST', 'VTDID', 'MCDNAME', 'MNSENDIST'}
#
# NC : ----
# {'EL12G_GV_T', 'PL10AA_TOT', 'EL12G_PR_R', 'Shape_Area', 'VTD_Name', 'EL08G_GV_D', 'EL16G_GV_D', 'EL10G_USS_', 'EL08G_US_2', 'judge', 'EL08G_GV_L', 'EL12G_GV_D', 'EL16G_PR_D', 'BPOP', 'EL14G_US_2', 'EL14G_US_4', 'EL16G_US_2', 'EL12G_PR_T', 'EL16G_US_1', 'EL16G_PR_T', 'EL16G_PR_L', 'EL14G_US_3', 'EL16G_US_3', 'EL14G_US_1', 'EL16G_GV_T', 'newplan', 'EL08G_US_3', 'VTD', 'PL10VA_TOT', 'EL12G_GV_R', 'EL12G_PR_W', 'EL16G_PR_R', 'EL08G_GV_T', 'EL12G_PR_L', 'EL10G_US_3', 'EL08G_US_1', 'EL10G_US_4', 'EL14G_USS_', 'Shape_Leng', 'EL12G_GV_1', 'EL12G_GV_W', 'EL10G_US_1', 'EL08G_USS_', 'AWATER10', 'EL16G_GV_R', 'EL16G_USS_', 'EL10G_US_2', 'EL12G_GV_L', 'EL08G_US_4', 'EL12G_PR_1', 'oldplan', 'EL16G_PR_W', 'County', 'EL16G_GV_L', 'VTD_Key', 'EL08G_GV_R', 'nBPOP', 'ALAND10', 'EL12G_PR_D'}
#
# NM : ----
# {'CDDIST', 'NAME10', 'County', 'Area', 'prec_num', 'SDIST', 'Perimeter'}
#
# OH : ----
# {'PRECODE', 'PRENAME', 'CNTYFIPS', 'TOTVOTE16', 'STH16R', 'STH16D'}
#
# OK : ----
# {'CNTYFIPS', 'PRECODE', 'CNTYNAME'}
#
# OR : ----
# {'Pct_Name', 'State', 'Shape_Area', 'Precinct', 'County', 'Shape_Leng', 'GOV18C'}
#
# PA : ----
# {'NAMELSAD10', 'PRES12O', 'STATEFP10', 'MTFCC10', 'USS12R', 'ALAND10', 'TS', 'T16ATGR', 'COUNTYFP10', '538DEM', 'NAME10', 'GOV', 'USS12D', 'ATG12D', 'VTDST10', 'ATG12R', '538GOP', 'F2014GOVD', 'CD_2011', 'LSAD10', 'REMEDIAL', 'VTDI10', 'T16SEND', 'T16SENR', 'GEOID10', 'AWATER10', 'T16PRESR', 'T16PRESOTH', 'INTPTLAT10', 'INTPTLON10', 'T16PRESD', 'F2014GOVR', '538CMPCT', 'T16ATGD', 'FUNCSTAT10'}
#
# RI : ----
# {'NAME', 'REGVOT16', 'REGVOT18', 'PRENAME', 'JOINID', 'Shape__Len', 'OBJECTID', 'SENDIST', 'Shape__Are'}
#
# TX : ----
# {'OTHER', 'PERIM', 'BLKHISP', 'TOTVR12', 'TOTVR16', 'HISPANIC', 'HD', 'TOTVR14', 'AREA', 'HISPVAP', 'WHITE', 'VTD', 'BLACK', 'TOTTO12', 'BHVAP', 'TOTTO16', 'USCD', 'CNTYVTD', 'FIPS', 'OTHVAP', 'TOTTO14'}
#
# UT : ----
# {'cnty_fp', 'jrsdctn', 'AliasNm', 'PrcncID', 'DsslvID', 'SbPrcnc', 'cnty_nm', 'CountyID', 'SENDIST', 'VistaID'}
#
# VA : ----
# {'CD_12', 'G18RHOR', 'HDIST_11', 'G17DATG', 'G17RHOD', 'G16RPRS', 'locality', 'G17OHOD', 'G17RATG', 'G16OHOR', 'G17DHOD', 'H_AMN', 'G18DSEN', 'G16DHOR', 'G16DPRS', 'SENDIST', 'G18DHOR', 'loc_prec', 'G17RGOV', 'G16OPRS', 'G17RLTG', 'district', 'CD_16', 'G17DLTG', 'G16RHOR', 'G18OSEN', 'G18OHOR', 'precinct', 'G18RSEN', 'G17OGOV', 'G17DGOV', 'HDIST_REM'}
#
# VT : ----
# {'NAMELSAD10', 'AMIN', 'OTHER', 'STATEFP10', 'TOTV14', 'COUNTYFP10', 'PRES16B', 'NAME10', 'WHITE', 'ASIAN', 'SENDIST', '2MORE', 'BLACK', 'SEN12B', 'TOTV12', 'TOTV16', 'COUSUBFP10', 'GEOID10', 'AWATER10', 'NHPI', 'INTPTLAT10', 'INTPTLON10', 'DISTNAME', 'ALAND10'}
#
# WI : ----
# {'PREIND612', 'GOVCON14', 'USHIND12', 'WSSREP212', 'CDADEM12', 'CDADEM16', 'WSSIND12', 'TRSTOT14', 'HISPANIC', 'GOVREP14', 'WSALIB16', 'WSAREP214', 'USHSCT16', 'WSASCT16', 'CDAREP16', 'USSDEM12', 'PISLAND18', 'PRECON16', 'BLACK', 'USHTOT12', 'GOVIND514', 'WSSIND16', 'GOVSCT12', 'USSSCT12', 'CDADEM212', 'WAGTOT12', 'WSASCT14', 'CDAIND16', 'GOVREP12', 'WSSSCT12', 'USSCON12', 'GOVSCT14', 'GOVDEM12', 'USSTOT12', 'USSDEM16', 'SEN', 'PREDEM16', 'WAGREP14', 'USHTOT16', 'USSIND212', 'PERSONS18', 'USHREP214', 'WSSAME12', 'WAGSCT12', 'WSSREP16', 'WAGIND12', 'USHGRN16', 'USSREP216', 'CDATOT16', 'CON', 'SOSCON14', 'USHDEM14', 'USHSCT12', 'PREIND1116', 'USSDEM14', 'PRELIB16', 'SOSIND14', 'ASIAN', 'USHSCT14', 'WSSTOT16', 'NAME', 'GOVDEM14', 'PREIND16', 'PREIND616', 'USHREP16', 'WSSTOT12', 'WAGDEM212', 'WSADEM16', 'PREREP12', 'USHDEM16', 'USSTOT14', 'OTHERMLT', 'WSATOT14', 'GOVIND12', 'WSAIND212', 'USHDEM12', 'AMINDIAN', 'PERSONS', 'WSAREP16', 'HISPANIC18', 'CDADEM216', 'SOSTOT14', 'PREIND416', 'WAGDEM14', 'PREIND212', 'WAGDEM12', 'CDASCT12', 'USHREP14', 'PRETOT16', 'USSREP16', 'PREIND412', 'ASIAN18', 'WHITE18', 'GOVIND214', 'PREREP16', 'WSSREP12', 'USHIND16', 'PREIND312', 'TRSSCT14', 'CDASCT16', 'GOVREP214', 'WAGSCT14', 'PREGRN16', 'WSSDEM16', 'WSATOT12', 'USHIND14', 'USSREP14', 'USSLIB16', 'SOSDEM14', 'TRSDEM14', 'PRECON12', 'ASM', 'PREDEM12', 'USSSCT16', 'WSAIND12', 'USHDEM216', 'WAGTOT14', 'WSSCON12', 'PRESCT16', 'GOVIND314', 'USSIND14', 'USHREP12', 'PREIND216', 'GOVTOT12', 'WAGIND14', 'USSIND12', 'SOSSCT14', 'WSAIND16', 'WSAIND14', 'OBJECTID', 'PREIND12', 'USSTOT16', 'GOVIND414', 'WSASCT12', 'WAGREP12', 'OTHER', 'CDAREP12', 'WSAREP14', 'WSSDEM12', 'TRSIND214', 'USHIND214', 'CDAIND12', 'PISLAND', 'USSREP12', 'AMINDIAN18', 'PREIND916', 'TRSIND14', 'SOSREP14', 'CNTY_NAME', 'PRETOT12', 'PREIND1016', 'WHITE', 'PREIND316', 'USHLIB16', 'GOVIND14', 'USHTOT14', 'OTHERMLT18', 'GOVTOT14', 'TRSCON14', 'WSSSCT16', 'WSAREP12', 'BLACK18', 'WSATOT16', 'OTHER18', 'PREIND816', 'WSAREP212', 'USSIND312', 'CDATOT12', 'GEOID10', 'PREIND512', 'PREIND716', 'PRESCT12', 'TRSREP14', 'USSSCT14', 'WSADEM12', 'WSADEM14', 'PREIND516', 'WSADEM212', 'GOVREP314'}

# %%
def flatten(xs):
    return [x for sublist in xs for x in sublist]

bulk_discrepancies = flatten([discrs for _, discrs in all_discrepancies])
bulk_discrepancies = list(set(bulk_discrepancies))

print("======== List of all unique discrepancies ========")
print("Total number of unique discrepancies: ", len(bulk_discrepancies))
bulk_discrepancies
# Out:
# ======== List of all unique discrepancies ========
# Total number of unique discrepancies:  485
# ['PRES12O',
#  'STATEFP10',
#  'PRES12OTH',
#  'CDADEM12',
#  'TS',
#  'NAME10',
#  '40K_45K',
#  'WSSIND12',
#  'HISPANIC',
#  'TOTVR14',
#  'GOVREP14',
#  'CTYNAME',
#  'WSASCT16',
#  'LEG02',
#  'BLACK',
#  'ADJ_WVAP',
#  'EL12G_PR_L',
#  'LSAD10',
#  'EL08G_US_1',
#  'USCD',
#  'T16SEND',
#  'PRES16OTH',
#  'CNTYABV',
#  'CDAIND16',
#  'GOVREP12',
#  'T16PRESOTH',
#  'ElectionYe',
#  'DISTNAME',
#  'TOTHH',
#  'USHTOT16',
#  '20K_25K',
#  'USSIND212',
#  'AliasNm',
#  'EL08G_GV_D',
#  'LHGTFT_19',
#  'MTFCC10',
#  'CTU_TYPE',
#  'WAGIND12',
#  'VTDID',
#  'TOTVR12',
#  'MNSENDIST',
#  'HD',
#  'JOINID',
#  'USSDEM14',
#  'SOSIND14',
#  'UNOCCUPIED',
#  'G16DPRS',
#  'WSSTOT16',
#  'jrsdctn',
#  'WSSTOT12',
#  'EL10G_US_3',
#  'EL10G_US_4',
#  'CNTYVTD',
#  'USHDEM16',
#  'OTHERMLT',
#  '10K_15K',
#  'EL12G_GV_W',
#  'USHDEM12',
#  'EL08G_USS_',
#  'AMINDIAN',
#  'WSAREP16',
#  'PREIND416',
#  'UNADJHISP',
#  'WAGDEM14',
#  'PREIND212',
#  '200K_MORE',
#  'county_fip',
#  'CNTYFIPS',
#  'USHREP14',
#  'PRETOT16',
#  'T16ATGD',
#  'MNLEGDIST',
#  'NAMELSAD10',
#  'AMIN',
#  'ADJASNVAP',
#  'USHIND16',
#  'ward',
#  'MCDCODE',
#  'TRSSCT14',
#  'GOVREP214',
#  'judge',
#  'WSATOT12',
#  'G17DHOD',
#  'FORD_19',
#  'ADJAMINVAP',
#  'CONGDIST',
#  'COUNTYFIPS',
#  'EL14G_US_1',
#  'SENDIST',
#  'CHICO_19',
#  'loc_prec',
#  'RO_G15',
#  'G16OPRS',
#  'PREDEM12',
#  'VTDST',
#  'USSSCT16',
#  'district',
#  'VALLAS_19',
#  'PRESCT16',
#  'REGVOT16',
#  'GOVTOT12',
#  'USSIND12',
#  'G17DGOV',
#  '15K_20K',
#  'FUNCSTAT10',
#  'WAGREP12',
#  'PERIM',
#  'CDAREP12',
#  'VTD_1',
#  'USHIND214',
#  'ShapeSTLen',
#  'G17RATG',
#  'AMINDIAN18',
#  'jurisdic_1',
#  'PREIND316',
#  '538GOP',
#  'USHTOT14',
#  'EL12G_GV_R',
#  'CD_2011',
#  'BHVAP',
#  'CD_16',
#  'District_1',
#  '60K_75K',
#  'DISTRICT',
#  'EL12G_GV_L',
#  'FIPS',
#  'RSHARE',
#  'USSSCT14',
#  'TOTTO14',
#  'INTPTLAT10',
#  'EL16G_GV_L',
#  'Pct_Name',
#  'ADJ_2MORE',
#  'PREIND612',
#  'USHIND12',
#  'G17OHOD',
#  'cnty_fp',
#  'EL16G_PR_D',
#  'WILS_G15',
#  'ADJNHPIVAP',
#  'GARCIA_G15',
#  'USHSCT16',
#  'CD116FP',
#  '2MORE',
#  'USHTOT12',
#  'GOVIND514',
#  'FIPS1',
#  'TOTV12',
#  'G18OSEN',
#  'VTD2016_x',
#  'G18RSEN',
#  'WSSSCT12',
#  'GOVSCT14',
#  'County',
#  'OTHVAP',
#  'USSTOT12',
#  'Shape__Len',
#  'USSDEM16',
#  'PREDEM16',
#  'EL12G_PR_D',
#  'PL10AA_TOT',
#  'EL12G_PR_R',
#  'MCCART_19',
#  'WILSON_19',
#  'WAGSCT12',
#  'WSSREP16',
#  'PRES08OTH',
#  'SDIST',
#  'EL08G_GV_L',
#  'county_lon',
#  'SALGRIF_19',
#  'EL12G_PR_T',
#  'CON',
#  'WALLS_G15',
#  'USHSCT12',
#  'PREIND1116',
#  'PRELIB16',
#  'EL16G_US_3',
#  'ASIAN',
#  'GOVDEM14',
#  'PREIND16',
#  'WAGDEM212',
#  'PRES00OTH',
#  'WSATOT14',
#  'CDADEM216',
#  'USSREP16',
#  'ASIAN18',
#  'MCDNAME',
#  'HDIST_REM',
#  'PRECODE',
#  'Shape_Area',
#  'PREIND312',
#  'WSSDEM16',
#  'PRECINCT_I',
#  'EL14G_US_2',
#  'TOTVR16',
#  'ADJ_ASIAN',
#  'PLACE',
#  'State',
#  'WSAIND12',
#  'REMEDIAL',
#  'USSIND14',
#  'ADJ_OTHER',
#  'WSAIND16',
#  'F2014GOVR',
#  'OBJECTID',
#  'PREIND12',
#  'WSASCT12',
#  'ADJ_NHPI',
#  'VTD_Name',
#  'WSAREP14',
#  'TRSIND214',
#  'COUNTYNAME',
#  'CDAIND12',
#  'PISLAND',
#  'EL12G_GV_D',
#  'USSREP12',
#  'EL14G_US_4',
#  '538DEM',
#  'PRES16B',
#  'EL16G_US_1',
#  'USS12D',
#  'ATG12D',
#  'ADJ_BVAP',
#  'HISPVAP',
#  'PREIND1016',
#  'EL16G_GV_T',
#  'GOVIND14',
#  'PCTCODE',
#  'F2014GOVD',
#  'WSAREP12',
#  '100K_125K',
#  'MCD',
#  'G16RHOR',
#  'T16SENR',
#  'COUSUBFP10',
#  'WSAREP212',
#  'EL10G_US_2',
#  'CNG02',
#  'PRESCT12',
#  'REG18D',
#  'TRSREP14',
#  'WSADEM14',
#  'PREIND516',
#  'FIPS2',
#  'PRES04OTH',
#  'ZEROPOP',
#  'VistaID',
#  'CDADEM16',
#  'TRSTOT14',
#  'Precinct',
#  'EL14G_US_3',
#  'ATG12R',
#  'G16DHOR',
#  'WSAREP214',
#  'USSDEM12',
#  'PISLAND18',
#  'SLDLST',
#  'CDADEM212',
#  '25K_30K',
#  'WSASCT14',
#  'DsslvID',
#  'EL08G_US_4',
#  'USSCON12',
#  'T16PRESD',
#  '538CMPCT',
#  'WAGREP14',
#  'PRECINCT_N',
#  'WSSAME12',
#  'RO_E15',
#  'EL10G_USS_',
#  'shape_len',
#  'USHGRN16',
#  'G16OHOR',
#  'CDATOT16',
#  'USHDEM14',
#  'EL16G_PR_L',
#  'VTDST10',
#  'USHSCT14',
#  'G17RGOV',
#  'NAME',
#  'VTD',
#  'EL12G_PR_W',
#  'county_nam',
#  'PREIND616',
#  'PREREP12',
#  '75K_100K',
#  'WSAIND212',
#  'G17DLTG',
#  'EL10G_US_1',
#  'T16PRESR',
#  'G18OHOR',
#  'HISPANIC18',
#  'SOSTOT14',
#  'Shape_Le_1',
#  'EL08G_GV_R',
#  'nBPOP',
#  'HDIST_11',
#  'G17RHOD',
#  'CNTYNAME',
#  'PREGRN16',
#  'full_text',
#  'STH16D',
#  'county_lat',
#  'KOZLAR_19',
#  'AREA',
#  'USSREP14',
#  'Area',
#  'BALLOTTYPE',
#  'USSLIB16',
#  'OCCUPIED',
#  'EL08G_US_3',
#  'TRSDEM14',
#  'TOTTO12',
#  'ASM',
#  'USHDEM216',
#  '125K_150K',
#  'ADJ_AMIN',
#  'PREIND216',
#  'precinct',
#  'EL12G_PR_1',
#  'INTPTLON10',
#  'JOYCE_19',
#  'GOVIND414',
#  'PRENAME',
#  'G16RPRS',
#  'WSSDEM12',
#  'POPULATION',
#  'TOTV14',
#  'GOV18C',
#  'PREIND916',
#  'GOV',
#  'SOSREP14',
#  'ENYIA_19',
#  'ADJ_BLACK',
#  'LESS_10K',
#  'WHITE',
#  'G18DHOR',
#  'newplan',
#  'OTHERMLT18',
#  'WSSSCT16',
#  'SEN12B',
#  'PCTNAME',
#  'DALEY_19',
#  'WSATOT16',
#  'OTHER18',
#  'PREIND816',
#  'GOV14U1',
#  'WSADEM12',
#  'VTD_Key',
#  'UNADJPOP',
#  'TOTVOTE16',
#  'CountyID',
#  'EL14G_USS_',
#  'GOVREP314',
#  'EL12G_GV_T',
#  'CD_12',
#  'G17DATG',
#  'FIORETTI_1',
#  'BLKHISP',
#  'GOVCON14',
#  'N_NHPI',
#  'WSSREP212',
#  'BPOP',
#  'T16ATGR',
#  'WSADEM212',
#  'WSALIB16',
#  'CDAREP16',
#  'PRECON16',
#  'ADJ_WHITE',
#  'CTYCOMDIST',
#  'WSSIND16',
#  'ADJOTHVAP',
#  'GOVSCT12',
#  'USSSCT12',
#  '35K_40K',
#  'WAGTOT12',
#  'WARD',
#  'EL16G_USS_',
#  'NHPI',
#  'oldplan',
#  'GOVDEM12',
#  'cnty_nm',
#  'SEN',
#  'REGVOT18',
#  'PERSONS18',
#  'USHREP214',
#  'USS12R',
#  'prec_num',
#  'CountyFips',
#  'locality',
#  'USSREP216',
#  'SOSCON14',
#  'H_AMN',
#  'SLDUST',
#  'MEND_19',
#  'USHREP16',
#  '45K_50K',
#  'EL16G_PR_R',
#  'TOTTO16',
#  'WSADEM16',
#  'Perimeter',
#  'EDRD_2012',
#  'USSTOT14',
#  'GOVIND12',
#  'TOTV16',
#  'PERSONS',
#  'ADJ_VAP',
#  'WAGDEM12',
#  'PRECK_19',
#  'CDASCT12',
#  'PREIND412',
#  'shape_area',
#  'ALAND10',
#  'Jurisdicti',
#  'WHITE18',
#  'CDDIST',
#  'GOVIND214',
#  'PREREP16',
#  'PrcncID',
#  'WSSREP12',
#  'CDASCT16',
#  'WAGSCT14',
#  'STH16R',
#  'COUNTYFP10',
#  'USHIND14',
#  'PRES16C',
#  'G18DSEN',
#  'FIORET_G15',
#  'SOSDEM14',
#  '150K_200K',
#  'PRECON12',
#  'EL08G_GV_T',
#  'EMAN_G15',
#  'WAGTOT14',
#  'WSSCON12',
#  'Shape_Leng',
#  'VTDI10',
#  'GOVIND314',
#  'USHREP12',
#  'EL16G_GV_R',
#  'SbPrcnc',
#  'TOTV_RO15',
#  'GOV14U2',
#  'WAGIND14',
#  'SOSSCT14',
#  'DPTYPE',
#  'WSAIND14',
#  'Shape__Are',
#  'REG18R',
#  'G18RHOR',
#  'USSTOT16',
#  'OTHER',
#  'EL16G_GV_D',
#  'TOWN',
#  'EL08G_US_2',
#  'ID',
#  'JUDDIST',
#  'EL16G_US_2',
#  'ADJ_POP',
#  'TRSIND14',
#  'CNTY_NAME',
#  'PRETOT12',
#  'USHLIB16',
#  'Label',
#  'PL10VA_TOT',
#  'PRECID',
#  'G17RLTG',
#  'GOVTOT14',
#  'TRSCON14',
#  '50K_60K',
#  'BLACK18',
#  'USSIND312',
#  'CDATOT12',
#  'GEOID10',
#  'AWATER10',
#  'PREIND512',
#  'TOTV_19',
#  'PREIND716',
#  'G17OGOV',
#  'EL16G_PR_W',
#  'EL12G_GV_1',
#  'TOTV_G15',
#  'EL16G_PR_T',
#  '30K_35K']

# %% [markdown]
# ## Election Data Summation

# %%
print("======== Election Data Summations by State ========")
print()
print("Format:")
print("Election = Total Votes \t\ttype: datatype of votes value")
print()

for state, gdf, matches, notes in states_gdf:
    print("---- {} ----".format(state))
    if notes is not None:
        print("# Note: {}".format(notes))
    
    cols_to_sum = set(matches).intersection(
                        set(elections).union(set(counts)))
        
    sums = dataqa.sum_column_values(gdf, cols_to_sum)
    for col, val in sums:
        print('{:10} = {:20} \t\ttype: {}'.format(col, val, type(val)))
    
    print()
# Out:
# ======== Election Data Summations by State ========
#
# Format:
# Election = Total Votes 		type: datatype of votes value
#
# ---- AK ----
# GOV18D     =                80954 		type: <class 'numpy.int64'>
# GOV18L     =                 3970 		type: <class 'numpy.int64'>
# GOV18R     =               100372 		type: <class 'numpy.int64'>
# PRES16D    =                69097 		type: <class 'numpy.int64'>
# PRES16G    =                 3782 		type: <class 'numpy.int64'>
# PRES16L    =                12004 		type: <class 'numpy.int64'>
# PRES16R    =               103457 		type: <class 'numpy.int64'>
# SEN16D     =                19602 		type: <class 'numpy.int64'>
# SEN16L     =                60768 		type: <class 'numpy.int64'>
# SEN16R     =                87854 		type: <class 'numpy.int64'>
# USH14D     =                77004 		type: <class 'numpy.int64'>
# USH14L     =                14715 		type: <class 'numpy.int64'>
# USH14R     =               102464 		type: <class 'numpy.int64'>
# USH16D     =                67274 		type: <class 'numpy.int64'>
# USH16L     =                20100 		type: <class 'numpy.int64'>
# USH16R     =               100702 		type: <class 'numpy.int64'>
# USH18D     =                83855 		type: <class 'numpy.int64'>
# USH18R     =               103385 		type: <class 'numpy.int64'>
#
# ---- AZ ----
# # Note: Shapefile name does not fit convention.
# AG18D      =              1120726 		type: <class 'numpy.int64'>
# AG18R      =              1201398 		type: <class 'numpy.int64'>
# GOV18D     =               994341 		type: <class 'numpy.int64'>
# GOV18R     =              1330863 		type: <class 'numpy.int64'>
# SEN18D     =              1191100 		type: <class 'numpy.int64'>
# SEN18R     =              1135200 		type: <class 'numpy.int64'>
# SOS18D     =              1176384 		type: <class 'numpy.int64'>
# SOS18R     =              1156132 		type: <class 'numpy.int64'>
# SSEN18D    =              1125010 		type: <class 'numpy.int64'>
# SSEN18R    =              1093513 		type: <class 'numpy.int64'>
# TRE18D     =              1052197 		type: <class 'numpy.int64'>
# TRE18R     =              1249120 		type: <class 'numpy.int64'>
# USH18D     =              1179193 		type: <class 'numpy.int64'>
# USH18G     =                18706 		type: <class 'numpy.int64'>
# USH18R     =              1139251 		type: <class 'numpy.int64'>
#
# ---- CO ----
# AG18D      =              1285464 		type: <class 'numpy.int64'>
# AG18R      =              1124757 		type: <class 'numpy.int64'>
# GOV18D     =              1348888 		type: <class 'numpy.int64'>
# GOV18R     =              1080801 		type: <class 'numpy.int64'>
# SOS18D     =              1313716 		type: <class 'numpy.int64'>
# SOS18R     =              1113927 		type: <class 'numpy.int64'>
# TRE18D     =              1292281 		type: <class 'numpy.int64'>
# TRE18R     =              1111641 		type: <class 'numpy.int64'>
# USH18D     =              1343345 		type: <class 'numpy.int64'>
# USH18R     =              1079772 		type: <class 'numpy.int64'>
#
# ---- CT ----
# AG18D      =               691496 		type: <class 'numpy.int64'>
# AG18R      =               605504 		type: <class 'numpy.int64'>
# COMP18D    =               718033 		type: <class 'numpy.int64'>
# COMP18R    =               563099 		type: <class 'numpy.int64'>
# GOV18D     =               676649 		type: <class 'numpy.int64'>
# GOV18R     =               624750 		type: <class 'numpy.int64'>
# SEN18D     =               787685 		type: <class 'numpy.int64'>
# SEN18R     =               545717 		type: <class 'numpy.int64'>
# SOS18D     =               735743 		type: <class 'numpy.int64'>
# SOS18R     =               557616 		type: <class 'numpy.int64'>
# TRE18D     =               717002 		type: <class 'numpy.int64'>
# TRE18R     =               569737 		type: <class 'numpy.int64'>
# USH18D     =               808652 		type: <class 'numpy.int64'>
# USH18R     =               512495 		type: <class 'numpy.int64'>
#
# ---- DE ----
# AG14D      =             121410.0 		type: <class 'numpy.float64'>
# AG14R      =              90257.0 		type: <class 'numpy.float64'>
# AG18D      =             218351.0 		type: <class 'numpy.float64'>
# AG18R      =             137730.0 		type: <class 'numpy.float64'>
# AUD14D     =             103939.0 		type: <class 'numpy.float64'>
# AUD14R     =             123100.0 		type: <class 'numpy.float64'>
# AUD18D     =             205624.0 		type: <class 'numpy.float64'>
# AUD18R     =             149481.0 		type: <class 'numpy.float64'>
# GOV12D     =             275986.0 		type: <class 'numpy.float64'>
# GOV12R     =             113788.0 		type: <class 'numpy.float64'>
# GOV16D     =             248321.0 		type: <class 'numpy.float64'>
# GOV16R     =             166835.0 		type: <class 'numpy.float64'>
# LG12D      =             238953.0 		type: <class 'numpy.float64'>
# LG12R      =               143973 		type: <class 'numpy.int64'>
# LG16D      =             248141.0 		type: <class 'numpy.float64'>
# LG16R      =             169291.0 		type: <class 'numpy.float64'>
# PRES12D    =             242585.0 		type: <class 'numpy.float64'>
# PRES12R    =             165429.0 		type: <class 'numpy.float64'>
# PRES16D    =             235612.0 		type: <class 'numpy.float64'>
# PRES16R    =             185064.0 		type: <class 'numpy.float64'>
# SEN12D     =             265420.0 		type: <class 'numpy.float64'>
# SEN12R     =             115653.0 		type: <class 'numpy.float64'>
# SEN14D     =             130588.0 		type: <class 'numpy.float64'>
# SEN14R     =              98810.0 		type: <class 'numpy.float64'>
# SEN18D     =             217391.0 		type: <class 'numpy.float64'>
# SEN18R     =             137106.0 		type: <class 'numpy.float64'>
# SH12D      =             226728.0 		type: <class 'numpy.float64'>
# SH12R      =             124805.0 		type: <class 'numpy.float64'>
# SH14D      =             116349.0 		type: <class 'numpy.float64'>
# SH14R      =              91575.0 		type: <class 'numpy.float64'>
# SH16D      =             226083.0 		type: <class 'numpy.float64'>
# SH16R      =             149871.0 		type: <class 'numpy.float64'>
# SH18D      =             199716.0 		type: <class 'numpy.float64'>
# SH18R      =             135694.0 		type: <class 'numpy.float64'>
# SSEN12D    =             234613.0 		type: <class 'numpy.float64'>
# SSEN12R    =             123380.0 		type: <class 'numpy.float64'>
# TRE14D     =             100218.0 		type: <class 'numpy.float64'>
# TRE14R     =             123105.0 		type: <class 'numpy.float64'>
# TRE18D     =             187240.0 		type: <class 'numpy.float64'>
# TRE18R     =             164001.0 		type: <class 'numpy.float64'>
# USH12D     =             249934.0 		type: <class 'numpy.float64'>
# USH12R     =             129707.0 		type: <class 'numpy.float64'>
# USH14D     =             137184.0 		type: <class 'numpy.float64'>
# USH14R     =              85134.0 		type: <class 'numpy.float64'>
# USH16D     =             233543.0 		type: <class 'numpy.float64'>
# USH16R     =             172239.0 		type: <class 'numpy.float64'>
# USH18D     =             227356.0 		type: <class 'numpy.float64'>
# USH18R     =             125363.0 		type: <class 'numpy.float64'>
#
# ---- GA ----
# PRES16D    = ... 		type: <class 'str'>
# PRES16L    = ... 		type: <class 'str'>
# PRES16R    = ... 		type: <class 'str'>
# SEN16D     = ... 		type: <class 'str'>
# SEN16L     = ... 		type: <class 'str'>
# SEN16R     = ... 		type: <class 'str'>
#
# ---- HI ----
# GOV18D     =               244934 		type: <class 'numpy.int64'>
# GOV18R     =               131719 		type: <class 'numpy.int64'>
# PRES16D    =             266891.0 		type: <class 'numpy.float64'>
# PRES16R    =             128847.0 		type: <class 'numpy.float64'>
# SEN16D     =             306604.0 		type: <class 'numpy.float64'>
# SEN16R     =              92653.0 		type: <class 'numpy.float64'>
# SEN18D     =               276316 		type: <class 'numpy.int64'>
# SEN18R     =               112035 		type: <class 'numpy.int64'>
# USH16D     =             445348.0 		type: <class 'numpy.float64'>
# USH16R     =              85626.0 		type: <class 'numpy.float64'>
# USH18D     =               287921 		type: <class 'numpy.int64'>
# USH18R     =                87348 		type: <class 'numpy.int64'>
#
# ---- IA ----
# PRES00D    =               638517 		type: <class 'numpy.int64'>
# PRES00G    =                29374 		type: <class 'numpy.int64'>
# PRES00R    =               634373 		type: <class 'numpy.int64'>
# PRES04D    =               741898 		type: <class 'numpy.int64'>
# PRES04R    =               751957 		type: <class 'numpy.int64'>
# PRES08D    =               828940 		type: <class 'numpy.int64'>
# PRES08R    =               682379 		type: <class 'numpy.int64'>
# PRES12D    =               822544 		type: <class 'numpy.int64'>
# PRES12R    =               730617 		type: <class 'numpy.int64'>
# PRES16D    =               653669 		type: <class 'numpy.int64'>
# PRES16R    =               800983 		type: <class 'numpy.int64'>
# TOTVOT00   =              1315563 		type: <class 'numpy.int64'>
# TOTVOT04   =              1506908 		type: <class 'numpy.int64'>
# TOTVOT08   =              1536820 		type: <class 'numpy.int64'>
# TOTVOT12   =              1582180 		type: <class 'numpy.int64'>
# TOTVOT16   =              1566031 		type: <class 'numpy.int64'>
#
# ---- IL ----
# # Note: Chicago only. Shapefile name does not fit convention.
#
# ---- MA ----
# # Note: Multiple shapefiles. Using MA_precincts_12_16.zip. Shapefile name does not fit convention.
# GOV14D     =              1004408 		type: <class 'numpy.int64'>
# GOV14I     =                71814 		type: <class 'numpy.int64'>
# GOV14R     =              1044573 		type: <class 'numpy.int64'>
# GOV18D     =               885770 		type: <class 'numpy.int64'>
# GOV18R     =              1781341 		type: <class 'numpy.int64'>
# PRES12D    =              1921290 		type: <class 'numpy.int64'>
# PRES12R    =              1188314 		type: <class 'numpy.int64'>
# PRES16D    =              1995196 		type: <class 'numpy.int64'>
# PRES16R    =              1090893 		type: <class 'numpy.int64'>
# SEN12D     =              1696346 		type: <class 'numpy.int64'>
# SEN12R     =              1458048 		type: <class 'numpy.int64'>
# SEN13D     =               645429 		type: <class 'numpy.int64'>
# SEN13R     =               525307 		type: <class 'numpy.int64'>
# SEN14D     =              1289944 		type: <class 'numpy.int64'>
# SEN14R     =               791950 		type: <class 'numpy.int64'>
# SEN18D     =              1633371 		type: <class 'numpy.int64'>
# SEN18R     =               979210 		type: <class 'numpy.int64'>
# SEN18U     =                91710 		type: <class 'numpy.int64'>
#
# ---- MD ----
# # Note: Multiple shapefiles. Using MD_precincts.zip
# AG14D      =               701386 		type: <class 'numpy.int64'>
# AG14L      =                46763 		type: <class 'numpy.int64'>
# AG14R      =               548604 		type: <class 'numpy.int64'>
# AG18D      =               894050 		type: <class 'numpy.int64'>
# AG18R      =               564151 		type: <class 'numpy.int64'>
# COMP14D    =               796738 		type: <class 'numpy.int64'>
# COMP14R    =               511995 		type: <class 'numpy.int64'>
# COMP18D    =               991794 		type: <class 'numpy.int64'>
# COMP18R    =               448838 		type: <class 'numpy.int64'>
# GOV14D     =               608476 		type: <class 'numpy.int64'>
# GOV14R     =               710854 		type: <class 'numpy.int64'>
# GOV18D     =               608810 		type: <class 'numpy.int64'>
# GOV18R     =               855539 		type: <class 'numpy.int64'>
# PRES12D    =              1218419 		type: <class 'numpy.int64'>
# PRES12R    =               792375 		type: <class 'numpy.int64'>
# PRES16D    =               897159 		type: <class 'numpy.int64'>
# PRES16G    =                24221 		type: <class 'numpy.int64'>
# PRES16L    =                55938 		type: <class 'numpy.int64'>
# PRES16R    =               654557 		type: <class 'numpy.int64'>
# SEN12D     =              1053951 		type: <class 'numpy.int64'>
# SEN12L     =                26165 		type: <class 'numpy.int64'>
# SEN12R     =               554795 		type: <class 'numpy.int64'>
# SEN12U     =               363245 		type: <class 'numpy.int64'>
# SEN16D     =               893627 		type: <class 'numpy.int64'>
# SEN16G     =                59034 		type: <class 'numpy.int64'>
# SEN16R     =               675205 		type: <class 'numpy.int64'>
# SEN18D     =               906253 		type: <class 'numpy.int64'>
# SEN18R     =               495134 		type: <class 'numpy.int64'>
# SSEN14D    =               716844 		type: <class 'numpy.int64'>
# SSEN14R    =               528421 		type: <class 'numpy.int64'>
# SSEN14U    =                 1787 		type: <class 'numpy.int64'>
# SSEN18D    =               866959 		type: <class 'numpy.int64'>
# SSEN18G    =                11459 		type: <class 'numpy.int64'>
# SSEN18L    =                 6444 		type: <class 'numpy.int64'>
# SSEN18R    =               524430 		type: <class 'numpy.int64'>
# SSEN18U    =                 8573 		type: <class 'numpy.int64'>
# USH12D     =              1194400 		type: <class 'numpy.int64'>
# USH12R     =               698266 		type: <class 'numpy.int64'>
# USH14D     =               737506 		type: <class 'numpy.int64'>
# USH14R     =               567879 		type: <class 'numpy.int64'>
# USH16D     =               886248 		type: <class 'numpy.int64'>
# USH16R     =               664681 		type: <class 'numpy.int64'>
# USH18D     =               909915 		type: <class 'numpy.int64'>
# USH18R     =               521827 		type: <class 'numpy.int64'>
#
# ---- MI ----
# PRES16D    =              2210068 		type: <class 'numpy.int64'>
# PRES16G    =                51147 		type: <class 'numpy.int64'>
# PRES16L    =               171437 		type: <class 'numpy.int64'>
# PRES16R    =              2270022 		type: <class 'numpy.int64'>
#
# ---- MN ----
# # Note: Multiple shapefiles. Using MN16.zip. Shapefile name does not fit convention.
# PRES16D    =              1367716 		type: <class 'numpy.int64'>
# PRES16G    =                36985 		type: <class 'numpy.int64'>
# PRES16I    =                53076 		type: <class 'numpy.int64'>
# PRES16L    =               112972 		type: <class 'numpy.int64'>
# PRES16R    =              1322951 		type: <class 'numpy.int64'>
# SH16D      =              1366375 		type: <class 'numpy.int64'>
# SH16R      =              1400587 		type: <class 'numpy.int64'>
# SSEN16D    =              1409775 		type: <class 'numpy.int64'>
# SSEN16R    =              1377128 		type: <class 'numpy.int64'>
# TOTVOT16   =              2968281 		type: <class 'numpy.int64'>
# USH16D     =              1434590 		type: <class 'numpy.int64'>
# USH16R     =              1334686 		type: <class 'numpy.int64'>
#
# ---- NC ----
# # Note: Multiple shapefiles. Using NC_VTD.zip. Shapefile name does not fit convention.
#
# ---- NM ----
# # Note: Shapefile name does not fit convention.
# AG18D      =               427583 		type: <class 'numpy.int64'>
# AG18L      =                32931 		type: <class 'numpy.int64'>
# AG18R      =               231296 		type: <class 'numpy.int64'>
# GOV18D     =               398368 		type: <class 'numpy.int64'>
# GOV18R     =               298091 		type: <class 'numpy.int64'>
# PRES16D    =               385234 		type: <class 'numpy.int64'>
# PRES16L    =                74541 		type: <class 'numpy.int64'>
# PRES16R    =               319667 		type: <class 'numpy.int64'>
# SEN18D     =               376998 		type: <class 'numpy.int64'>
# SEN18L     =               107201 		type: <class 'numpy.int64'>
# SEN18R     =               212813 		type: <class 'numpy.int64'>
# SOS16D     =               433227 		type: <class 'numpy.int64'>
# SOS16R     =               334733 		type: <class 'numpy.int64'>
# SOS18D     =               399134 		type: <class 'numpy.int64'>
# SOS18L     =                34527 		type: <class 'numpy.int64'>
# SOS18R     =               257306 		type: <class 'numpy.int64'>
#
# ---- OH ----
# PRES16D    =              2393911 		type: <class 'numpy.int64'>
# PRES16G    =                46262 		type: <class 'numpy.int64'>
# PRES16L    =               174473 		type: <class 'numpy.int64'>
# PRES16R    =              2840380 		type: <class 'numpy.int64'>
# SEN16D     =              1996908 		type: <class 'numpy.int64'>
# SEN16R     =              3118567 		type: <class 'numpy.int64'>
# SSEN16D    =               821822 		type: <class 'numpy.int64'>
# SSEN16R    =              1640498 		type: <class 'numpy.int64'>
# TOTREG16   =              7859534 		type: <class 'numpy.int64'>
# TURNOUT16  =    6345.312926665814 		type: <class 'numpy.float64'>
# USH16D     =              2154523 		type: <class 'numpy.int64'>
# USH16R     =              2996017 		type: <class 'numpy.int64'>
#
# ---- OK ----
# AG18D      =             421699.0 		type: <class 'numpy.float64'>
# AG18R      =             750769.0 		type: <class 'numpy.float64'>
# AUD18L     =             270313.0 		type: <class 'numpy.float64'>
# AUD18R     =             818851.0 		type: <class 'numpy.float64'>
# GOV18D     =             500973.0 		type: <class 'numpy.float64'>
# GOV18R     =             644579.0 		type: <class 'numpy.float64'>
# LG18D      =             406797.0 		type: <class 'numpy.float64'>
# LG18R      =             729221.0 		type: <class 'numpy.float64'>
# TRE18I     =             309525.0 		type: <class 'numpy.float64'>
# TRE18R     =             779657.0 		type: <class 'numpy.float64'>
# USH18D     =             428452.0 		type: <class 'numpy.float64'>
# USH18R     =             730531.0 		type: <class 'numpy.float64'>
#
# ---- OR ----
# AG16D      =              1011761 		type: <class 'numpy.int64'>
# AG16R      =               766743 		type: <class 'numpy.int64'>
# GOV16D     =               984922 		type: <class 'numpy.int64'>
# GOV16I     =                47481 		type: <class 'numpy.int64'>
# GOV16L     =                45191 		type: <class 'numpy.int64'>
# GOV16R     =               844372 		type: <class 'numpy.int64'>
# GOV18D     =               934498 		type: <class 'numpy.int64'>
# GOV18I     =                53392 		type: <class 'numpy.int64'>
# GOV18L     =                28927 		type: <class 'numpy.int64'>
# GOV18R     =               814988 		type: <class 'numpy.int64'>
# PRES16D    =              1002106 		type: <class 'numpy.int64'>
# PRES16G    =                50002 		type: <class 'numpy.int64'>
# PRES16L    =                94231 		type: <class 'numpy.int64'>
# PRES16R    =               782403 		type: <class 'numpy.int64'>
# SEN16D     =              1105119 		type: <class 'numpy.int64'>
# SEN16R     =               651106 		type: <class 'numpy.int64'>
# SOS16D     =               814089 		type: <class 'numpy.int64'>
# SOS16G     =                47576 		type: <class 'numpy.int64'>
# SOS16I     =                64956 		type: <class 'numpy.int64'>
# SOS16L     =                46975 		type: <class 'numpy.int64'>
# SOS16R     =               892667 		type: <class 'numpy.int64'>
# USH16D     =              1026851 		type: <class 'numpy.int64'>
# USH16R     =               809048 		type: <class 'numpy.int64'>
# USH18D     =              1061412 		type: <class 'numpy.int64'>
# USH18R     =               702531 		type: <class 'numpy.int64'>
#
# ---- PA ----
# # Note: Shapefile uses VTDs. Shapefile name does not fit convention.
# GOV10D     =   1810618.5497945147 		type: <class 'numpy.float64'>
# GOV10R     =    2170505.937484242 		type: <class 'numpy.float64'>
# PRES12D    =   2983823.8808644107 		type: <class 'numpy.float64'>
# PRES12R    =    2676889.311001338 		type: <class 'numpy.float64'>
# SEN10D     =   1944080.2181969609 		type: <class 'numpy.float64'>
# SEN10R     =   2027647.4629169584 		type: <class 'numpy.float64'>
#
# ---- RI ----
# GOV18D     =               198011 		type: <class 'numpy.int64'>
# GOV18R     =               140716 		type: <class 'numpy.int64'>
# PRES16D    =               248124 		type: <class 'numpy.int64'>
# PRES16R    =               178596 		type: <class 'numpy.int64'>
# SEN18D     =               231441 		type: <class 'numpy.int64'>
# SEN18R     =               144996 		type: <class 'numpy.int64'>
# TOTVOT16   =               462839 		type: <class 'numpy.int64'>
# TOTVOT18   =               381814 		type: <class 'numpy.int64'>
#
# ---- TX ----
# # Note: Shapefile stored externally (MIT). Shapefile name does not fit convention.
# GOV14D     =              1835458 		type: <class 'numpy.int64'>
# GOV14R     =              2796251 		type: <class 'numpy.int64'>
# PRES12D    =              3307609 		type: <class 'numpy.int64'>
# PRES12R    =              4568788 		type: <class 'numpy.int64'>
# PRES16D    =              3877626 		type: <class 'numpy.int64'>
# PRES16R    =              4684288 		type: <class 'numpy.int64'>
# SEN12D     =              3194484 		type: <class 'numpy.int64'>
# SEN12R     =              4439084 		type: <class 'numpy.int64'>
# SEN14D     =              1597272 		type: <class 'numpy.int64'>
# SEN14R     =              2861244 		type: <class 'numpy.int64'>
#
# ---- UT ----
# GOV16D     =               323157 		type: <class 'numpy.int64'>
# GOV16R     =               750899 		type: <class 'numpy.int64'>
# PRES16D    =             310701.0 		type: <class 'numpy.float64'>
# PRES16I    =               243264 		type: <class 'numpy.int64'>
# PRES16R    =               515081 		type: <class 'numpy.int64'>
# SEN16D     =               301952 		type: <class 'numpy.int64'>
# SEN16R     =               759487 		type: <class 'numpy.int64'>
#
# ---- VA ----
#
# ---- VT ----
# # Note: Uses towns as counting unit. Shapefile name does not fit convention.
# PRES12D    = 1,78918268254303370197833863401,238509951115992925812,6357246533332082673565829938249275684045827881794011333863427971,2755522875282965045304182941,2287364104971,5931,5924761,4615824556952199241581,140168346342538821,3323203591,0033011,2049191,7801,80523318763355646317987412648374678211132363844,6211794338973929713,3561,2906521,839192431319272439504611608912358532603155524817321,0641,5622594638704962,3442608952824548574981,2114,252383199177663734495622471,2133766921461,1191,361270795975917291755053127241,9462,1277954877531,1515285217563,6946641,3785092288247741,97831741643375414,3261,6774,6186,6301,7458501,9902,5891,7222193,0766,5131,2267423,3291,9413584566713982902292562973314083616232511,4094351,2342991712901232285611,1962885002303151629624053931701041958407494,503762821,4391601,047223238121241,163274310297122 		type: <class 'str'>
# PRES12L    =                 3487 		type: <class 'numpy.int64'>
# PRES12R    = 1,08193191671583261323533627750718150221471761816613303232751225817140223221512225120123031276127541902193988263061560232435244181852619185421742577521,147283947363287475211384788661111362012115751214613038715956833366880098118461843061586962885582363991419625555915762992342614891,41752543729313816126216329432254116543113261136119334732001884971021733552021,3421195091302194682941,0292,4302481021094267019149513033822632770406508234443913144481131842493471,0481,734426221208402189253216700261685118912371976541571121614162,5926572,5513,6406522321,0261,9666501031,4032,7485653761,6975521852163901581491501691832792401533752486631518481011212346914311431220823910319517555527023611292935494681,7534242085055507122137822167317616518945 		type: <class 'str'>
# PRES16D    = 1,46911058168246292156783242921,07551789282752174942,682671594270171228296302292117918151356534712149415952952095021,0634891240181713930183362291,0194743023241,2871,4163051,101485381645159651125827130291252397531,0672213397882169246911,5501,97416116650339543280795352470252478188102357694,3471694097973068273,1901,1585381,982173395302233337453681476682107192023115174326529921,3152313936984281,8732227452674696523851,0643,495325163139529654124921991,0012835911569641,319209563843725941364343206721,6531,7606583946881,0325864177193,6986491,1134241867517522,03527137438962414,5191,7944,4836,7531,7267962,0172,2601,6942003,3907,2461,2386963,5082,1052893785022902071461841963043083505281861,160435885271811941131235001,1452263491892171017212562431341031616276623,361740711,452166761166213991995220328129994 		type: <class 'str'>
# PRES16G    =                 6758 		type: <class 'numpy.int64'>
# PRES16L    =                10078 		type: <class 'numpy.int64'>
# PRES16R    = 1,11013122220168341175313372785581475012954207188595360337284126581895227628207292702112563268374682093084299473382276283116046382402961,0236992313888071,2683771,19235533649423450196883116113239276855202411324752327233957415591461256017429916080831264129152916310323261859682792132625121,30355840319112513026817932542311114669131274183132303902091755761081624062171,5101406471061735993399792,7342691221234635017448613735228533879462372312565413994311401962163011,0911,8624542521953561422842284922167081291182101825921691172054092,0825122,4253,0306232328902,0855151109412,0595043711,4815362172314251931831932102442732641494032657371531,0049617528410125010532427424211824119761433828312393976584351,9493341870654681173138953666123818315866 		type: <class 'str'>
# SEN12R     = ,14545535525611514122313321924194904431042011168525970148148331801192851671,090924271081843452168461,8691949381336531514281022421792585735247717527311236328781442022757651,37733418918531914720819057319651410973213170541110911202912,0366001,9172,9655371718351,429486881,2032,3364602811,47642915318429412411210712010822018811729118851013159192851584410692249165183801581264021961638166614033601,266386267585236397103711248413912816725 		type: <class 'str'>
# SEN16D     = 1,62314468210302310201753553081,14053797398842585312,6637536193071782513215427527213221753905527861704191143643187151,2865852764242325635214143051,2246663854671,5841,7774221,436534424713199784142986142291275473731,2052723589102481,0567741,7021,95018517657331603273893380558295574192111357924,3471764318223458783,2201,1895771,928175351322267384524131537462127732103095294366849891,4012224117064432,0672318042764487654761,1793,908357174160567604085042231,0483116061491,0621,261260684894856761484553387161,7841,8757204547161,0975844827803,7676961,2354442087847432,12027640841169214,6441,8264,9377,2821,8238982,1152,6621,7632193,4597,3601,3087823,6692,1803213965773172251872192552953563465952111,2724401,0732911032451341834921,177244372216209125797312307148951667137323,751715621,404145915191240108201,026227296300114 		type: <class 'str'>
# SEN16R     = 1,174125252121863921604139132166618759436642112108004054103181506220644239251722986023631039198120672022724011,0233201372262775242362483041,0866512103227731,2293591,126367355575257514106927125168242284805802471685552247404208707911681355420035219875933463329950616812325448873782762322715421,61161640829714721930119531641282117720137254162141318892181965041321865252791,4551566381182255653391,0242,6982761321184915618050112734326132690485564286644873534571332802563571,2792,2255812852474292013172837282798371801392752497801751452194332,5406792,5563,5287362711,0622,1716601131,2142,5525734201,754606241324441232196175199215336282185406298857189980117166292722151583873072981183271976343413031301051007664321,6544093982769510127130852964218217616749 		type: <class 'str'>
# USH12D     = 1,91819071270323414200944514071,3075201,0381151113105982,6667847103772172793736633844267291774345728391964271504113749101,3736492474283405453284403731,3478654325621,7691,8365521,6386284947552549671681,252172357354548921,4013233701,0363101,2539461,8661,823233194673786963391,066471716403708208144406844,5331744249224171,0123,2641,3086961,856197461361299458524811619572228662472905354517321,0821,5772714948815122,4542719282854809255661,4054,741420202195738604185642451,2423566691391,1531,379317896626198151925233578022,1672,4548895117651,2175455667873,7607171,4785192418277672,06932744545280414,0411,6825,0617,1411,8368882,1152,9101,8162373,2386,7601,3018233,5001,9153734757394082982502633503624303826643071,5164491,3703081953331352285581,2072995352313421921,0834334531901262019547944,560773721,4161491,055214245121291,234263311272132 		type: <class 'str'>
# USH12R     = ,31444031123511212420612022525186793941041851198423462149133324741182501481,05789418941733361897591,665188868331662144404962391842424230842616430287232302701341732217111,2622991711662821302001615061724769967186155475126761123151,8125151,7122,6824721687771,241480661,0182,0104322591,3113631471712721251251051331052091961182831724879960781801574311787239161194821341123781821437558753693501,19134123686473579991641246912412614925 		type: <class 'str'>
# USH14D     = 1,1189762129221213112442842431,01034561674631734471,6905614992231291921872419725981453625444651811729669237233652782432165113139292082282627385512923011,0821,0732909113532574601375499664692229225344517321602527761458334741,1029591131052726541617654331136820837211277220512,4721232615292345331,9237443471,195110295221212278273191065571234681301732692984586568371622935543241,1741314471883175113308822,7392741391214053723124916972717334191636837175553193835421213252345441,3101,5355262845417653863426132,5134618173181605854941,2492212962884037,6791,0432,7833,8231,1906111,4041,3651,1871272,0193,8938745041,9541,069232291395287186174141193265260252383159980293804209791817411537582614136913618796612220236101811025944772,6215184996492765137160631166014018215682 		type: <class 'str'>
# USH14R     = ,46916473692683996275851911381633423534216523256197315891461692036781,2212981441502621021691524101694719968163143430118701212071,4964191,5582,3494231487551,259438668631,5854242921,06829114817022210811412311599207164952101604811015346868139451167520612818369161108370151129705642352255922288274924430682985015355799410318 		type: <class 'str'>
#
# ---- WI ----
# # Note: Shapefile name does not fit convention.

# %% [markdown]
# ## Demographics Data Summation

# %%
print("======== Demographics Summations by State ========")
print()
print("Format:")
print("Demographic = Population Count \ttype: datatype of population count value")
print()

for state, gdf, matches, notes in states_gdf:
    print("---- {} ----".format(state))
    if notes is not None:
        print("# Note: {}".format(notes))
    
    cols_to_sum = set(matches).intersection(demographics)
        
    sums = dataqa.sum_column_values(gdf, cols_to_sum)
    for col, val in sums:
        print('{:10} = {:20} \t\ttype: {}'.format(col, val, str(type(val))))
    
    print()
# Out:
# ======== Demographics Summations by State ========
#
# Format:
# Demographic = Population Count 	type: datatype of population count value
#
# ---- AK ----
# 2MOREVAP   =                25525 		type: <class 'numpy.int64'>
# AMINVAP    =                70630 		type: <class 'numpy.int64'>
# ASIANVAP   =                28312 		type: <class 'numpy.int64'>
# BVAP       =                16904 		type: <class 'numpy.int64'>
# NHPIVAP    =                 4599 		type: <class 'numpy.int64'>
# OTHERVAP   =                 7988 		type: <class 'numpy.int64'>
# TOTPOP     =               710231 		type: <class 'numpy.int64'>
# VAP        =               522853 		type: <class 'numpy.int64'>
# WVAP       =               368895 		type: <class 'numpy.int64'>
#
# ---- AZ ----
# # Note: Shapefile name does not fit convention.
# 2MOREVAP   =              60372.0 		type: <class 'numpy.float64'>
# AMINVAP    =             175207.0 		type: <class 'numpy.float64'>
# ASIANVAP   =             132317.0 		type: <class 'numpy.float64'>
# BVAP       =             172249.0 		type: <class 'numpy.float64'>
# HISP       =            1895149.0 		type: <class 'numpy.float64'>
# HVAP       =            1191203.0 		type: <class 'numpy.float64'>
# H_2MORE    =             103669.0 		type: <class 'numpy.float64'>
# H_AMIN     =              39103.0 		type: <class 'numpy.float64'>
# H_ASIAN    =               6186.0 		type: <class 'numpy.float64'>
# H_BLACK    =              19907.0 		type: <class 'numpy.float64'>
# H_NHPI     =               1689.0 		type: <class 'numpy.float64'>
# H_OTHER    =             753121.0 		type: <class 'numpy.float64'>
# H_WHITE    =             971474.0 		type: <class 'numpy.float64'>
# NHPIVAP    =               8200.0 		type: <class 'numpy.float64'>
# NH_2MORE   =             114631.0 		type: <class 'numpy.float64'>
# NH_AMIN    =             257426.0 		type: <class 'numpy.float64'>
# NH_ASIAN   =             170509.0 		type: <class 'numpy.float64'>
# NH_BLACK   =             239101.0 		type: <class 'numpy.float64'>
# NH_NHPI    =              10959.0 		type: <class 'numpy.float64'>
# NH_OTHER   =               8595.0 		type: <class 'numpy.float64'>
# NH_WHITE   =            3695647.0 		type: <class 'numpy.float64'>
# OTHERVAP   =               5560.0 		type: <class 'numpy.float64'>
# TOTPOP     =            6392017.0 		type: <class 'numpy.float64'>
# VAP        =            4763003.0 		type: <class 'numpy.float64'>
# WVAP       =            3017895.0 		type: <class 'numpy.float64'>
#
# ---- CO ----
# 2MOREVAP   =                52039 		type: <class 'numpy.int64'>
# AMINVAP    =                22560 		type: <class 'numpy.int64'>
# ASIANVAP   =               101885 		type: <class 'numpy.int64'>
# BVAP       =               137437 		type: <class 'numpy.int64'>
# HISP       =              1037160 		type: <class 'numpy.int64'>
# HVAP       =               662933 		type: <class 'numpy.int64'>
# H_2MORE    =                70158 		type: <class 'numpy.int64'>
# H_AMIN     =                23550 		type: <class 'numpy.int64'>
# H_ASIAN    =                 2815 		type: <class 'numpy.int64'>
# H_BLACK    =                12032 		type: <class 'numpy.int64'>
# H_NHPI     =                  736 		type: <class 'numpy.int64'>
# H_OTHER    =               355033 		type: <class 'numpy.int64'>
# H_WHITE    =               566866 		type: <class 'numpy.int64'>
# NHPIVAP    =                 3376 		type: <class 'numpy.int64'>
# NH_2MORE   =                99318 		type: <class 'numpy.int64'>
# NH_AMIN    =                29840 		type: <class 'numpy.int64'>
# NH_ASIAN   =               134096 		type: <class 'numpy.int64'>
# NH_BLACK   =               187370 		type: <class 'numpy.int64'>
# NH_NHPI    =                 4900 		type: <class 'numpy.int64'>
# NH_OTHER   =                 6621 		type: <class 'numpy.int64'>
# NH_WHITE   =              3519213 		type: <class 'numpy.int64'>
# OTHERVAP   =                 3924 		type: <class 'numpy.int64'>
# TOTPOP     =              5027604 		type: <class 'numpy.int64'>
# VAP        =              3802040 		type: <class 'numpy.int64'>
# WVAP       =              2808959 		type: <class 'numpy.int64'>
#
# ---- CT ----
# 2MOREVAP   =                30800 		type: <class 'numpy.int64'>
# AMINVAP    =                 5044 		type: <class 'numpy.int64'>
# ASIANVAP   =               100486 		type: <class 'numpy.int64'>
# BVAP       =               246016 		type: <class 'numpy.int64'>
# HISP       =               479087 		type: <class 'numpy.int64'>
# HVAP       =               318947 		type: <class 'numpy.int64'>
# H_2MORE    =                33171 		type: <class 'numpy.int64'>
# H_AMIN     =                 4371 		type: <class 'numpy.int64'>
# H_ASIAN    =                 1474 		type: <class 'numpy.int64'>
# H_BLACK    =                27177 		type: <class 'numpy.int64'>
# H_NHPI     =                  470 		type: <class 'numpy.int64'>
# H_OTHER    =               186276 		type: <class 'numpy.int64'>
# H_WHITE    =               226148 		type: <class 'numpy.int64'>
# NHPIVAP    =                  729 		type: <class 'numpy.int64'>
# NH_2MORE   =                59505 		type: <class 'numpy.int64'>
# NH_AMIN    =                 6885 		type: <class 'numpy.int64'>
# NH_ASIAN   =               134091 		type: <class 'numpy.int64'>
# NH_BLACK   =               335119 		type: <class 'numpy.int64'>
# NH_NHPI    =                  958 		type: <class 'numpy.int64'>
# NH_OTHER   =                12190 		type: <class 'numpy.int64'>
# NH_WHITE   =              2546262 		type: <class 'numpy.int64'>
# OTHERVAP   =                 8512 		type: <class 'numpy.int64'>
# TOTPOP     =              3574097 		type: <class 'numpy.int64'>
# VAP        =              2757082 		type: <class 'numpy.int64'>
# WVAP       =              2046548 		type: <class 'numpy.int64'>
#
# ---- DE ----
# 2MOREVAP   =                 8492 		type: <class 'numpy.int64'>
# AMINVAP    =                 2248 		type: <class 'numpy.int64'>
# ASIANVAP   =                21667 		type: <class 'numpy.int64'>
# BVAP       =               134984 		type: <class 'numpy.int64'>
# HISP       =                73221 		type: <class 'numpy.int64'>
# HVAP       =                46136 		type: <class 'numpy.int64'>
# H_2MORE    =                 5570 		type: <class 'numpy.int64'>
# H_AMIN     =                 1357 		type: <class 'numpy.int64'>
# H_ASIAN    =                  241 		type: <class 'numpy.int64'>
# H_BLACK    =                 5032 		type: <class 'numpy.int64'>
# H_NHPI     =                  162 		type: <class 'numpy.int64'>
# H_OTHER    =                28994 		type: <class 'numpy.int64'>
# H_WHITE    =                31865 		type: <class 'numpy.int64'>
# NHPIVAP    =                  177 		type: <class 'numpy.int64'>
# NH_2MORE   =                18284 		type: <class 'numpy.int64'>
# NH_AMIN    =                 2824 		type: <class 'numpy.int64'>
# NH_ASIAN   =                28308 		type: <class 'numpy.int64'>
# NH_BLACK   =               186782 		type: <class 'numpy.int64'>
# NH_NHPI    =                  238 		type: <class 'numpy.int64'>
# NH_OTHER   =                 1525 		type: <class 'numpy.int64'>
# NH_WHITE   =               586752 		type: <class 'numpy.int64'>
# OTHERVAP   =                  829 		type: <class 'numpy.int64'>
# TOTPOP     =               897934 		type: <class 'numpy.int64'>
# VAP        =               692169 		type: <class 'numpy.int64'>
# WVAP       =               477636 		type: <class 'numpy.int64'>
#
# ---- GA ----
# 2MOREVAP   =                77345 		type: <class 'numpy.int64'>
# AMINVAP    =                16324 		type: <class 'numpy.int64'>
# ASIANVAP   =               234164 		type: <class 'numpy.int64'>
# BVAP       =              2072946 		type: <class 'numpy.int64'>
# HISP       =               853689 		type: <class 'numpy.int64'>
# HVAP       =               539002 		type: <class 'numpy.int64'>
# H_2MORE    =                55509 		type: <class 'numpy.int64'>
# H_AMIN     =                10872 		type: <class 'numpy.int64'>
# H_ASIAN    =                 2775 		type: <class 'numpy.int64'>
# H_BLACK    =                39635 		type: <class 'numpy.int64'>
# H_NHPI     =                 1647 		type: <class 'numpy.int64'>
# H_OTHER    =               369731 		type: <class 'numpy.int64'>
# H_WHITE    =               373520 		type: <class 'numpy.int64'>
# NHPIVAP    =                 3699 		type: <class 'numpy.int64'>
# NH_2MORE   =               151980 		type: <class 'numpy.int64'>
# NH_AMIN    =                21279 		type: <class 'numpy.int64'>
# NH_ASIAN   =               311692 		type: <class 'numpy.int64'>
# NH_BLACK   =              2910800 		type: <class 'numpy.int64'>
# NH_NHPI    =                 5152 		type: <class 'numpy.int64'>
# NH_OTHER   =                19141 		type: <class 'numpy.int64'>
# NH_WHITE   =              5413920 		type: <class 'numpy.int64'>
# OTHERVAP   =                10107 		type: <class 'numpy.int64'>
# TOTPOP     =              9687653 		type: <class 'numpy.int64'>
# VAP        =              7196101 		type: <class 'numpy.int64'>
# WVAP       =              4242514 		type: <class 'numpy.int64'>
#
# ---- HI ----
# 2MOREVAP   =               166762 		type: <class 'numpy.int64'>
# AMINVAP    =                 2323 		type: <class 'numpy.int64'>
# ASIANVAP   =               434573 		type: <class 'numpy.int64'>
# BVAP       =                15662 		type: <class 'numpy.int64'>
# HISP       =               120842 		type: <class 'numpy.int64'>
# HVAP       =                75574 		type: <class 'numpy.int64'>
# H_2MORE    =                56644 		type: <class 'numpy.int64'>
# H_AMIN     =                 1341 		type: <class 'numpy.int64'>
# H_ASIAN    =                11784 		type: <class 'numpy.int64'>
# H_BLACK    =                 1520 		type: <class 'numpy.int64'>
# H_NHPI     =                 7200 		type: <class 'numpy.int64'>
# H_OTHER    =                15097 		type: <class 'numpy.int64'>
# H_WHITE    =                27256 		type: <class 'numpy.int64'>
# NHPIVAP    =                90694 		type: <class 'numpy.int64'>
# NH_2MORE   =               263983 		type: <class 'numpy.int64'>
# NH_AMIN    =                 2823 		type: <class 'numpy.int64'>
# NH_ASIAN   =               513294 		type: <class 'numpy.int64'>
# NH_BLACK   =                19904 		type: <class 'numpy.int64'>
# NH_NHPI    =               128222 		type: <class 'numpy.int64'>
# NH_OTHER   =                 1888 		type: <class 'numpy.int64'>
# NH_WHITE   =               309343 		type: <class 'numpy.int64'>
# OTHERVAP   =                 1363 		type: <class 'numpy.int64'>
# TOTPOP     =              1360299 		type: <class 'numpy.int64'>
# VAP        =              1056481 		type: <class 'numpy.int64'>
# WVAP       =               269530 		type: <class 'numpy.int64'>
#
# ---- IA ----
# 2MOREVAP   =                17141 		type: <class 'numpy.int64'>
# AMINVAP    =                 6038 		type: <class 'numpy.int64'>
# ASIANVAP   =                39569 		type: <class 'numpy.int64'>
# BVAP       =                57064 		type: <class 'numpy.int64'>
# HISP       =               151544 		type: <class 'numpy.int64'>
# HVAP       =                88337 		type: <class 'numpy.int64'>
# H_2MORE    =                11658 		type: <class 'numpy.int64'>
# H_AMIN     =                 2503 		type: <class 'numpy.int64'>
# H_ASIAN    =                  497 		type: <class 'numpy.int64'>
# H_BLACK    =                 2242 		type: <class 'numpy.int64'>
# H_OTHER    =                54000 		type: <class 'numpy.int64'>
# H_WHITE    =                80438 		type: <class 'numpy.int64'>
# NHPIVAP    =                 1181 		type: <class 'numpy.int64'>
# NH_2MORE   =                41675 		type: <class 'numpy.int64'>
# NH_AMIN    =                 8581 		type: <class 'numpy.int64'>
# NH_ASIAN   =                52597 		type: <class 'numpy.int64'>
# NH_BLACK   =                86906 		type: <class 'numpy.int64'>
# NH_NHPI    =                 1797 		type: <class 'numpy.int64'>
# NH_OTHER   =                 2132 		type: <class 'numpy.int64'>
# NH_WHITE   =              2701123 		type: <class 'numpy.int64'>
# OTHERVAP   =                 1057 		type: <class 'numpy.int64'>
# TOTPOP     =              3046355 		type: <class 'numpy.int64'>
# VAP        =              2318362 		type: <class 'numpy.int64'>
# WVAP       =              2107975 		type: <class 'numpy.int64'>
#
# ---- IL ----
# # Note: Chicago only. Shapefile name does not fit convention.
# 2MOREVAP   =    23701.81097761165 		type: <class 'numpy.float64'>
# AMINVAP    =   3220.4020166269497 		type: <class 'numpy.float64'>
# ASIANVAP   =   122701.57245268475 		type: <class 'numpy.float64'>
# BVAP       =    643557.6466378801 		type: <class 'numpy.float64'>
# HISP       =    778823.9334779162 		type: <class 'numpy.float64'>
# HVAP       =    524449.9712480567 		type: <class 'numpy.float64'>
# H_2MORE    =    37197.10909686604 		type: <class 'numpy.float64'>
# H_AMIN     =    9239.798897347448 		type: <class 'numpy.float64'>
# H_ASIAN    =   2260.8398302805454 		type: <class 'numpy.float64'>
# H_BLACK    =   15319.520973717865 		type: <class 'numpy.float64'>
# H_NHPI     =    455.9938087179302 		type: <class 'numpy.float64'>
# H_OTHER    =   356254.71931660705 		type: <class 'numpy.float64'>
# H_WHITE    =    358095.9515543793 		type: <class 'numpy.float64'>
# NHPIVAP    =    470.9920263093641 		type: <class 'numpy.float64'>
# NH_2MORE   =    35939.30884964757 		type: <class 'numpy.float64'>
# NH_AMIN    =   4095.3898520475177 		type: <class 'numpy.float64'>
# NH_ASIAN   =   144881.56424711802 		type: <class 'numpy.float64'>
# NH_BLACK   =    872006.3349713972 		type: <class 'numpy.float64'>
# NH_NHPI    =    556.9920263093637 		type: <class 'numpy.float64'>
# NH_OTHER   =    4226.697228762735 		type: <class 'numpy.float64'>
# NH_WHITE   =    854525.0015836715 		type: <class 'numpy.float64'>
# OTHERVAP   =    2936.797797617949 		type: <class 'numpy.float64'>
# TOTPOP     =     2695055.22223687 		type: <class 'numpy.float64'>
# VAP        =   2073503.5406012186 		type: <class 'numpy.float64'>
# WVAP       =     752464.347444431 		type: <class 'numpy.float64'>
#
# ---- MA ----
# # Note: Multiple shapefiles. Using MA_precincts_12_16.zip. Shapefile name does not fit convention.
# 2MOREVAP   =    69536.41433409628 		type: <class 'numpy.float64'>
# AMINVAP    =    8214.442703233644 		type: <class 'numpy.float64'>
# ASIANVAP   =   268927.96030954993 		type: <class 'numpy.float64'>
# BVAP       =   288449.31596011465 		type: <class 'numpy.float64'>
# HISP       =    681574.5040915324 		type: <class 'numpy.float64'>
# HVAP       =   416580.97300083924 		type: <class 'numpy.float64'>
# H_AMIN     =   15064.281075512125 		type: <class 'numpy.float64'>
# H_ASIAN    =    5913.045311649861 		type: <class 'numpy.float64'>
# H_BLACK    =   61403.226590386854 		type: <class 'numpy.float64'>
# H_NHPI     =     3221.50654650452 		type: <class 'numpy.float64'>
# H_OTHER    =    278679.4850743842 		type: <class 'numpy.float64'>
# H_WHITE    =    317292.9594930949 		type: <class 'numpy.float64'>
# NHPIVAP    =   1187.9682639123303 		type: <class 'numpy.float64'>
# NH_AMIN    =    35607.09578430552 		type: <class 'numpy.float64'>
# NH_ASIAN   =    388069.0291578567 		type: <class 'numpy.float64'>
# NH_BLACK   =   446865.19663259294 		type: <class 'numpy.float64'>
# NH_NHPI    =    7030.736045298074 		type: <class 'numpy.float64'>
# NH_OTHER   =    90789.28025305326 		type: <class 'numpy.float64'>
# NH_WHITE   =    5078233.872527252 		type: <class 'numpy.float64'>
# OTHERVAP   =    45854.59836936093 		type: <class 'numpy.float64'>
# TOTPOP     =    6728169.714491891 		type: <class 'numpy.float64'>
# VAP        =    5124198.413256808 		type: <class 'numpy.float64'>
# WVAP       =    4025446.740315702 		type: <class 'numpy.float64'>
#
# ---- MD ----
# # Note: Multiple shapefiles. Using MD_precincts.zip
# 2MOREVAP   =                63854 		type: <class 'numpy.int64'>
# AMINVAP    =                10722 		type: <class 'numpy.int64'>
# ASIANVAP   =               245537 		type: <class 'numpy.int64'>
# BVAP       =              1239796 		type: <class 'numpy.int64'>
# HISP       =               470632 		type: <class 'numpy.int64'>
# HVAP       =               322308 		type: <class 'numpy.int64'>
# H_2MORE    =                38868 		type: <class 'numpy.int64'>
# H_AMIN     =                 6605 		type: <class 'numpy.int64'>
# H_ASIAN    =                 2159 		type: <class 'numpy.int64'>
# H_BLACK    =                26069 		type: <class 'numpy.int64'>
# H_NHPI     =                  745 		type: <class 'numpy.int64'>
# H_OTHER    =               194860 		type: <class 'numpy.int64'>
# H_WHITE    =               201326 		type: <class 'numpy.int64'>
# NHPIVAP    =                 1937 		type: <class 'numpy.int64'>
# NH_2MORE   =               125840 		type: <class 'numpy.int64'>
# NH_AMIN    =                13815 		type: <class 'numpy.int64'>
# NH_ASIAN   =               316694 		type: <class 'numpy.int64'>
# NH_BLACK   =              1674229 		type: <class 'numpy.int64'>
# NH_NHPI    =                 2412 		type: <class 'numpy.int64'>
# NH_OTHER   =                11972 		type: <class 'numpy.int64'>
# NH_WHITE   =              3157958 		type: <class 'numpy.int64'>
# OTHERVAP   =                 6928 		type: <class 'numpy.int64'>
# TOTPOP     =              5773552 		type: <class 'numpy.int64'>
# VAP        =              4420588 		type: <class 'numpy.int64'>
# WVAP       =              2529506 		type: <class 'numpy.int64'>
#
# ---- MI ----
# 2MOREVAP   =    93714.72346323807 		type: <class 'numpy.float64'>
# AMINVAP    =    40068.32061064335 		type: <class 'numpy.float64'>
# ASIANVAP   =   175250.36756005313 		type: <class 'numpy.float64'>
# BVAP       =    998307.4265698013 		type: <class 'numpy.float64'>
# HISP       =    480260.5191083141 		type: <class 'numpy.float64'>
# HVAP       =   264509.88713948074 		type: <class 'numpy.float64'>
# H_AMIN     =    15827.91564024902 		type: <class 'numpy.float64'>
# H_ASIAN    =    4911.986918126602 		type: <class 'numpy.float64'>
# H_BLACK    =   28442.971707537876 		type: <class 'numpy.float64'>
# H_NHPI     =   1430.9953555864945 		type: <class 'numpy.float64'>
# H_OTHER    =   162834.68282201653 		type: <class 'numpy.float64'>
# H_WHITE    =    266811.9666647976 		type: <class 'numpy.float64'>
# NHPIVAP    =   1692.9349915840164 		type: <class 'numpy.float64'>
# NH_AMIN    =   123261.16422943986 		type: <class 'numpy.float64'>
# NH_ASIAN   =   284694.02811046946 		type: <class 'numpy.float64'>
# NH_BLACK   =   1477068.5185150122 		type: <class 'numpy.float64'>
# NH_NHPI    =   7916.9102859384775 		type: <class 'numpy.float64'>
# NH_OTHER   =   18913.935779698528 		type: <class 'numpy.float64'>
# NH_WHITE   =    7740049.871430405 		type: <class 'numpy.float64'>
# OTHERVAP   =    5321.988675813522 		type: <class 'numpy.float64'>
# TOTPOP     =   10132164.947459279 		type: <class 'numpy.float64'>
# VAP        =    7539471.741063415 		type: <class 'numpy.float64'>
# WVAP       =   5960606.0920528015 		type: <class 'numpy.float64'>
#
# ---- MN ----
# # Note: Multiple shapefiles. Using MN16.zip. Shapefile name does not fit convention.
# 2MOREVAP   =              45057.0 		type: <class 'numpy.float64'>
# AMINVAP    =              38010.0 		type: <class 'numpy.float64'>
# ASIANVAP   =             146014.0 		type: <class 'numpy.float64'>
# BVAP       =             174688.0 		type: <class 'numpy.float64'>
# HISP       =             250258.0 		type: <class 'numpy.float64'>
# HVAP       =             148836.0 		type: <class 'numpy.float64'>
# H_2MORE    =              21985.0 		type: <class 'numpy.float64'>
# H_AMIN     =               5495.0 		type: <class 'numpy.float64'>
# H_ASIAN    =               1238.0 		type: <class 'numpy.float64'>
# H_BLACK    =               5271.0 		type: <class 'numpy.float64'>
# H_NHPI     =                296.0 		type: <class 'numpy.float64'>
# H_OTHER    =              97053.0 		type: <class 'numpy.float64'>
# H_WHITE    =             118920.0 		type: <class 'numpy.float64'>
# NHPIVAP    =               1351.0 		type: <class 'numpy.float64'>
# NH_2MORE   =             103160.0 		type: <class 'numpy.float64'>
# NH_AMIN    =              55421.0 		type: <class 'numpy.float64'>
# NH_ASIAN   =             212996.0 		type: <class 'numpy.float64'>
# NH_BLACK   =             269141.0 		type: <class 'numpy.float64'>
# NH_NHPI    =               1860.0 		type: <class 'numpy.float64'>
# NH_OTHER   =               5947.0 		type: <class 'numpy.float64'>
# NH_WHITE   =            4405142.0 		type: <class 'numpy.float64'>
# OTHERVAP   =               3262.0 		type: <class 'numpy.float64'>
# TOTPOP     =            5303925.0 		type: <class 'numpy.float64'>
# VAP        =            4019862.0 		type: <class 'numpy.float64'>
# WVAP       =            3462644.0 		type: <class 'numpy.float64'>
#
# ---- NC ----
# # Note: Multiple shapefiles. Using NC_VTD.zip. Shapefile name does not fit convention.
# 2MOREVAP   =                73634 		type: <class 'numpy.int64'>
# AMINVAP    =                79295 		type: <class 'numpy.int64'>
# ASIANVAP   =               152537 		type: <class 'numpy.int64'>
# BVAP       =              1480769 		type: <class 'numpy.int64'>
# HISP       =               800120 		type: <class 'numpy.int64'>
# HVAP       =               492330 		type: <class 'numpy.int64'>
# H_2MORE    =                50440 		type: <class 'numpy.int64'>
# H_AMIN     =                13281 		type: <class 'numpy.int64'>
# H_ASIAN    =                 2383 		type: <class 'numpy.int64'>
# H_BLACK    =                28774 		type: <class 'numpy.int64'>
# H_NHPI     =                 1345 		type: <class 'numpy.int64'>
# H_OTHER    =               398942 		type: <class 'numpy.int64'>
# H_WHITE    =               304955 		type: <class 'numpy.int64'>
# NHPIVAP    =                 3791 		type: <class 'numpy.int64'>
# NH_2MORE   =               155759 		type: <class 'numpy.int64'>
# NH_AMIN    =               108829 		type: <class 'numpy.int64'>
# NH_ASIAN   =               206579 		type: <class 'numpy.int64'>
# NH_BLACK   =              2019854 		type: <class 'numpy.int64'>
# NH_NHPI    =                 5259 		type: <class 'numpy.int64'>
# NH_OTHER   =                15088 		type: <class 'numpy.int64'>
# NH_WHITE   =              6223995 		type: <class 'numpy.int64'>
# OTHERVAP   =                 7167 		type: <class 'numpy.int64'>
# TOTPOP     =              9535483 		type: <class 'numpy.int64'>
# VAP        =              7253848 		type: <class 'numpy.int64'>
# WVAP       =              4964325 		type: <class 'numpy.int64'>
#
# ---- NM ----
# # Note: Shapefile name does not fit convention.
# 2MOREVAP   =                17342 		type: <class 'numpy.int64'>
# AMINVAP    =               121962 		type: <class 'numpy.int64'>
# ASIANVAP   =                20956 		type: <class 'numpy.int64'>
# BVAP       =                27453 		type: <class 'numpy.int64'>
# HISP       =               953403 		type: <class 'numpy.int64'>
# HVAP       =               651326 		type: <class 'numpy.int64'>
# H_2MORE    =                47175 		type: <class 'numpy.int64'>
# H_AMIN     =                17854 		type: <class 'numpy.int64'>
# H_ASIAN    =                 1903 		type: <class 'numpy.int64'>
# H_BLACK    =                 7088 		type: <class 'numpy.int64'>
# H_NHPI     =                  564 		type: <class 'numpy.int64'>
# H_OTHER    =               304753 		type: <class 'numpy.int64'>
# H_WHITE    =               574066 		type: <class 'numpy.int64'>
# NHPIVAP    =                  987 		type: <class 'numpy.int64'>
# NH_2MORE   =                29835 		type: <class 'numpy.int64'>
# NH_AMIN    =               175368 		type: <class 'numpy.int64'>
# NH_ASIAN   =                26305 		type: <class 'numpy.int64'>
# NH_BLACK   =                35462 		type: <class 'numpy.int64'>
# NH_NHPI    =                 1246 		type: <class 'numpy.int64'>
# NH_OTHER   =                 3750 		type: <class 'numpy.int64'>
# NH_WHITE   =               833810 		type: <class 'numpy.int64'>
# OTHERVAP   =                 2633 		type: <class 'numpy.int64'>
# TOTPOP     =              2059179 		type: <class 'numpy.int64'>
# VAP        =              1540507 		type: <class 'numpy.int64'>
# WVAP       =               697848 		type: <class 'numpy.int64'>
#
# ---- OH ----
# 2MOREVAP   =              92106.0 		type: <class 'numpy.float64'>
# AMINVAP    =              16698.0 		type: <class 'numpy.float64'>
# ASIANVAP   =             145508.0 		type: <class 'numpy.float64'>
# BVAP       =             993016.0 		type: <class 'numpy.float64'>
# HISP       =             354674.0 		type: <class 'numpy.float64'>
# HVAP       =             218924.0 		type: <class 'numpy.float64'>
# H_2MORE    =              34542.0 		type: <class 'numpy.float64'>
# H_AMIN     =               4386.0 		type: <class 'numpy.float64'>
# H_ASIAN    =               1468.0 		type: <class 'numpy.float64'>
# H_BLACK    =              18566.0 		type: <class 'numpy.float64'>
# H_NHPI     =                666.0 		type: <class 'numpy.float64'>
# H_OTHER    =             114872.0 		type: <class 'numpy.float64'>
# H_WHITE    =             180174.0 		type: <class 'numpy.float64'>
# NHPIVAP    =               2389.0 		type: <class 'numpy.float64'>
# NH_2MORE   =             203223.0 		type: <class 'numpy.float64'>
# NH_AMIN    =              20906.0 		type: <class 'numpy.float64'>
# NH_ASIAN   =             190765.0 		type: <class 'numpy.float64'>
# NH_BLACK   =            1389115.0 		type: <class 'numpy.float64'>
# NH_NHPI    =               3400.0 		type: <class 'numpy.float64'>
# NH_OTHER   =              15158.0 		type: <class 'numpy.float64'>
# NH_WHITE   =            9359246.0 		type: <class 'numpy.float64'>
# OTHERVAP   =               6687.0 		type: <class 'numpy.float64'>
# TOTPOP     =           11536487.0 		type: <class 'numpy.float64'>
# VAP        =            8805740.0 		type: <class 'numpy.float64'>
# WVAP       =            7330412.0 		type: <class 'numpy.float64'>
#
# ---- OK ----
# 2MOREVAP   =               109872 		type: <class 'numpy.int64'>
# AMINVAP    =               207883 		type: <class 'numpy.int64'>
# ASIANVAP   =                48930 		type: <class 'numpy.int64'>
# BVAP       =               195546 		type: <class 'numpy.int64'>
# HISP       =               332007 		type: <class 'numpy.int64'>
# HVAP       =               199457 		type: <class 'numpy.int64'>
# H_2MORE    =                29247 		type: <class 'numpy.int64'>
# H_AMIN     =                12954 		type: <class 'numpy.int64'>
# H_ASIAN    =                  922 		type: <class 'numpy.int64'>
# H_BLACK    =                 5573 		type: <class 'numpy.int64'>
# H_NHPI     =                  392 		type: <class 'numpy.int64'>
# H_OTHER    =               151455 		type: <class 'numpy.int64'>
# H_WHITE    =               131464 		type: <class 'numpy.int64'>
# NHPIVAP    =                 2701 		type: <class 'numpy.int64'>
# NH_2MORE   =               192074 		type: <class 'numpy.int64'>
# NH_AMIN    =               308733 		type: <class 'numpy.int64'>
# NH_ASIAN   =                64154 		type: <class 'numpy.int64'>
# NH_BLACK   =               272071 		type: <class 'numpy.int64'>
# NH_NHPI    =                 3977 		type: <class 'numpy.int64'>
# NH_OTHER   =                 2954 		type: <class 'numpy.int64'>
# NH_WHITE   =              2575381 		type: <class 'numpy.int64'>
# OTHERVAP   =                 1792 		type: <class 'numpy.int64'>
# TOTPOP     =              3751351 		type: <class 'numpy.int64'>
# VAP        =              2821685 		type: <class 'numpy.int64'>
# WVAP       =              2055504 		type: <class 'numpy.int64'>
#
# ---- OR ----
# 2MOREVAP   =                61774 		type: <class 'numpy.int64'>
# AMINVAP    =                31264 		type: <class 'numpy.int64'>
# ASIANVAP   =               107626 		type: <class 'numpy.int64'>
# BVAP       =                46424 		type: <class 'numpy.int64'>
# HISP       =               449417 		type: <class 'numpy.int64'>
# HVAP       =               269102 		type: <class 'numpy.int64'>
# H_2MORE    =                34334 		type: <class 'numpy.int64'>
# H_AMIN     =                10058 		type: <class 'numpy.int64'>
# H_ASIAN    =                 1590 		type: <class 'numpy.int64'>
# H_BLACK    =                 3939 		type: <class 'numpy.int64'>
# H_NHPI     =                  582 		type: <class 'numpy.int64'>
# H_OTHER    =               198528 		type: <class 'numpy.int64'>
# H_WHITE    =               198134 		type: <class 'numpy.int64'>
# NHPIVAP    =                 8398 		type: <class 'numpy.int64'>
# NH_2MORE   =               109205 		type: <class 'numpy.int64'>
# NH_AMIN    =                42093 		type: <class 'numpy.int64'>
# NH_ASIAN   =               138838 		type: <class 'numpy.int64'>
# NH_BLACK   =                64442 		type: <class 'numpy.int64'>
# NH_NHPI    =                12278 		type: <class 'numpy.int64'>
# NH_OTHER   =                 5117 		type: <class 'numpy.int64'>
# NH_WHITE   =              3005164 		type: <class 'numpy.int64'>
# OTHERVAP   =                 3414 		type: <class 'numpy.int64'>
# TOTPOP     =              3830404 		type: <class 'numpy.int64'>
# VAP        =              2963948 		type: <class 'numpy.int64'>
# WVAP       =              2432193 		type: <class 'numpy.int64'>
#
# ---- PA ----
# # Note: Shapefile uses VTDs. Shapefile name does not fit convention.
# 2MOREVAP   =                86330 		type: <class 'numpy.int64'>
# AMINVAP    =                13163 		type: <class 'numpy.int64'>
# ASIANVAP   =               264676 		type: <class 'numpy.int64'>
# BVAP       =               963866 		type: <class 'numpy.int64'>
# HISP       =               719660 		type: <class 'numpy.int64'>
# HVAP       =               459421 		type: <class 'numpy.int64'>
# H_2MORE    =                59240 		type: <class 'numpy.int64'>
# H_AMIN     =                 9934 		type: <class 'numpy.int64'>
# H_ASIAN    =                 2800 		type: <class 'numpy.int64'>
# H_BLACK    =                50598 		type: <class 'numpy.int64'>
# H_NHPI     =                  938 		type: <class 'numpy.int64'>
# H_OTHER    =               284514 		type: <class 'numpy.int64'>
# H_WHITE    =               311636 		type: <class 'numpy.int64'>
# NHPIVAP    =                 2109 		type: <class 'numpy.int64'>
# NH_2MORE   =               178595 		type: <class 'numpy.int64'>
# NH_AMIN    =                16909 		type: <class 'numpy.int64'>
# NH_ASIAN   =               346288 		type: <class 'numpy.int64'>
# NH_BLACK   =              1327091 		type: <class 'numpy.int64'>
# NH_NHPI    =                 2715 		type: <class 'numpy.int64'>
# NH_OTHER   =                16469 		type: <class 'numpy.int64'>
# NH_WHITE   =             10094652 		type: <class 'numpy.int64'>
# OTHERVAP   =                 9383 		type: <class 'numpy.int64'>
# TOTPOP     =             12702379 		type: <class 'numpy.int64'>
# VAP        =              9910224 		type: <class 'numpy.int64'>
# WVAP       =              8111276 		type: <class 'numpy.int64'>
#
# ---- RI ----
# 2MOREVAP   =    13011.17722168194 		type: <class 'numpy.float64'>
# AMINVAP    =    2931.399784622033 		type: <class 'numpy.float64'>
# ASIANVAP   =    23245.95323196268 		type: <class 'numpy.float64'>
# BVAP       =    37199.94461714463 		type: <class 'numpy.float64'>
# HISP       =    130629.6035580843 		type: <class 'numpy.float64'>
# HVAP       =    84695.28658067863 		type: <class 'numpy.float64'>
# NHPIVAP    =   239.99444642785977 		type: <class 'numpy.float64'>
# NH_2MORE   =    23469.29549543841 		type: <class 'numpy.float64'>
# NH_AMIN    =   4018.2403668531406 		type: <class 'numpy.float64'>
# NH_ASIAN   =    29975.72045378507 		type: <class 'numpy.float64'>
# NH_BLACK   =    51531.29436098998 		type: <class 'numpy.float64'>
# NH_NHPI    =   304.99444642785863 		type: <class 'numpy.float64'>
# NH_OTHER   =     8871.84181898511 		type: <class 'numpy.float64'>
# NH_WHITE   =    803157.9016378372 		type: <class 'numpy.float64'>
# OTHERVAP   =    6398.007466156627 		type: <class 'numpy.float64'>
# TOTPOP     =    1051958.892138401 		type: <class 'numpy.float64'>
# VAP        =    828092.7366311187 		type: <class 'numpy.float64'>
# WVAP       =    660370.9732824443 		type: <class 'numpy.float64'>
#
# ---- TX ----
# # Note: Shapefile stored externally (MIT). Shapefile name does not fit convention.
# BVAP       =            2196259.0 		type: <class 'numpy.float64'>
# TOTPOP     =           25145561.0 		type: <class 'numpy.float64'>
# VAP        =           18279737.0 		type: <class 'numpy.float64'>
# WVAP       =            9074684.0 		type: <class 'numpy.float64'>
#
# ---- UT ----
# 2MOREVAP   =    21189.18896737852 		type: <class 'numpy.float64'>
# AMINVAP    =   18438.133814532852 		type: <class 'numpy.float64'>
# ASIANVAP   =    41754.92557225698 		type: <class 'numpy.float64'>
# BVAP       =   16410.043896447125 		type: <class 'numpy.float64'>
# HISP       =   358356.55772402906 		type: <class 'numpy.float64'>
# HVAP       =   214504.29287178727 		type: <class 'numpy.float64'>
# H_2MORE    =   26533.750837595224 		type: <class 'numpy.float64'>
# H_AMIN     =    5846.656119573669 		type: <class 'numpy.float64'>
# H_ASIAN    =   1109.1461464514878 		type: <class 'numpy.float64'>
# H_BLACK    =   3336.6985082202473 		type: <class 'numpy.float64'>
# H_NHPI     =    645.0178684517828 		type: <class 'numpy.float64'>
# H_OTHER    =   163039.03419464125 		type: <class 'numpy.float64'>
# H_WHITE    =   157846.25404909538 		type: <class 'numpy.float64'>
# NHPIVAP    =   14720.527132470428 		type: <class 'numpy.float64'>
# NH_2MORE   =   48987.908761684506 		type: <class 'numpy.float64'>
# NH_AMIN    =   27081.391867138034 		type: <class 'numpy.float64'>
# NH_ASIAN   =    54168.71485922523 		type: <class 'numpy.float64'>
# NH_BLACK   =     25956.0889830315 		type: <class 'numpy.float64'>
# NH_NHPI    =    23911.09945662714 		type: <class 'numpy.float64'>
# NH_OTHER   =    3724.905305604757 		type: <class 'numpy.float64'>
# NH_WHITE   =   2221869.3897179104 		type: <class 'numpy.float64'>
# OTHERVAP   =     2286.33977838555 		type: <class 'numpy.float64'>
# TOTPOP     =    2764056.056675251 		type: <class 'numpy.float64'>
# VAP        =    1892986.705672805 		type: <class 'numpy.float64'>
# WVAP       =   1563683.2536395462 		type: <class 'numpy.float64'>
#
# ---- VA ----
# 2MOREVAP   =    89985.99999504918 		type: <class 'numpy.float64'>
# AMINVAP    =   16172.999999547643 		type: <class 'numpy.float64'>
# ASIANVAP   =    334139.9999938982 		type: <class 'numpy.float64'>
# BVAP       =    1135014.999981714 		type: <class 'numpy.float64'>
# HISP       =     631824.999991347 		type: <class 'numpy.float64'>
# HVAP       =    426856.9999939167 		type: <class 'numpy.float64'>
# H_2MORE    =    51730.99999953982 		type: <class 'numpy.float64'>
# H_ASIAN    =    3591.999999943414 		type: <class 'numpy.float64'>
# H_BLACK    =   27694.999999939344 		type: <class 'numpy.float64'>
# H_NHPI     =    918.9999999900004 		type: <class 'numpy.float64'>
# H_OTHER    =   238939.99999746715 		type: <class 'numpy.float64'>
# H_WHITE    =   300401.99999452854 		type: <class 'numpy.float64'>
# NHPIVAP    =   3957.9999998971916 		type: <class 'numpy.float64'>
# NH_2MORE   =    181668.9999917023 		type: <class 'numpy.float64'>
# NH_AMIN    =    20678.99999944322 		type: <class 'numpy.float64'>
# NH_ASIAN   =   436297.99999203143 		type: <class 'numpy.float64'>
# NH_BLACK   =   1523703.9999780415 		type: <class 'numpy.float64'>
# NH_NHPI    =    5060.999999884956 		type: <class 'numpy.float64'>
# NH_OTHER   =    15337.99999950733 		type: <class 'numpy.float64'>
# NH_WHITE   =    5186449.999617692 		type: <class 'numpy.float64'>
# OTHERVAP   =    7832.999999664129 		type: <class 'numpy.float64'>
# TOTPOP     =    8001023.999569651 		type: <class 'numpy.float64'>
# VAP        =    6147346.999654168 		type: <class 'numpy.float64'>
# WVAP       =   4133384.9996904815 		type: <class 'numpy.float64'>
#
# ---- VT ----
# # Note: Uses towns as counting unit. Shapefile name does not fit convention.
# HISP       =                 9205 		type: <class 'numpy.int64'>
# TOTPOP     =               625640 		type: <class 'numpy.int64'>
# VAP        =               496422 		type: <class 'numpy.int64'>
#
# ---- WI ----
# # Note: Shapefile name does not fit convention.

# %% [markdown]
# ## Clean Directory

# %%
#!echo y | rm -r ./*-shapefiles/
dataqa.remove_repos('shps/')
