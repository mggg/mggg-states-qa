# %% [markdown]
# Data QA Case: ``mggg-states``
# ========================
#
# Below are the steps involved in performing automated data quality checks on ``mggg-states`` data.
#
# *Note:* the automated checks are not completely exhaustive and further manual checks are required.
#
# Step 0. Setup
# ----------------

# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install geopandas
# !pip3 install wikipedia

# !pip3 install git+https://github.com/KeiferC/gdutils.git

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import json
import wikipedia
import os

import gdutils.datamine as dm
import gdutils.dataqa as dq
import gdutils.extract as et

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Step 1. Data collection
# ---------------------------

# %% [markdown]
# __Step 1.1.__ Gather ``mggg-states`` data

# %%
# dm.clone_gh_repos(account='mggg-states', account_type='orgs', outpath=os.path.join('qafiles', 'mggg'))
#     # this will take some time to complete

# %%
mggg_gdfs = {}

for filepath in dm.list_files_of_type('.zip', os.path.join('qafiles', 'mggg')):
      mggg_gdfs[os.path.basename(filepath)[:-4]] = et.read_file(filepath).extract()

# %% [markdown]
# __Step 1.2.__ Gather MEDSL data for comparison purposes

# %%
print('{:27} : {}'.format('Repo Name', 'Repo URL'))
print('------------------------------------------------------------------')
for (repo, url) in dm.list_gh_repos(account='MEDSL', account_type='orgs'):
    print("{:27} : {}".format(repo, url))
# Out:
# Repo Name                   : Repo URL
# ------------------------------------------------------------------
# elections                   : https://github.com/MEDSL/elections.git
# official-precinct-returns   : https://github.com/MEDSL/official-precinct-returns.git
# primaries                   : https://github.com/MEDSL/primaries.git
# data-management             : https://github.com/MEDSL/data-management.git
# election-scrapers           : https://github.com/MEDSL/election-scrapers.git
# medslcleaner                : https://github.com/MEDSL/medslcleaner.git
# precinct-shapefiles         : https://github.com/MEDSL/precinct-shapefiles.git
# documentation               : https://github.com/MEDSL/documentation.git
# elections-performance-index : https://github.com/MEDSL/elections-performance-index.git
# constituency-returns        : https://github.com/MEDSL/constituency-returns.git
# state-returns               : https://github.com/MEDSL/state-returns.git
# county-returns              : https://github.com/MEDSL/county-returns.git
# 2018-elections-unoffical    : https://github.com/MEDSL/2018-elections-unoffical.git
# 2018-elections-official     : https://github.com/MEDSL/2018-elections-official.git
# Medium                      : https://github.com/MEDSL/Medium.git
# ggmedsl                     : https://github.com/MEDSL/ggmedsl.git
# resources                   : https://github.com/MEDSL/resources.git
# election-data               : https://github.com/MEDSL/election-data.git
# 2019-elections-unofficial   : https://github.com/MEDSL/2019-elections-unofficial.git
# primary-precinct-returns    : https://github.com/MEDSL/primary-precinct-returns.git
# 2020-primaries-unofficial   : https://github.com/MEDSL/2020-primaries-unofficial.git
# 2020-Primaries-Official     : https://github.com/MEDSL/2020-Primaries-Official.git
# healthy_elections           : https://github.com/MEDSL/healthy_elections.git

# %%
medsl_repos = ['official-precinct-returns', # precinct-level 2016 election results
               '2018-elections-official'] # constituency-level 2018 election results
    
# dm.clone_gh_repos(account='MEDSL', account_type='orgs', repos=medsl_repos, outpath=os.path.join('qafiles', 'medsl'))
#     # this will take some time to complete

# %%
medsl_dfs = {}

# Note: will likely throw warnings because MEDSL data contains multiple datatypes in some columns
for filepath in dm.list_files_of_type('.zip', os.path.join('qafiles', 'medsl')):
    medsl_dfs[os.path.basename(filepath)[:-4]] = et.read_file(filepath).extract()

# %% [markdown]
# __Step 1.3.__ Gather Wikipedia data for comparison purposes

# %%
# Generate wikipedia page titles
states = ['Alabama', 'Alaska','Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 
          'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 
          'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 
          'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 
          'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 
          'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 
          'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

wiki_pres_elections = ['United States presidential election']
wiki_fed_elections  = ['United States Senate election']
                      #'United States House of Representatives election']
election_years_to_check = [2016, 2018]

wiki_titles = []
for yr in election_years_to_check:
    generate_title = lambda yr, etype: str(yr) + ' ' + etype 
    
    if yr % 4 == 0:
        wiki_titles.append(generate_title(yr, wiki_pres_elections[0]))
        
    [wiki_titles.append(generate_title(yr, etype) + ' in ' + st) 
         for etype in wiki_fed_elections
         for st in states]

# %%
# Gather wikipedia page URLs
wiki_urls = {}
for page_title in wiki_titles:
    try:
        wiki_urls[page_title] = wikipedia.page(title=page_title).url
    except Exception as e:
        continue

# %%
# Print retrieved page URLs
for wiki in wiki_urls:
    print('{:65}\n\t{}'.format(wiki, wiki_urls[wiki]))

# %%
# Gather wikipedia tabular election results
wiki_tables = {}
for wiki in wiki_urls:
    try:
        wiki_tables[wiki] = pd.read_html(wiki_urls[wiki])
    except Exception as e:
        print("Unable to gather Wikipedia tabular data:", e)
# Out:
# Unable to gather Wikipedia tabular data: invalid literal for int() with base 10: '{{{vp_count}}}'

# %%
# Display wikipedia tabular election data
for wiki in wiki_tables:
    print('================================================')
    print('Wiki: {} '.format(wiki))
    print('================================================')
    
    for i in range(len(wiki_tables[wiki])):
        print('TABLE {}: ############################\n{}\n\n\n'.format(i, wiki_tables[wiki][i].head()))

# %%
# Manually gather found tabular election results

# Generate shorthand keys for wikipedia tabular data
pres_election_short = ['PRES']
fed_elections_short = ['SEN'] # , 'USH']
st_abvs = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 
           'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 
           'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

wiki_titles_short = []
for yr in election_years_to_check:
    generate_title = lambda st_abv, yr, etype: etype + str(yr % 100) + '_' + st_abv
    
    if yr % 4 == 0:
        [wiki_titles_short.append(generate_title(abv, yr, pres_election_short[0])) 
            for abv in st_abvs]
        
    [wiki_titles_short.append(generate_title(abv, yr, etype)) 
         for etype in fed_elections_short
         for abv in st_abvs]

# %%
wiki_dfs = {}

# wiki_pres16_by_state = [{state_abv : table} for _______] # TODO

# has to be done manually because every wikipedia page is different

# wiki_dfs['PRES16_AL'] = wiki_pres16_by_state['AL']
# wiki_dfs['PRES16_AK'] = wiki_pres16_by_state['AK']
# wiki_dfs['PRES16_AZ'] = wiki_pres16_by_state['AZ']
# wiki_dfs['PRES16_AR'] = wiki_pres16_by_state['AR']
# wiki_dfs['PRES16_CA'] = wiki_pres16_by_state['CA']
# wiki_dfs['PRES16_CO'] = wiki_pres16_by_state['CO']
# wiki_dfs['PRES16_CT'] = wiki_pres16_by_state['CT']
# wiki_dfs['PRES16_DE'] = wiki_pres16_by_state['DE']
# wiki_dfs['PRES16_FL'] = wiki_pres16_by_state['FL']
# wiki_dfs['PRES16_GA'] = wiki_pres16_by_state['GA']
# wiki_dfs['PRES16_HI'] = wiki_pres16_by_state['HI']
# wiki_dfs['PRES16_ID'] = wiki_pres16_by_state['ID']
# wiki_dfs['PRES16_IL'] = wiki_pres16_by_state['IL']
# wiki_dfs['PRES16_IN'] = wiki_pres16_by_state['IN']
# wiki_dfs['PRES16_IA'] = wiki_pres16_by_state['IA']
# wiki_dfs['PRES16_KS'] = wiki_pres16_by_state['KS']
# wiki_dfs['PRES16_KY'] = wiki_pres16_by_state['KY']
# wiki_dfs['PRES16_LA'] = wiki_pres16_by_state['LA']
# wiki_dfs['PRES16_ME'] = wiki_pres16_by_state['ME']
# wiki_dfs['PRES16_MD'] = wiki_pres16_by_state['MD']
# wiki_dfs['PRES16_MA'] = wiki_pres16_by_state['MA']
# wiki_dfs['PRES16_MI'] = wiki_pres16_by_state['MI']
# wiki_dfs['PRES16_MN'] = wiki_pres16_by_state['MN']
# wiki_dfs['PRES16_MS'] = wiki_pres16_by_state['MS']
# wiki_dfs['PRES16_MO'] = wiki_pres16_by_state['MO']
# wiki_dfs['PRES16_MT'] = wiki_pres16_by_state['MT']
# wiki_dfs['PRES16_NE'] = wiki_pres16_by_state['NE']
# wiki_dfs['PRES16_NV'] = wiki_pres16_by_state['NV']
# wiki_dfs['PRES16_NH'] = wiki_pres16_by_state['NH']
# wiki_dfs['PRES16_NJ'] = wiki_pres16_by_state['NJ']
# wiki_dfs['PRES16_NM'] = wiki_pres16_by_state['NM']
# wiki_dfs['PRES16_NY'] = wiki_pres16_by_state['NY']
# wiki_dfs['PRES16_NC'] = wiki_pres16_by_state['NC']
# wiki_dfs['PRES16_ND'] = wiki_pres16_by_state['ND']
# wiki_dfs['PRES16_OH'] = wiki_pres16_by_state['OH']
# wiki_dfs['PRES16_OK'] = wiki_pres16_by_state['OK']
# wiki_dfs['PRES16_OR'] = wiki_pres16_by_state['OR']
# wiki_dfs['PRES16_PA'] = wiki_pres16_by_state['PA']
# wiki_dfs['PRES16_RI'] = wiki_pres16_by_state['RI']
# wiki_dfs['PRES16_SC'] = wiki_pres16_by_state['SC']
# wiki_dfs['PRES16_SD'] = wiki_pres16_by_state['SD']
# wiki_dfs['PRES16_TN'] = wiki_pres16_by_state['TN']
# wiki_dfs['PRES16_TX'] = wiki_pres16_by_state['TX']
# wiki_dfs['PRES16_UT'] = wiki_pres16_by_state['UT']
# wiki_dfs['PRES16_VT'] = wiki_pres16_by_state['VT']
# wiki_dfs['PRES16_VA'] = wiki_pres16_by_state['VA']
# wiki_dfs['PRES16_WA'] = wiki_pres16_by_state['WA']
# wiki_dfs['PRES16_WV'] = wiki_pres16_by_state['WV']
# wiki_dfs['PRES16_WI'] = wiki_pres16_by_state['WI']
# wiki_dfs['PRES16_WY'] = wiki_pres16_by_state['WY']

wiki_dfs['SEN16_AL'] = wiki_tables['2016 United States Senate election in Alabama'][19]
wiki_dfs['SEN16_AK'] = wiki_tables['2016 United States Senate election in Alaska'][20]
wiki_dfs['SEN16_AZ'] = wiki_tables['2016 United States Senate election in Arizona'][40]
# wiki_dfs['SEN16_AR'] =
# wiki_dfs['SEN16_CA'] =
# wiki_dfs['SEN16_CO'] = 
# wiki_dfs['SEN16_CT'] = 
# wiki_dfs['SEN16_DE'] = 
# wiki_dfs['SEN16_FL'] = 
# wiki_dfs['SEN16_GA'] = 
# wiki_dfs['SEN16_HI'] = 
# wiki_dfs['SEN16_ID'] = 
# wiki_dfs['SEN16_IL'] = 
# wiki_dfs['SEN16_IN'] = 
# wiki_dfs['SEN16_IA'] = 
# wiki_dfs['SEN16_KS'] = 
# wiki_dfs['SEN16_KY'] = 
# wiki_dfs['SEN16_LA'] = 
# wiki_dfs['SEN16_ME'] = 
# wiki_dfs['SEN16_MD'] = 
# wiki_dfs['SEN16_MA'] = 
# wiki_dfs['SEN16_MI'] = 
# wiki_dfs['SEN16_MN'] = 
# wiki_dfs['SEN16_MS'] = 
# wiki_dfs['SEN16_MO'] = 
# wiki_dfs['SEN16_MT'] = 
# wiki_dfs['SEN16_NE'] = 
# wiki_dfs['SEN16_NV'] = 
# wiki_dfs['SEN16_NH'] = 
# wiki_dfs['SEN16_NJ'] = 
# wiki_dfs['SEN16_NM'] = 
# wiki_dfs['SEN16_NY'] = 
# wiki_dfs['SEN16_NC'] = 
# wiki_dfs['SEN16_ND'] = 
# wiki_dfs['SEN16_OH'] = 
# wiki_dfs['SEN16_OK'] = 
# wiki_dfs['SEN16_OR'] = 
# wiki_dfs['SEN16_PA'] = 
# wiki_dfs['SEN16_RI'] = 
# wiki_dfs['SEN16_SC'] = 
# wiki_dfs['SEN16_SD'] = 
# wiki_dfs['SEN16_TN'] = 
# wiki_dfs['SEN16_TX'] = 
# wiki_dfs['SEN16_UT'] = 
# wiki_dfs['SEN16_VT'] = 
# wiki_dfs['SEN16_VA'] = 
# wiki_dfs['SEN16_WA'] = 
# wiki_dfs['SEN16_WV'] = 
# wiki_dfs['SEN16_WI'] = 
# wiki_dfs['SEN16_WY'] = 

wiki_dfs['SEN18_AZ'] = wiki_tables['2018 United States Senate election in Arizona'][40]
# wiki_dfs['SEN18_AR'] = 
# wiki_dfs['SEN18_CA'] = 
# wiki_dfs['SEN18_CO'] = 
# wiki_dfs['SEN18_CT'] = 
# wiki_dfs['SEN18_DE'] = 
# wiki_dfs['SEN18_FL'] = 
# wiki_dfs['SEN18_GA'] = 
# wiki_dfs['SEN18_HI'] = 
# wiki_dfs['SEN18_ID'] = 
# wiki_dfs['SEN18_IL'] = 
# wiki_dfs['SEN18_IN'] = 
# wiki_dfs['SEN18_IA'] = 
# wiki_dfs['SEN18_KS'] = 
# wiki_dfs['SEN18_KY'] = 
# wiki_dfs['SEN18_LA'] = 
# wiki_dfs['SEN18_ME'] = 
# wiki_dfs['SEN18_MD'] = 
# wiki_dfs['SEN18_MA'] = 
# wiki_dfs['SEN18_MI'] = 
# wiki_dfs['SEN18_MN'] = 
# wiki_dfs['SEN18_MS'] = 
# wiki_dfs['SEN18_MO'] = 
# wiki_dfs['SEN18_MT'] = 
# wiki_dfs['SEN18_NE'] = 
# wiki_dfs['SEN18_NV'] = 
# wiki_dfs['SEN18_NH'] = 
# wiki_dfs['SEN18_NJ'] = 
# wiki_dfs['SEN18_NM'] = 
# wiki_dfs['SEN18_NY'] = 
# wiki_dfs['SEN18_NC'] = 
# wiki_dfs['SEN18_ND'] = 
# wiki_dfs['SEN18_OH'] = 
# wiki_dfs['SEN18_OK'] = 
# wiki_dfs['SEN18_OR'] = 
# wiki_dfs['SEN18_PA'] = 
# wiki_dfs['SEN18_RI'] = 
# wiki_dfs['SEN18_SC'] = 
# wiki_dfs['SEN18_SD'] = 
# wiki_dfs['SEN18_TN'] = 
# wiki_dfs['SEN18_TX'] = 
# wiki_dfs['SEN18_UT'] = 
# wiki_dfs['SEN18_VT'] = 
# wiki_dfs['SEN18_VA'] = 
# wiki_dfs['SEN18_WA'] = 
# wiki_dfs['SEN18_WV'] = 
# wiki_dfs['SEN18_WI'] = 
# wiki_dfs['SEN18_WY'] =

# %% [markdown]
# [Coming Soon] __Step 1.4.__ Gather Ballotpedia data for comparison purposes
#
# *Note:* Depending on response to API access, this step may need to be done manually

# %% [markdown]
# Step 2. Data wrangling
# ---------------------------

# %% [markdown]
# __Step 2.1.__ Wrangle MEDSL data

# %%
def pivot_medsl(medsl_dfs_dict):
    for df in medsl_dfs_dict:
        medsl_pvt = medsl_dfs_dict[df].pivot_table(index='precinct',
                                                   columns=['office', 'party'],
                                                   values='votes')
        medsl_pvt.columns = [' '.join(col).strip() for col in medsl_pvt.columns.values]
        medsl_dfs_dict[df] = et.ExtractTable(medsl_pvt).extract()

# %%
# View available data
for df in medsl_dfs:
    print('--------{}--------'.format(df))
    print(medsl_dfs[df].head())

# %%
# Extract relevant election data
medsl_18_dfs = {}
medsl_pres16_dfs = {}
medsl_sen16_dfs = {}
medsl_ush16_dfs = {}

for st in states:
    try:
        medsl_18_dfs[st] = et.ExtractTable(medsl_dfs['precinct_2018'], column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_18:', e)
    
    try:
        medsl_pres16_dfs[st] = et.ExtractTable(medsl_dfs['2016-precinct-president'], 
                                               column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_pres16:', e)
    
    try:
        medsl_sen16_dfs[st] = et.ExtractTable(medsl_dfs['2016-precinct-senate'], 
                                               column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_sen16:', e)
    
    try:
        medsl_ush16_dfs[st] = et.ExtractTable(medsl_dfs['2016-precinct-house'], 
                                               column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_ush16:', e)

        
pivot_medsl(medsl_18_dfs)
pivot_medsl(medsl_pres16_dfs)
pivot_medsl(medsl_sen16_dfs)
pivot_medsl(medsl_ush16_dfs)

# %% [markdown]
# Step 3. Data standardization check of ``mggg-states``
# ---------------------------------------------------------------

# %% [markdown]
# __Step 3.1__ Generate naming conventions

# %%
with open('naming_convention.json') as json_file:
    standards_raw = json.load(json_file)
    
offices = dm.get_keys_by_category(standards_raw, 'offices')
parties = dm.get_keys_by_category(standards_raw, 'parties')
counts = dm.get_keys_by_category(standards_raw, 'counts')
others = dm.get_keys_by_category(standards_raw, 
            ['geographies', 'demographics', 'districts', 'other'])

elections = [office + format(year, '02') + party 
                 for office in offices
                 for year in range(0, 21)
                 for party in parties 
                 if not (office == 'PRES' and year % 4 != 0)]

counts = [count + format(year, '02') for count in counts 
                                     for year in range(0, 20)]

standards = elections + counts + others

# %% [markdown]
# __Step 3.2.__ Check ``mggg-states`` data compliance with naming conventions

# %%
naming_check = {}

for gdf in mggg_gdfs:
      naming_check[gdf] = dq.compare_column_names(mggg_gdfs[gdf], standards)

# %%
matched_columns = {}

# Print results
for gdf in naming_check:
    print('=========================================')
    print('Dataset: {}'.format(gdf))
    print('=========================================')
    
    (matches, diffs) = naming_check[gdf]
    matched_columns[gdf] = matches
    
    diffs = list(diffs)
    diffs.sort()
    
    print('Discrepancies from naming convention:')
    print(diffs)
    print()
# Out:
# =========================================
# Dataset: MN12
# =========================================
# Discrepancies from naming convention:
# ['CA1NO12', 'CA1YES12', 'CA2NO12', 'CA2YES12', 'CONGDIST', 'COUNTYFIPS', 'COUNTYNAME', 'CTU_TYPE', 'CTYCOMDIST', 'JUDDIST', 'MCDCODE', 'MCDNAME', 'MNLEGDIST', 'MNSENDIST', 'PCTCODE', 'PCTNAME', 'VTD']
#
# =========================================
# Dataset: MN16
# =========================================
# Discrepancies from naming convention:
# ['CONGDIST', 'COUNTYFIPS', 'COUNTYNAME', 'CTU_TYPE', 'CTYCOMDIST', 'JUDDIST', 'MCDCODE', 'MCDNAME', 'MNLEGDIST', 'MNSENDIST', 'PCTCODE', 'PCTNAME', 'VTDID']
#
# =========================================
# Dataset: MN14
# =========================================
# Discrepancies from naming convention:
# ['AG14LM', 'AUD14LC', 'CONGDIST', 'COUNTYFIPS', 'COUNTYNAME', 'CTU_TYPE', 'CTYCOMDIST', 'JUDDIST', 'MCDCODE', 'MCDNAME', 'MNLEGDIST', 'MNSENDIST', 'PCTCODE', 'PCTNAME', 'VTDID']
#
# =========================================
# Dataset: MN12_18
# =========================================
# Discrepancies from naming convention:
# ['AG14LM', 'AG18LC', 'AUD14LC', 'AUD18LM', 'CA1NO12', 'CA1YES12', 'CA2NO12', 'CA2YES12', 'CONGDIST', 'COUNTYFIPS', 'COUNTYNAME', 'CTU_TYPE', 'CTYCOMDIST', 'GOV18LC', 'JUDDIST', 'MCDCODE', 'MCDNAME', 'MNLEGDIST', 'MNSENDIST', 'PCTCODE', 'PCTNAME', 'SEN18LM', 'SP_SEN18D', 'SP_SEN18LM', 'SP_SEN18R', 'VTDID']
#
# =========================================
# Dataset: MN_16
# =========================================
# Discrepancies from naming convention:
# ['CONGDIST', 'COUNTYCODE', 'COUNTYFIPS', 'COUNTYNAME', 'MCDNAME', 'MNLEGDFL', 'MNLEGDIST', 'MNLEGGP', 'MNLEGIPL', 'MNLEGLIB', 'MNLEGR', 'MNLEGTOTAL', 'MNLEGWI', 'MNSENDFL', 'MNSENDIST', 'MNSENIP', 'MNSENLIB', 'MNSENLMN', 'MNSENR', 'MNSENTOTAL', 'MNSENWI', 'PCTCODE', 'PCTNAME', 'SHORTLABEL', 'USPRSADP', 'USPRSCP', 'USPRSDFL', 'USPRSGP', 'USPRSIP', 'USPRSLIB', 'USPRSLMN', 'USPRSR', 'USPRSSWP', 'USPRSTOTAL', 'USPRSWI', 'USREPDFL', 'USREPIP', 'USREPLMN', 'USREPR', 'USREPTOTAL', 'USREPWI', 'VTD']
#
# =========================================
# Dataset: MN_14
# =========================================
# Discrepancies from naming convention:
# ['AB_MB', 'CONGDIST', 'COUNTYCODE', 'COUNTYFIPS', 'COUNTYNAME', 'CTU_TYPE', 'CTYCOMDIST', 'EDR', 'FEDONLYAB', 'HOSPDIST', 'HOSPDIST_N', 'JUDDIST', 'MAILBALLOT', 'MCDCODE', 'MCDFIPS', 'MCDGNIS', 'MCDNAME', 'MNAGDFL', 'MNAGGP', 'MNAGIP', 'MNAGLIB', 'MNAGLMN', 'MNAGR', 'MNAGTOTAL', 'MNAGWI', 'MNAUDDFL', 'MNAUDGLC', 'MNAUDIP', 'MNAUDLIB', 'MNAUDR', 'MNAUDTOTAL', 'MNAUDWI', 'MNGOVDFL', 'MNGOVGLC', 'MNGOVIP', 'MNGOVLIB', 'MNGOVR', 'MNGOVTOTAL', 'MNGOVWI', 'MNLEGDFL', 'MNLEGDIST', 'MNLEGIP', 'MNLEGR', 'MNLEGTOTAL', 'MNLEGWI', 'MNSENDIST', 'MNSOSDFL', 'MNSOSIP', 'MNSOSLIB', 'MNSOSR', 'MNSOSTOTAL', 'MNSOSWI', 'OBJECTID_1', 'PARKDIST', 'PARKDIST_N', 'PCTCODE', 'PCTNAME', 'REG7AM', 'SHORTLABEL', 'SIGNATURES', 'SWCDIST', 'SWCDIST_N', 'Shape_Area', 'Shape_Leng', 'TABMODEL', 'TABSYSTEM', 'TOTVOTING', 'USREPDFL', 'USREPIP', 'USREPR', 'USREPTOTAL', 'USREPWI', 'USSENDFL', 'USSENIP', 'USSENLIB', 'USSENR', 'USSENTOTAL', 'USSENWI', 'VTD', 'VTDID', 'WARD']
#
# =========================================
# Dataset: MN_10
# =========================================
# Discrepancies from naming convention:
# ['ATGENDFL', 'ATGENIP', 'ATGENR', 'ATGENTOT', 'ATGENTRP', 'ATGENWI', 'CNG', 'COM', 'CONGDFL', 'CONGIP', 'CONGR', 'CONGTOT', 'CONGWI', 'COUNTYCODE', 'COUNTY_NAM', 'CTU_Code', 'County', 'DISTRICT', 'EDR', 'EQUIPMODEL', 'FEDAB', 'GOVDFL', 'GOVEDP', 'GOVGP', 'GOVGR', 'GOVIP', 'GOVR', 'GOVTOT', 'GOVTRP', 'GOVWI', 'JUD', 'LEG', 'LongLabel', 'MCD', 'MNLEGDFL', 'MNLEGIP', 'MNLEGR', 'MNLEGTOT', 'MNLEGWI', 'MNSENDFL', 'MNSENIP', 'MNSENR', 'MNSENTOT', 'MNSENWI', 'Number_', 'PRESAB', 'Precinct', 'Precinct_N', 'REGAB', 'SEN', 'SIGNATURES', 'SOSDFL', 'SOSIP', 'SOSR', 'SOSTOT', 'SOSWI', 'STAUDDFL', 'STAUDGP', 'STAUDGR', 'STAUDR', 'STAUDTOT', 'STAUDWI', 'Shape_Area', 'Shape_Leng', 'ShortLabel', 'TOTALVOTER', 'VOTINGSYST', 'VR_MCD', 'VSCODE', 'WD', 'X7AM']
#
# =========================================
# Dataset: MN_12
# =========================================
# Discrepancies from naming convention:
# ['CONGDIST', 'COUNTYCODE', 'COUNTYFIPS', 'COUNTYNAME', 'CTYCOMDIST', 'EDR', 'FEDONLYAB', 'HOSPDIST', 'JUDDIST', 'MAILBALLOT', 'MCDNAME', 'MNCA1EST', 'MNCA1NO', 'MNCA1TOTAL', 'MNCA1YES', 'MNCA2EST', 'MNCA2NO', 'MNCA2TOTAL', 'MNCA2YES', 'MNLEGDFL', 'MNLEGDIST', 'MNLEGIP', 'MNLEGR', 'MNLEGTOTAL', 'MNLEGWI', 'MNSENDFL', 'MNSENDIST', 'MNSENIP', 'MNSENR', 'MNSENTOTAL', 'MNSENWI', 'PARKDIST', 'PCTCODE', 'PCTNAME', 'PRESONLYAB', 'REG7AM', 'REGMILOVAB', 'SHORTLABEL', 'SIGNATURES', 'SWCDIST', 'TABMODEL', 'TABSYSTEM', 'TOTVOTING', 'USPRSCG', 'USPRSCP', 'USPRSDFL', 'USPRSGP', 'USPRSGR', 'USPRSJP', 'USPRSLIB', 'USPRSR', 'USPRSSL', 'USPRSSWP', 'USPRSTOTAL', 'USPRSWI', 'USREPDFL', 'USREPIP', 'USREPR', 'USREPTOTAL', 'USREPWI', 'USSENDFL', 'USSENGR', 'USSENIP', 'USSENMOP', 'USSENR', 'USSENTOTAL', 'USSENWI', 'VTD', 'WARD']
#
# =========================================
# Dataset: MN_08
# =========================================
# Discrepancies from naming convention:
# ['CG', 'CM', 'CNG', 'COM', 'CONGDFL', 'CONGIP', 'CONGR', 'CONGTOT', 'CONGWI', 'COUNTYID', 'CTU_Code', 'County', 'DISTRICT', 'EDR', 'EQUIPMENTM', 'FEDAB', 'FIPS', 'HD', 'JD', 'JUD', 'LEG', 'LEG_1', 'LongLabel', 'MCD', 'MCDNAME', 'MCD_1', 'MNLEGDFL', 'MNLEGIP', 'MNLEGR', 'MNLEGTOT', 'MNLEGWI', 'MNSENDFL', 'MNSENR', 'MNSENTOT', 'MNSENWI', 'Number_', 'OBJECTID', 'OID_', 'PK', 'PRCT', 'PRECINCTID', 'PRECINCT_1', 'PRESAB', 'Precinct', 'Precinct_N', 'REGMILAB', 'SEN', 'SIGNATURES', 'SW', 'Shape_Area', 'Shape_Leng', 'ShortLabel', 'TOTVOTERS', 'USPRESCP', 'USPRESDFL', 'USPRESGP', 'USPRESIND', 'USPRESLIB', 'USPRESR', 'USPRESSWP', 'USPRESTOT', 'USPRESWI', 'USSENCP', 'USSENDFL', 'USSENIP', 'USSENLIB', 'USSENR', 'USSENTOT', 'USSENWI', 'VR_MCD', 'VSCODE', 'WD', 'X7AM']
#
# =========================================
# Dataset: mn_08_16
# =========================================
# Discrepancies from naming convention:
# ['CONGDIST', 'COUNTYCODE', 'COUNTYFIPS', 'COUNTYNAME', 'LEG08D', 'LEG08R', 'LEG10D', 'LEG10R', 'LEG12D', 'LEG12R', 'LEG14D', 'LEG14R', 'LEG16D', 'LEG16R', 'MCDNAME', 'MNLEGDIST', 'MNSENDIST', 'PCTCODE', 'PCTNAME', 'SHORTLABEL', 'VTD']
#
# =========================================
# Dataset: VT_towns
# =========================================
# Discrepancies from naming convention:
# ['2MORE', 'ALAND10', 'AMIN', 'ASIAN', 'AWATER10', 'BLACK', 'COUNTYFP10', 'COUSUBFP10', 'DISTNAME', 'GEOID10', 'INTPTLAT10', 'INTPTLON10', 'NAME10', 'NAMELSAD10', 'NHPI', 'OTHER', 'PRES16B', 'SEN12B', 'SENDIST', 'STATEFP10', 'TOTV12', 'TOTV14', 'TOTV16', 'WHITE']
#
# =========================================
# Dataset: OH_precincts
# =========================================
# Discrepancies from naming convention:
# ['CNTYFIPS', 'PRECODE', 'PRENAME', 'STH16D', 'STH16R', 'TOTVOTE16']
#
# =========================================
# Dataset: AK_precincts
# =========================================
# Discrepancies from naming convention:
# ['2MORE', 'AMIN', 'AREA', 'ASIAN', 'BLACK', 'DISTRICT', 'ID', 'NAME', 'NHPI', 'OTHER', 'POPULATION', 'PRES16C', 'WHITE']
#
# =========================================
# Dataset: GA_precincts
# =========================================
# Discrepancies from naming convention:
# ['CTYNAME', 'DISTRICT', 'FIPS1', 'FIPS2', 'ID', 'PRECINCT_I', 'PRECINCT_N']
#
# =========================================
# Dataset: HI_precincts
# =========================================
# Discrepancies from naming convention:
# ['BALLOTTYPE', 'DPTYPE', 'NAME', 'ZEROPOP']
#
# =========================================
# Dataset: WI_wards_12_16
# =========================================
# Discrepancies from naming convention:
# ['AMINDIAN', 'AMINDIAN18', 'ASIAN', 'ASIAN18', 'ASM', 'BLACK', 'BLACK18', 'CDADEM12', 'CDADEM16', 'CDADEM212', 'CDADEM216', 'CDAIND12', 'CDAIND16', 'CDAREP12', 'CDAREP16', 'CDASCT12', 'CDASCT16', 'CDATOT12', 'CDATOT16', 'CNTY_NAME', 'CON', 'GEOID10', 'GOVCON14', 'GOVDEM12', 'GOVDEM14', 'GOVIND12', 'GOVIND14', 'GOVIND214', 'GOVIND314', 'GOVIND414', 'GOVIND514', 'GOVREP12', 'GOVREP14', 'GOVREP214', 'GOVREP314', 'GOVSCT12', 'GOVSCT14', 'GOVTOT12', 'GOVTOT14', 'HISPANIC', 'HISPANIC18', 'NAME', 'OBJECTID', 'OTHER', 'OTHER18', 'OTHERMLT', 'OTHERMLT18', 'PERSONS', 'PERSONS18', 'PISLAND', 'PISLAND18', 'PRECON12', 'PRECON16', 'PREDEM12', 'PREDEM16', 'PREGRN16', 'PREIND1016', 'PREIND1116', 'PREIND12', 'PREIND16', 'PREIND212', 'PREIND216', 'PREIND312', 'PREIND316', 'PREIND412', 'PREIND416', 'PREIND512', 'PREIND516', 'PREIND612', 'PREIND616', 'PREIND716', 'PREIND816', 'PREIND916', 'PRELIB16', 'PREREP12', 'PREREP16', 'PRESCT12', 'PRESCT16', 'PRETOT12', 'PRETOT16', 'SEN', 'SOSCON14', 'SOSDEM14', 'SOSIND14', 'SOSREP14', 'SOSSCT14', 'SOSTOT14', 'TRSCON14', 'TRSDEM14', 'TRSIND14', 'TRSIND214', 'TRSREP14', 'TRSSCT14', 'TRSTOT14', 'USHDEM12', 'USHDEM14', 'USHDEM16', 'USHDEM216', 'USHGRN16', 'USHIND12', 'USHIND14', 'USHIND16', 'USHIND214', 'USHLIB16', 'USHREP12', 'USHREP14', 'USHREP16', 'USHREP214', 'USHSCT12', 'USHSCT14', 'USHSCT16', 'USHTOT12', 'USHTOT14', 'USHTOT16', 'USSCON12', 'USSDEM12', 'USSDEM14', 'USSDEM16', 'USSIND12', 'USSIND14', 'USSIND212', 'USSIND312', 'USSLIB16', 'USSREP12', 'USSREP14', 'USSREP16', 'USSREP216', 'USSSCT12', 'USSSCT14', 'USSSCT16', 'USSTOT12', 'USSTOT14', 'USSTOT16', 'WAGDEM12', 'WAGDEM14', 'WAGDEM212', 'WAGIND12', 'WAGIND14', 'WAGREP12', 'WAGREP14', 'WAGSCT12', 'WAGSCT14', 'WAGTOT12', 'WAGTOT14', 'WHITE', 'WHITE18', 'WSADEM12', 'WSADEM14', 'WSADEM16', 'WSADEM212', 'WSAIND12', 'WSAIND14', 'WSAIND16', 'WSAIND212', 'WSALIB16', 'WSAREP12', 'WSAREP14', 'WSAREP16', 'WSAREP212', 'WSAREP214', 'WSASCT12', 'WSASCT14', 'WSASCT16', 'WSATOT12', 'WSATOT14', 'WSATOT16', 'WSSAME12', 'WSSCON12', 'WSSDEM12', 'WSSDEM16', 'WSSIND12', 'WSSIND16', 'WSSREP12', 'WSSREP16', 'WSSREP212', 'WSSSCT12', 'WSSSCT16', 'WSSTOT12', 'WSSTOT16']
#
# =========================================
# Dataset: az_precincts
# =========================================
# Discrepancies from naming convention:
# ['CNTYABV', 'PCTNAME']
#
# =========================================
# Dataset: CO_precincts
# =========================================
# Discrepancies from naming convention:
# ['CD116FP', 'NAME', 'PRECID', 'REG18D', 'REG18R', 'SLDLST', 'SLDUST', 'VTDST']
#
# =========================================
# Dataset: MA_no_islands_02_10
# =========================================
# Discrepancies from naming convention:
# ['ALAND10', 'AWATER10', 'COUNTYFP10', 'City/Town', 'FUNCSTAT10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10', 'LSAD10', 'MTFCC10', 'NAME10', 'NAMELSAD10', 'POP2000', 'Pct', 'STATEFP10', 'VTDI10', 'VTDST10', 'Ward']
#
# =========================================
# Dataset: MA_precincts_12_16
# =========================================
# Discrepancies from naming convention:
# ['DISTRICT', 'GOV14U1', 'GOV14U2', 'NAME', 'NAME10', 'RSHARE', 'Shape_Area', 'Shape_Le_1', 'TOWN', 'WARD']
#
# =========================================
# Dataset: MA_no_islands_12_16
# =========================================
# Discrepancies from naming convention:
# ['AmIndian', 'Asian', 'Black', 'City/Town', 'District', 'Hawaiian', 'Hispanic_O', 'Name', 'Not_Hispan', 'Other', 'POP10', 'Pct', 'Population', 'Shape_Area', 'Shape_Le_1', 'Ward', 'White', '_1_Race', '_2__Races']
#
# =========================================
# Dataset: MA_precincts_02_10
# =========================================
# Discrepancies from naming convention:
# ['ALAND10', 'AWATER10', 'CD00', 'CD10', 'COUNTYFP10', 'FUNCSTAT10', 'GEOID10', 'HDIST00', 'HDIST10', 'INTPTLAT10', 'INTPTLON10', 'LSAD10', 'MTFCC10', 'NAME10', 'NAMELSAD10', 'SEND00', 'SEND10', 'STATEFP10', 'TOWN', 'VTDI10', 'VTDST10', 'WARD']
#
# =========================================
# Dataset: MD_precincts_abs
# =========================================
# Discrepancies from naming convention:
# ['ADJAMINVAP', 'ADJASNVAP', 'ADJNHPIVAP', 'ADJOTHVAP', 'ADJ_2MORE', 'ADJ_AMIN', 'ADJ_ASIAN', 'ADJ_BLACK', 'ADJ_BVAP', 'ADJ_NHPI', 'ADJ_OTHER', 'ADJ_POP', 'ADJ_VAP', 'ADJ_WHITE', 'ADJ_WVAP', 'ADJ_nBVAP', 'CNG02', 'LEG02', 'LEG10', 'MCD', 'NAME', 'OCCUPIED', 'PLACE', 'UNADJHISP', 'UNADJPOP', 'UNOCCUPIED', 'VTD', 'VTD_1', 'nBVAP']
#
# =========================================
# Dataset: MD_precincts
# =========================================
# Discrepancies from naming convention:
# ['ADJAMINVAP', 'ADJASNVAP', 'ADJNHPIVAP', 'ADJOTHVAP', 'ADJ_2MORE', 'ADJ_AMIN', 'ADJ_ASIAN', 'ADJ_BLACK', 'ADJ_BVAP', 'ADJ_NHPI', 'ADJ_OTHER', 'ADJ_POP', 'ADJ_VAP', 'ADJ_WHITE', 'ADJ_WVAP', 'CNG02', 'LEG02', 'MCD', 'NAME', 'OCCUPIED', 'PLACE', 'UNADJHISP', 'UNADJPOP', 'UNOCCUPIED', 'VTD', 'VTD_1']
#
# =========================================
# Dataset: NC_VTD
# =========================================
# Discrepancies from naming convention:
# ['ALAND10', 'AWATER10', 'BPOP', 'County', 'EL08G_GV_D', 'EL08G_GV_L', 'EL08G_GV_R', 'EL08G_GV_T', 'EL08G_USS_', 'EL08G_US_1', 'EL08G_US_2', 'EL08G_US_3', 'EL08G_US_4', 'EL10G_USS_', 'EL10G_US_1', 'EL10G_US_2', 'EL10G_US_3', 'EL10G_US_4', 'EL12G_GV_1', 'EL12G_GV_D', 'EL12G_GV_L', 'EL12G_GV_R', 'EL12G_GV_T', 'EL12G_GV_W', 'EL12G_PR_1', 'EL12G_PR_D', 'EL12G_PR_L', 'EL12G_PR_R', 'EL12G_PR_T', 'EL12G_PR_W', 'EL14G_USS_', 'EL14G_US_1', 'EL14G_US_2', 'EL14G_US_3', 'EL14G_US_4', 'EL16G_GV_D', 'EL16G_GV_L', 'EL16G_GV_R', 'EL16G_GV_T', 'EL16G_PR_D', 'EL16G_PR_L', 'EL16G_PR_R', 'EL16G_PR_T', 'EL16G_PR_W', 'EL16G_USS_', 'EL16G_US_1', 'EL16G_US_2', 'EL16G_US_3', 'PL10AA_TOT', 'PL10VA_TOT', 'Shape_Area', 'Shape_Leng', 'VTD', 'VTD_Key', 'VTD_Name', 'judge', 'nBPOP', 'newplan', 'oldplan']
#
# =========================================
# Dataset: UT_precincts
# =========================================
# Discrepancies from naming convention:
# ['AliasNm', 'CountyID', 'DsslvID', 'PrcncID', 'SENDIST', 'SbPrcnc', 'VistaID', 'cnty_fp', 'cnty_nm', 'jrsdctn']
#
# =========================================
# Dataset: MI_precincts
# =========================================
# Discrepancies from naming convention:
# ['CountyFips', 'ElectionYe', 'Jurisdicti', 'Label', 'SENDIST', 'ShapeSTLen', 'VTD', 'VTD2016_x', 'county_fip', 'county_lat', 'county_lon', 'county_nam', 'jurisdic_1', 'precinct']
#
# =========================================
# Dataset: CT_precincts
# =========================================
# Discrepancies from naming convention:
# ['COUNTYFP10', 'NAME10', 'NAMELSAD10', 'STATEFP10']
#
# =========================================
# Dataset: RI_precincts
# =========================================
# Discrepancies from naming convention:
# ['JOINID', 'NAME', 'OBJECTID', 'PRENAME', 'REGVOT16', 'REGVOT18', 'SENDIST', 'Shape__Are', 'Shape__Len']
#
# =========================================
# Dataset: Providence_blocks
# =========================================
# Discrepancies from naming convention:
# ['ALAND10', 'AWATER10', 'BLOCKCE10', 'COUNTYFP10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10', 'NAME10', 'STATEFP10', 'TRACTCE10', 'WARD']
#
# =========================================
# Dataset: OR_precincts
# =========================================
# Discrepancies from naming convention:
# ['County', 'GOV18C', 'Pct_Name', 'Precinct', 'Shape_Area', 'Shape_Leng', 'State']
#
# =========================================
# Dataset: new_mexico_precincts
# =========================================
# Discrepancies from naming convention:
# ['Area', 'CDDIST', 'County', 'NAME10', 'Perimeter', 'SDIST', 'prec_num']
#
# =========================================
# Dataset: PA_VTDs
# =========================================
# Discrepancies from naming convention:
# ['538CMPCT', '538DEM', '538GOP', 'ALAND10', 'ATG12D', 'ATG12R', 'AWATER10', 'CD_2011', 'COUNTYFP10', 'F2014GOVD', 'F2014GOVR', 'FUNCSTAT10', 'GEOID10', 'GOV', 'INTPTLAT10', 'INTPTLON10', 'LSAD10', 'MTFCC10', 'NAME10', 'NAMELSAD10', 'PRES12O', 'REMEDIAL', 'STATEFP10', 'T16ATGD', 'T16ATGR', 'T16PRESD', 'T16PRESOTH', 'T16PRESR', 'T16SEND', 'T16SENR', 'TS', 'USS12D', 'USS12R', 'VTDI10', 'VTDST10']
#
# =========================================
# Dataset: Chicago_Precincts
# =========================================
# Discrepancies from naming convention:
# ['100K_125K', '10K_15K', '125K_150K', '150K_200K', '15K_20K', '200K_MORE', '20K_25K', '25K_30K', '30K_35K', '35K_40K', '40K_45K', '45K_50K', '50K_60K', '60K_75K', '75K_100K', 'CHICO_19', 'DALEY_19', 'EMAN_G15', 'ENYIA_19', 'FIORETTI_1', 'FIORET_G15', 'FORD_19', 'GARCIA_G15', 'JOINID', 'JOYCE_19', 'KOZLAR_19', 'LESS_10K', 'LHGTFT_19', 'MCCART_19', 'MEND_19', 'PRECK_19', 'RO_E15', 'RO_G15', 'SALGRIF_19', 'TOTHH', 'TOTV_19', 'TOTV_G15', 'TOTV_RO15', 'VALLAS_19', 'WALLS_G15', 'WILSON_19', 'WILS_G15', 'full_text', 'precinct', 'shape_area', 'shape_len', 'ward']
#
# =========================================
# Dataset: VA_precincts
# =========================================
# Discrepancies from naming convention:
# ['CD_12', 'CD_16', 'G16DHOR', 'G16DPRS', 'G16OHOR', 'G16OPRS', 'G16RHOR', 'G16RPRS', 'G17DATG', 'G17DGOV', 'G17DHOD', 'G17DLTG', 'G17OGOV', 'G17OHOD', 'G17RATG', 'G17RGOV', 'G17RHOD', 'G17RLTG', 'G18DHOR', 'G18DSEN', 'G18OHOR', 'G18OSEN', 'G18RHOR', 'G18RSEN', 'HDIST_11', 'HDIST_REM', 'H_AMN', 'SENDIST', 'district', 'loc_prec', 'locality', 'precinct']
#
# =========================================
# Dataset: DE_precincts
# =========================================
# Discrepancies from naming convention:
# ['District_1', 'EDRD_2012', 'ID', 'POPULATION']
#
# =========================================
# Dataset: IA_counties
# =========================================
# Discrepancies from naming convention:
# ['ALAND10', 'AWATER10', 'COUNTYFP10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10', 'NAME10', 'NAMELSAD10', 'N_NHPI', 'PRES00OTH', 'PRES04OTH', 'PRES08OTH', 'PRES12OTH', 'PRES16OTH', 'STATEFP10']
#
# =========================================
# Dataset: OK_precincts
# =========================================
# Discrepancies from naming convention:
# ['CNTYFIPS', 'CNTYNAME', 'PRECODE']

# %% [markdown]
# Step 4. Compare ``mggg-states`` data with external sources
# ----------------------------------------------------------

# %%
# View available MGGG data
sorted([gdf for gdf in mggg_gdfs], key=str.casefold)

# %%
available_mggg_states = [
    ('Alaska', 'AK_precincts'),
    ('Arizona', 'az_precincts'),
    ('Colorado', 'CO_precincts'),
    ('Connecticut', 'CT_precincts'),
    ('Delaware', 'DE_precincts'),
    ('Georgia', 'GA_precincts'),
    ('Hawaii', 'HI_precincts'),
    ('Indiana', 'IA_counties'),
    ('Massachusetts', 'MA_precincts_12_16'),
    ('Maryland', 'MD_precincts'),
    ('Michigan', 'MI_precincts'),
    ('Minnesota', 'MN_16'),
    ('North Carolina', 'NC_VTD'),
    ('New Mexico', 'new_mexico_precincts'),
    ('Ohio', 'OH_precincts'),
    ('Oklahoma', 'OK_precincts'),
    ('Oregon', 'OR_precincts'),
    ('Pennsylvania', 'PA_VTDs'),
    ('Rhode Island', 'RI_precincts'),
    ('Utah', 'UT_precincts'),
    ('Virginia', 'VA_precincts'),
    ('Vermont', 'VT_towns'),
    ('Wisconsin', 'WI_wards_12_16')
]

# %%
# View available columns
for st, gdf_name in available_mggg_states:
    print('======== {} ========'.format(st))
    print(sorted(matched_columns[gdf_name]))
    print()

# %% [markdown]
# __Step 4.1.__ Compare against MEDSL

# %%
pres16_cols = [
    ('PRES16D', 'US President democratic'), 
    ('PRES16G', 'US President green'), 
    ('PRES16L', 'US President libertarian'), 
    ('PRES16R', 'US President republican')
]

sen16_cols = [
    ('SEN16D', 'US Senate democrat'),
    ('SEN16G', 'US Senate green'),
    ('SEN16L', 'US Senate libertarian'),
    ('SEN16R', 'US Senate republican')
]

ush16_cols = [
    ('USH16D', 'US House democratic'),
    ('USH16G', 'US House green'),
    ('USH16L', 'US House libertarian'),
    ('USH16R', 'US House republican')
]

fed18_cols = [
    ('SEN18D', 'US Senate democratic'),
    ('SEN18G', 'US Senate green'),
    ('SEN18L', 'US Senate libertarian'),
    ('SEN18R', 'US Senate republican'),
    ('USH18D', 'US House democrat'),
    ('USH18G', 'US House green'),
    ('USH18L', 'US House libertarian'),
    ('USH18R', 'US House republican')
]

# %%
def bulk_compare(bulk_results, st, gdf_name, medsls, cols):
    if st in medsls:
        x = []
        y = []
        for mggg_col, medsl_col in cols:
            if (mggg_col in list(mggg_gdfs[gdf_name]) and 
                medsl_col in list(medsls[st])):
                x.append(mggg_col)
                y.append(medsl_col)
                
        if len(x) != 0:
            try:
                bulk_results[st] += dq.compare_column_sums(
                                        mggg_gdfs[gdf_name], medsls[st], x, y)
            except Exception as e:
                try:
                    bulk_results[st] = dq.compare_column_sums(
                                        mggg_gdfs[gdf_name], medsls[st], x, y)
                except Exception as z:
                    print("Unable to compare in {}. {}. Likely due to dtype incompatibility.".format(st, z))

results = {}

for st, gdf_name in available_mggg_states:
    bulk_compare(results, st, gdf_name, medsl_pres16_dfs, pres16_cols)
    bulk_compare(results, st, gdf_name, medsl_sen16_dfs, sen16_cols)
    bulk_compare(results, st, gdf_name, medsl_ush16_dfs, ush16_cols)
    bulk_compare(results, st, gdf_name, medsl_18_dfs, fed18_cols)

# %%
# Print comparison results
print("============================================================================")
print("Results of State-level Aggregation comparisons between mggg-states and MEDSL")
print("============================================================================")
print()
print('{:37} : {}'.format('mggg-states column [vs] MEDSL column', 'difference in sums'))
print('----------------------------------------------------------------------------')

for st in results:
    print("######## {} ########".format(st))
    for col_v_col, diff in results[st]:
        print('{:37} : {}'.format(col_v_col, diff))
    print()
# Out:
# ============================================================================
# Results of State-level Aggregation comparisons between mggg-states and MEDSL
# ============================================================================
#
# mggg-states column [vs] MEDSL column  : difference in sums
# ----------------------------------------------------------------------------
# ######## Alaska ########
# PRES16D [vs] US President democratic  : -47220.0
# PRES16G [vs] US President green       : -1947.5
# PRES16L [vs] US President libertarian : -6717.5
# PRES16R [vs] US President republican  : -59910.0
# SEN16L [vs] US Senate libertarian     : -30050.0
# SEN16R [vs] US Senate republican      : -50259.5
# USH16D [vs] US House democratic       : -43628.5
# USH16L [vs] US House libertarian      : -11665.5
# USH16R [vs] US House republican       : -54359.5
# USH18R [vs] US House republican       : -46390.5
#
# ######## Arizona ########
# SEN18R [vs] US Senate republican      : 0.0
# USH18D [vs] US House democrat         : 0.0
# USH18G [vs] US House green            : -3672.0
# USH18R [vs] US House republican       : 0.0
#
# ######## Colorado ########
# USH18R [vs] US House republican       : 0.0
#
# ######## Connecticut ########
# SEN18R [vs] US Senate republican      : 43311.511904761894
# USH18D [vs] US House democrat         : 63366.86904761905
# USH18R [vs] US House republican       : 40299.34523809521
#
# ######## Delaware ########
# PRES16D [vs] US President democratic  : 117810.5
# PRES16R [vs] US President republican  : 92500.5
# USH16D [vs] US House democratic       : 116766.0
# USH16R [vs] US House republican       : 86088.5
# SEN18R [vs] US Senate republican      : 68542.5
# USH18D [vs] US House democrat         : 113679.5
# USH18R [vs] US House republican       : 62671.0
#
# ######## Hawaii ########
# PRES16D [vs] US President democratic  : 177927.33333333334
# PRES16R [vs] US President republican  : 85898.0
# SEN16R [vs] US Senate republican      : 61768.66666666667
# USH16D [vs] US House democratic       : 372279.1862745098
# USH16R [vs] US House republican       : 57395.33333333333
# SEN18R [vs] US Senate republican      : 74690.0
# USH18D [vs] US House democrat         : 191947.3333333333
# USH18R [vs] US House republican       : 58232.0
#
# ######## Indiana ########
# PRES16D [vs] US President democratic  : -362537.0714285715
# PRES16R [vs] US President republican  : -711451.5357142857
#
# ######## Massachusetts ########
# PRES16D [vs] US President democratic  : 1667125.272913097
# PRES16R [vs] US President republican  : 996523.2058818067
# SEN18R [vs] US Senate republican      : 895615.5730249364
#
# ######## Maryland ########
# PRES16D [vs] US President democratic  : 715579.2136986301
# PRES16G [vs] US President green       : -122.125
# PRES16L [vs] US President libertarian : -246.53125
# PRES16R [vs] US President republican  : 544786.5737827716
# SEN16G [vs] US Senate green           : -325.45263157894806
# SEN16R [vs] US Senate republican      : -3125.1999999999534
# USH16D [vs] US House democratic       : 117838.5
# USH16R [vs] US House republican       : 28899.972222222248
# SEN18R [vs] US Senate republican      : 476128.3809942249
# USH18D [vs] US House democrat         : 862397.0261919883
# USH18R [vs] US House republican       : 506047.95125604176
#
# ######## Michigan ########
# PRES16D [vs] US President democratic  : 2376.9534632032737
# PRES16G [vs] US President green       : 1497.7027777777766
# PRES16L [vs] US President libertarian : 6737.207323232316
# PRES16R [vs] US President republican  : 113659.92658730177
#
# ######## New Mexico ########
# PRES16D [vs] US President democratic  : 144283.90765900767
# PRES16L [vs] US President libertarian : 28680.559595959596
# PRES16R [vs] US President republican  : 145168.17925130425
# SEN18L [vs] US Senate libertarian     : 64849.33024979239
# SEN18R [vs] US Senate republican      : 134868.78794535733
#
# ######## Ohio ########
# PRES16D [vs] US President democratic  : 24126.4119047625
# PRES16G [vs] US President green       : 602.0595238095193
# PRES16R [vs] US President republican  : 75449.74523809552
# SEN16R [vs] US Senate republican      : 76599.96428571409
# USH16D [vs] US House democratic       : 2021245.0683035715
# USH16R [vs] US House republican       : 2813583.821577381
#
# ######## Oklahoma ########
# USH18D [vs] US House democrat         : 289207.3333333333
# USH18R [vs] US House republican       : 489829.8333333333
#
# ######## Oregon ########
# PRES16L [vs] US President libertarian : 31820.308058608054
# PRES16R [vs] US President republican  : 319652.625996226
# SEN16D [vs] US Senate democrat        : 303174.2108447108
# SEN16R [vs] US Senate republican      : 251725.88214008213
# USH16R [vs] US House republican       : 559351.6666666667
# USH18D [vs] US House democrat         : 45346.666666666744
# USH18R [vs] US House republican       : 35328.66666666663
#
# ######## Rhode Island ########
# PRES16D [vs] US President democratic  : 121861.5
# PRES16R [vs] US President republican  : 88324.5
# SEN18R [vs] US Senate republican      : 72785.5
#
# ######## Utah ########
# PRES16D [vs] US President democratic  : 812.0
# PRES16R [vs] US President republican  : 2384.666666666628
# SEN16R [vs] US Senate republican      : 3309.666666666628

# %% [markdown]
# __Don't panic just yet -- potential explanations for differences:__
#
# - MEDSL data has columns with mixed datatypes, which could mess with the aggregations (e.g. float + None)
# - MGGG data may have columns with mixed datatypes as well. Some columns contain strings, when they should contain numbers
# - Some MGGG columns contain "messy" non-integer values -- something to investigate
# - Some shapefiles use VTDs and towns, which may differ from precincts
# - Undercounts may be the result of excluding absentee ballots in the count
# - Sums should be spot-checked manually in addition to the automated checks
# - The comparisons are conducted on the intersection between mggg-states and MEDSL datasets and are limited to 2016 and 2018 data
# - I also haven't rigourously examined the MEDSL data :P

# %% [markdown]
# [Coming Soon] __Step 4.2.__ Compare against Wikipedia

# %% [markdown]
# [Coming Soon] __Step 4.3.__ Compare against Ballotpedia

# %% [markdown]
# __Step 4.4__ Data summation for manual checks against external sources

# %%
# Print MGGG summation results
print("============================================================================")
print("Results of State-level Aggregations - mggg-states")
print("============================================================================")
print()
print('{:11} : {:10}\t\t{}'.format('mggg-states column', 'sum', 'dtype'))
print('----------------------------------------------------------------------------')

for st, gdf_name in available_mggg_states:
    print("######## {} : {} ########".format(st, gdf_name))
    
    cols_to_sum = [col for col in matched_columns[gdf_name] if col != 'geometry']
    col_sums = dq.sum_column_values(mggg_gdfs[gdf_name], cols_to_sum)
    
    for result in col_sums:
        col_name, col_sum = result
        print('{:11} : {:10}\t\t{}'.format(col_name, col_sum, str(type(col_sum))))
    print('\n\n')

# %%
# Print MEDSL summation results
def print_medsl_sums(st, medsl_name, medsls):
    if st in medsls:
        print("######## {} : {} ########".format(st, medsl_name))
        
        cols_to_sum = [col for col in list(medsls[st]) if col != 'geometry']
        try:
            col_sums = dq.sum_column_values(medsls[st], cols_to_sum)
        except:
            pass
        
        for result in col_sums:
            col_name, col_sum = result
            print('{:70} : {}\t{}'.format(col_name, col_sum, str(type(col_sum))))

        print('\n\n')

        
print("============================================================================")
print("Results of State-level Aggregations - MEDSL")
print("============================================================================")
print()
print('{:70} : {}\t{}'.format('MEDSL column', 'sum', 'dtype'))
print('----------------------------------------------------------------------------')

for st in states:
    print_medsl_sums(st, 'MEDSL 2018', medsl_18_dfs)
    print_medsl_sums(st, 'MEDSL PRES16', medsl_pres16_dfs)
    print_medsl_sums(st, 'MEDSL SEN16', medsl_sen16_dfs)
    print_medsl_sums(st, 'MEDSL USH16', medsl_ush16_dfs)

# %% [markdown]
# Step 5. Check topological soundness of ``mggg-states`` data
# -----------------------------------------------------------------------
#
# __Step 5.1.__ Check for empty geometries

# %%
topological_warnings = []
for gdf in mggg_gdfs:
    if any(mggg_gdfs[gdf]['geometry'].isna()):
        topological_warnings.append('{} has missing geometries.'.format(gdf))
        
    if any(mggg_gdfs[gdf]['geometry'].is_empty):
        topological_warnings.append('{} has empty geometries.')

if len(topological_warnings) == 0:
    print("All topologies are sound.")
else:
    [print(msg) for msg in topological_warnings]

# %% [markdown]
# Step 6. Cleanup
# -------------------

# %%
# # Remove cloned repos
# dm.remove_repos('qafiles/')

# %%
# # Delete output dump directory
# !echo y | rm -rf ./qafiles

# %%
# # Uninstall installed python packages
# !echo y | pip3 uninstall numpy
# !echo y | pip3 uninstall pandas
# !echo y | pip3 uninstall geopandas
# !echo y | pip3 uninstall wikipedia

# !echo y | pip3 uninstall gdutils

# %%
# # Reset Jupyter Notebook IPython Kernel
# from IPython.core.display import HTML
# HTML("<script>Jupyter.notebook.kernel.restart()</script>")

# %% [markdown]
# Next Steps
# -------------
#
# __Data Standardization__
#
# - Manually evaluate column naming discrepancies to determine if changes are needed
# - Manually evaluate column datatypes to determine if changes are needed
#
# __Data Comparison__
#
# - Manually investigate large differences found through comparing ``mggg-states`` data with external sources (e.g. Are absentee ballots counted? Are the precinct counts accurate? etc.)
# - For more accurate comparisons, compare ``mggg-states`` data with those in each States' Secretary of State website
#
# __Topological Soundness__
#
# - Manually examine shapefiles for gaps and overlaps. *Note:* although gaps and overlaps are not necessarily indicators of inaccurate data (because some counties have precinct islands), they do mean that the data cannot be for chain runs.
#
# __Data Documentation__
#
# - Do the READMEs provide data sources?
# - Do the READMEs describe what aggregation/disaggregation processes were used?
# - Do the READMEs discuss discrepancies/caveats in the data?
# - Do the READMEs provide scripts used and/or discuss the data wrangling/processing process?
