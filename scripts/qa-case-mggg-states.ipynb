# %% [markdown]
# Data QA Case: ``mggg-states``
# ========================
#
# Below are the steps involved in performing automated data quality checks on ``mggg-states`` data.
#
# *Note:* the automated checks are not completely exhaustive and further manual checks are required.
#
# Step 0. Setup
# ----------------

# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install geopandas
# !pip3 install wikipedia

# !pip3 install git+https://github.com/KeiferC/gdutils.git

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import json
import wikipedia
import os

import gdutils.datamine as dm
import gdutils.dataqa as dq
import gdutils.extract as et

from typing import Any, List, Tuple, Dict, Hashable, Union, NoReturn

# %% [markdown]
# Step 1. Data collection
# ---------------------------

# %%
state_names = [
    'Alabama', 'Alaska','Arizona', 'Arkansas', 'California', 
    'Colorado', 'Connecticut', 'Delaware',  'Florida', 'Georgia', 
    'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 
    'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 
    'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 
    'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 
    'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 
    'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 
    'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 
    'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
state_abbreviations = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 
    'CO', 'CT', 'DE', 'FL', 'GA', 
    'HI', 'ID', 'IL', 'IN', 'IA', 
    'KS', 'KY', 'LA', 'ME', 'MD', 
    'MA', 'MI', 'MN', 'MS', 'MO', 
    'MT', 'NE', 'NV', 'NH', 'NJ', 
    'NM', 'NY', 'NC', 'ND', 'OH', 
    'OK', 'OR', 'PA', 'RI', 'SC', 
    'SD', 'TN', 'TX', 'UT', 'VT', 
    'VA', 'WA', 'WV', 'WI', 'WY']

states = list(zip(state_names, state_abbreviations))

# %% [markdown]
# __Step 1.1.__ Gather ``mggg-states`` data

# %%
# dm.clone_gh_repos(account='mggg-states', account_type='orgs', 
#                   outpath=os.path.join('qafiles', 'mggg'))
#     # this will take some time to complete

# %%
mggg_gdfs = {}

for filepath in dm.list_files_of_type('.zip', os.path.join('qafiles', 'mggg')):
      mggg_gdfs[os.path.basename(filepath)[:-4]] = et.read_file(filepath).extract()

# %% [markdown]
# __Step 1.2.__ Gather MEDSL data for comparison purposes

# %%
# print('{:27} : {}'.format('Repo Name', 'Repo URL'))
# print('------------------------------------------------------------------')
# for (repo, url) in dm.list_gh_repos(account='MEDSL', account_type='orgs'):
#     print("{:27} : {}".format(repo, url))

# %%
medsl_repos = ['official-precinct-returns', # precinct-level 2016 election results
               '2018-elections-official'] # constituency-level 2018 election results
    
# dm.clone_gh_repos(account='MEDSL', account_type='orgs', repos=medsl_repos, 
#                   outpath=os.path.join('qafiles', 'medsl'))
#     # this will take some time to complete

# %%
medsl_dfs = {}

for filepath in dm.list_files_of_type('.zip', os.path.join('qafiles', 'medsl')):
    medsl_dfs[os.path.basename(filepath)[:-4]] = et.read_file(filepath).extract()

# %% [markdown]
# __Step 1.3.__ Gather Wikipedia data for comparison purposes

# %%
# Generate wikipedia page titles
pres_election = [('PRES', 'United States presidential election')]
fed_elections = [('SEN', 'United States Senate election')]
               # ('USH', United States House of Representatives election')]
election_years_to_check = [2016, 2018]

wiki_titles = []
for yr in election_years_to_check:
    generate_key = lambda yr, ekey: ekey + str(yr % 100)
    generate_title = lambda yr, etype: str(yr) + ' ' + etype
    
    if yr % 4 == 0:
        wiki_titles.append((generate_key(yr, pres_election[0][0]),
                            generate_title(yr, pres_election[0][1])))
        
    [wiki_titles.append(((generate_key(yr, ekey) + '_' + st_abv),
                         (generate_title(yr, etype) + ' in ' + st) ))
         for ekey, etype in fed_elections
         for st, st_abv in states]

# %%
# Gather wikipedia page URLs
wiki_urls = {}
for wiki_title in wiki_titles:
    key, title = wiki_title
    try:
        wiki_urls[key] = (title, wikipedia.page(title=title).url)
    except Exception as e:
        continue

# %%
# Print retrieved page URLs
# ^ necessary for verifying URL - election mapping
# Wikipedia API tries to find best match, not exact match
for wiki_key in wiki_urls:
    title, url = wiki_urls[wiki_key]
    print('{:10} : {}\n\t{}'.format(wiki_key, title, url))

# %%
# Gather wikipedia tabular election results
wiki_tables = {}
for wiki_key in wiki_urls:
    try:
        wiki_tables[wiki_key] = pd.read_html(wiki_urls[wiki_key][1])
    except Exception as e:
        print("Unable to gather Wikipedia tabular data:", e)

# %%
# Display wikipedia tabular election data
for wiki in wiki_tables:
    print('================================================')
    print('Wiki: {} '.format(wiki))
    print('================================================')
    
    for i in range(len(wiki_tables[wiki])):
        print('TABLE {}: ############################\n{}\n\n\n'.format(
                i, wiki_tables[wiki][i].head()))
# Out:
# ================================================
# Wiki: SEN16_AL
# ================================================
# TABLE 0: ############################
#                                                    0  \
# 0                                                NaN
# 1                     ← 2010 November 8, 2016 2022 →
# 2                                             ← 2010
# 3  Nominee Richard Shelby Ron Crumpton Party Repu...
# 4                                                NaN
#
#                                                    1       2   3
# 0                                                NaN     NaN NaN
# 1                     ← 2010 November 8, 2016 2022 →     NaN NaN
# 2                                   November 8, 2016  2022 → NaN
# 3  Nominee Richard Shelby Ron Crumpton Party Repu...     NaN NaN
# 4                                                NaN     NaN NaN
#
#
#
# TABLE 1: ############################
#         0                 1       2
# 0  ← 2010  November 8, 2016  2022 →
#
#
#
# TABLE 2: ############################
#               0               1             2   3
# 0           NaN             NaN           NaN NaN
# 1       Nominee  Richard Shelby  Ron Crumpton NaN
# 2         Party      Republican    Democratic NaN
# 3  Popular vote         1335104        748709 NaN
# 4    Percentage          63.96%        35.87% NaN
#
#
#
# TABLE 3: ############################
#                                                    0  \
# 0  U.S. senator before election Richard Shelby Re...
#
#                                                 1
# 0  Elected U.S. Senator Richard Shelby Republican
#
#
#
# TABLE 4: ############################
#                                 Elections in Alabama
# 0  Federal government U.S. President 1820 1824 18...
# 1                                     U.S. President
# 2  1820 1824 1828 1832 1836 1840 1844 1848 1852 1...
# 3                                        U.S. Senate
# 4  1819 1822 1822 (sp) 1826 (sp) 1828 1831 1834 1...
#
#
#
# TABLE 5: ############################
#                                       U.S. President
# 0  1820 1824 1828 1832 1836 1840 1844 1848 1852 1...
# 1                                        U.S. Senate
# 2  1819 1822 1822 (sp) 1826 (sp) 1828 1831 1834 1...
# 3                                         U.S. House
# 4  1819 1821 1823 1825 1827 1829 1831 1833 1835 1...
#
#
#
# TABLE 6: ############################
#                              Gubernatorial elections
# 0  1819 1821 1823 1825 1827 1829 1831 1833 1835 1...
# 1                                    State elections
# 2                 2004 2006 2008 2010 2012 2014 2018
# 3                   Alabama House of Representatives
# 4                      2002 2006 2010 2014 2018 2022
#
#
#
# TABLE 7: ############################
#    Mayoral elections
# 0               2017
#
#
#
# TABLE 8: ############################
#                Mayoral
# 0  2001 2005 2009 2013
#
#
#
# TABLE 9: ############################
#                     Mayoral elections
# 0  2007 2009 (special) 2011 2015 2019
#
#
#
# TABLE 10: ############################
#                                   Jonathan McConnell
# 0  Individuals John Rice, former State Senator, c...
#
#
#
# TABLE 11: ############################
#                                       Richard Shelby
# 0  U.S. Senators Jeff Sessions, U.S. Senator[13] ...
#
#
#
# TABLE 12: ############################
#                                 Poll source  Date(s)administered Samplesize  \
# 0  Thomas Partners Strategies (R-McConnell)  January 29–30, 2016       1299
# 1        McLaughlin & Associates (R-Shelby)  January 25–26, 2016        600
# 2  Thomas Partners Strategies (R-McConnell)        December 2015          –
# 3        McLaughlin & Associates (R-Shelby)        November 2015          –
#
#   Margin oferror MarcusBowman JohnMartin ShadrackMcGill JonathanMcConnell  \
# 0         ± 2.7%           1%         1%             2%               25%
# 1         ± 4.0%           1%         1%             1%                9%
# 2              –           1%         2%             3%               15%
# 3              –           1%         2%             1%                5%
#
#   RichardShelby Undecided
# 0           55%       16%
# 1           75%       13%
# 2           64%       21%
# 3           71%       20%
#
#
#
# TABLE 13: ############################
#                                 Hypothetical polling           Unnamed: 1  \
# 0  Poll source Date(s)administered Samplesize Mar...                  NaN
# 1                                        Poll source  Date(s)administered
# 2           Thomas Partners Strategies (R-McConnell)  January 29–30, 2016
# 3           Thomas Partners Strategies (R-McConnell)        December 2015
# 4           Thomas Partners Strategies (R-McConnell)         October 2015
#
#    Unnamed: 2      Unnamed: 3     Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0         NaN             NaN            NaN          NaN        NaN
# 1  Samplesize  Margin oferror  RichardShelby  SomeoneElse  Undecided
# 2        1299           ±2.7%            55%          29%        16%
# 3           ?             ±?%            64%          15%        21%
# 4           ?             ±?%            53%          22%        26%
#
#
#
# TABLE 14: ############################
#                                 Poll source  Date(s)administered Samplesize  \
# 0  Thomas Partners Strategies (R-McConnell)  January 29–30, 2016       1299
# 1  Thomas Partners Strategies (R-McConnell)        December 2015          ?
# 2  Thomas Partners Strategies (R-McConnell)         October 2015          ?
#
#   Margin oferror RichardShelby SomeoneElse Undecided
# 0          ±2.7%           55%         29%       16%
# 1            ±?%           64%         15%       21%
# 2            ±?%           53%         22%       26%
#
#
#
# TABLE 15: ############################
#   Party     Party.1                   Candidate   Votes       %
# 0   NaN  Republican  Richard Shelby (incumbent)  505586  64.91%
# 1   NaN  Republican          Jonathan McConnell  214770  27.58%
# 2   NaN  Republican                 John Martin   23558   3.02%
# 3   NaN  Republican               Marcus Bowman   19707   2.53%
# 4   NaN  Republican             Shadrack McGill   15230   1.96%
#
#
#
# TABLE 16: ############################
#          Party      Party.1     Candidate   Votes        %
# 0          NaN   Democratic  Ron Crumpton  145681   55.97%
# 1          NaN   Democratic  Charles Nana  114617   44.03%
# 2  Total votes  Total votes   Total votes  260298  100.00%
#
#
#
# TABLE 17: ############################
#                             Source Ranking               As of
# 0    The Cook Political Report[21]  Safe R   September 9, 2016
# 1        Sabato's Crystal Ball[22]  Safe R  September 19, 2016
# 2  Rothenberg Political Report[23]  Safe R   September 2, 2016
# 3                    Daily Kos[24]  Safe R  September 16, 2016
# 4          Real Clear Politics[25]  Safe R  September 15, 2016
#
#
#
# TABLE 18: ############################
#     Poll source          Date(s)administered  Samplesize Margin oferror  \
# 0  SurveyMonkey           November 1–7, 2016        1131         ± 4.6%
# 1  SurveyMonkey  October 31–November 6, 2016         971         ± 4.6%
# 2  SurveyMonkey  October 28–November 3, 2016         722         ± 4.6%
# 3  SurveyMonkey  October 27–November 2, 2016         621         ± 4.6%
# 4  SurveyMonkey  October 26–November 1, 2016         503         ± 4.6%
#
#   RichardShelby (R) RonCrumpton (D) Undecided
# 0               57%             38%        5%
# 1               58%             37%        5%
# 2               57%             38%        5%
# 3               58%             37%        5%
# 4               56%             40%        4%
#
#
#
# TABLE 19: ############################
#          Party          Party.1                   Candidate            Votes  \
# 0          NaN       Republican  Richard Shelby (incumbent)          1335104
# 1          NaN       Democratic                Ron Crumpton           748709
# 2          NaN         Write-in                    Write-in             3631
# 3  Total votes      Total votes                 Total votes          2087444
# 4          NaN  Republican hold             Republican hold  Republican hold
#
#                  %                ±
# 0           63.96%           -1.22%
# 1           35.87%           +1.16%
# 2            0.17%           +0.06%
# 3          100.00%              NaN
# 4  Republican hold  Republican hold
#
#
#
# TABLE 20: ############################
#   vte(2015 ←) 2016 United States elections (→ 2017)  \
# 0                                     U.S.President
# 1                                        U.S.Senate
# 2                                         U.S.House
# 3                                         Governors
# 4                                            Mayors
#
#   vte(2015 ←) 2016 United States elections (→ 2017).1
# 0  Alabama Alaska American Samoa Arizona Arkansas...
# 1  Alabama Alaska Arizona Arkansas California Col...
# 2  Alabama Alaska American Samoa Arizona Arkansas...
# 3  American Samoa Delaware Indiana Missouri Monta...
# 4  Augusta, GA Bakersfield, CA Baltimore, MD Bato...
#
#
#
# ================================================
# Wiki: SEN16_AK
# ================================================
# TABLE 0: ############################
#                                                    0  \
# 0                                                NaN
# 1                     ← 2010 November 8, 2016 2022 →
# 2                                             ← 2010
# 3  Nominee Lisa Murkowski Joe Miller Party Republ...
# 4                                                NaN
#
#                                                    1       2   3
# 0                                                NaN     NaN NaN
# 1                     ← 2010 November 8, 2016 2022 →     NaN NaN
# 2                                   November 8, 2016  2022 → NaN
# 3  Nominee Lisa Murkowski Joe Miller Party Republ...     NaN NaN
# 4                                                NaN     NaN NaN
#
#
#
# TABLE 1: ############################
#         0                 1       2
# 0  ← 2010  November 8, 2016  2022 →
#
#
#
# TABLE 2: ############################
#               0               1            2   3
# 0           NaN             NaN          NaN NaN
# 1       Nominee  Lisa Murkowski   Joe Miller NaN
# 2         Party      Republican  Libertarian NaN
# 3  Popular vote          138149        90825 NaN
# 4    Percentage          44.36%       29.16% NaN
#
#
#
# TABLE 3: ############################
#                                                    0  \
# 0  U.S. senator before election Lisa Murkowski Re...
#
#                                                 1
# 0  Elected U.S. Senator Lisa Murkowski Republican
#
#
#
# TABLE 4: ############################
#                                  Elections in Alaska
# 0  Federal government Presidential elections 1960...
# 1                             Presidential elections
# 2  1960 1964 1968 1972 1976 1980 1984 1988 1992 1...
# 3                              Presidential caucuses
# 4  .mw-parser-output .nobold{font-weight:normal}D...
#
#
#
# TABLE 5: ############################
#                               Presidential elections
# 0  1960 1964 1968 1972 1976 1980 1984 1988 1992 1...
# 1                              Presidential caucuses
# 2  .mw-parser-output .nobold{font-weight:normal}D...
# 3                              U.S. Senate elections
# 4  1962 1968 1972 1974 1978 1980 1984 1986 1990 1...
#
#
#
# TABLE 6: ############################
#                              Gubernatorial elections
# 0  1958 1962 1966 1970 1974 1978 1982 1986 1990 1...
# 1                                    State elections
# 2                                2006 2010 2012 2016
# 3                             State Senate elections
# 4                                     2014 2016 2018
#
#
#
# TABLE 7: ############################
#                                    Mayoral elections
# 0  1981 1984 1987 1990 1994 1997 2000 2003 2006 2...
#
#
#
# TABLE 8: ############################
#                                       Lisa Murkowski
# 0  Governors Bill Weld, (former) Massachusetts, a...
#
#
#
# TABLE 9: ############################
#                                          Bob Lochner
# 0  Alaska Right to Life[27] Alaska Republican Ass...
#
#
#
# TABLE 10: ############################
#          Party      Party.1                   Candidate  Votes        %
# 0          NaN   Republican  Lisa Murkowski (incumbent)  39545   71.52%
# 1          NaN   Republican                 Bob Lochner   8480   15.34%
# 2          NaN   Republican                Paul Kendall   4272    7.73%
# 3          NaN   Republican                 Thomas Lamb   2996    5.42%
# 4  Total votes  Total votes                 Total votes  55293  100.00%
#
#
#
# TABLE 11: ############################
#          Party      Party.1         Candidate  Votes        %
# 0          NaN   Democratic      Ray Metcalfe  15228   50.06%
# 1          NaN   Democratic  Edgar Blatchford  10090   33.17%
# 2          NaN  Libertarian      Cean Stevens   5102   16.77%
# 3  Total votes  Total votes       Total votes  30420  100.00%
#
#
#
# TABLE 12: ############################
#                 Candidate      Raised       Spent Cash on Hand
# 0  Lisa Murkowski (R)[44]  $6,058,418  $7,055,457      $91,119
# 1    Ray Metcalfe (D)[45]     $20,865     $13,147       $7,718
# 2  Margaret Stock (I)[46]    $740,769    $738,918       $1,850
# 3      Joe Miller (L)[47]        $122        $445      $99,402
#
#
#
# TABLE 13: ############################
#                             Source   Ranking               As of
# 0    The Cook Political Report[48]  Likely R   September 9, 2016
# 1        Sabato's Crystal Ball[49]    Safe R  September 19, 2016
# 2  Rothenberg Political Report[50]    Safe R   September 2, 2016
# 3                    Daily Kos[51]    Safe R  September 16, 2016
# 4          Real Clear Politics[52]    Safe R  September 15, 2016
#
#
#
# TABLE 14: ############################
#                        Poll source           Date(s)administered  Samplesize  \
# 0                Moore Information             October 5–6, 2016         500
# 1           Alaska Survey Research  September 28–October 2, 2016         660
# 2                Moore Information         September 13–15, 2016         500
# 3  Moore Information (R-Murkowski)            August 27–29, 2016         500
#
#   Margin oferror LisaMurkowski (R) Joe Miller (L) RayMetcalfe (D)  \
# 0         ± 4.0%               49%            16%              9%
# 1         ± 3.8%               50%            18%             12%
# 2          ±4.0%               48%            15%             15%
# 3         ± 4.0%               56%              —             12%
#
#   MargaretStock (I)    Other Undecided
# 0                8%       1%       15%
# 1                7%       2%       11%
# 2                7%       1%       12%
# 3                5%  10%[53]       17%
#
#
#
# TABLE 15: ############################
#                                 Hypothetical polling  \
# 0  Poll source Date(s)administered Samplesize Mar...
# 1                                        Poll source
# 2                                       SurveyMonkey
# 3                                       SurveyMonkey
# 4                                       SurveyMonkey
#
#                       Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0                            NaN         NaN             NaN
# 1            Date(s)administered  Samplesize  Margin oferror
# 2             November 1–7, 2016         409          ± 4.6%
# 3  October 31 – November 6, 2016         382          ± 4.6%
# 4  October 27 – November 2, 2016         303          ± 4.6%
#
#           Unnamed: 4       Unnamed: 5 Unnamed: 6
# 0                NaN              NaN        NaN
# 1  LisaMurkowski (R)  RayMetcalfe (D)  Undecided
# 2                55%              33%        12%
# 3                57%              32%        11%
# 4                60%              25%        15%
#
#
#
# TABLE 16: ############################
#     Poll source            Date(s)administered  Samplesize Margin oferror  \
# 0  SurveyMonkey             November 1–7, 2016         409         ± 4.6%
# 1  SurveyMonkey  October 31 – November 6, 2016         382         ± 4.6%
# 2  SurveyMonkey  October 27 – November 2, 2016         303         ± 4.6%
# 3  SurveyMonkey  October 28 – November 3, 2016         334         ± 4.6%
# 4  SurveyMonkey  October 26 – November 1, 2016         268         ± 4.6%
#
#   LisaMurkowski (R) RayMetcalfe (D) Undecided
# 0               55%             33%       12%
# 1               57%             32%       11%
# 2               60%             25%       15%
# 3               56%             30%       14%
# 4               60%             22%       18%
#
#
#
# TABLE 17: ############################
#                                       Lisa Murkowski
# 0  Individuals Dan Sullivan, U.S. Senator[54] Bil...
#
#
#
# TABLE 18: ############################
#                                           Joe Miller
# 0  Individuals Amy Demboski, Anchorage Assemblywo...
#
#
#
# TABLE 19: ############################
#                                       Margaret Stock
# 0  Individuals Mark Begich, former U.S. Senator[6...
#
#
#
# TABLE 20: ############################
#   Party      Party.1                   Candidate   Votes       %        ±
# 0   NaN   Republican  Lisa Murkowski (incumbent)  138149  44.36%   +8.87%
# 1   NaN  Libertarian                  Joe Miller   90825  29.16%  +28.59%
# 2   NaN  Independent              Margaret Stock   41194  13.23%      NaN
# 3   NaN   Democratic                Ray Metcalfe   36200  11.62%  -11.84%
# 4   NaN  Independent              Breck A. Craig    2609   0.84%      NaN
#
#
#
# TABLE 21: ############################
#   vte(2015 ←) 2016 United States elections (→ 2017)  \
# 0                                     U.S.President
# 1                                        U.S.Senate
# 2                                         U.S.House
# 3                                         Governors
# 4                                            Mayors
#
#   vte(2015 ←) 2016 United States elections (→ 2017).1
# 0  Alabama Alaska American Samoa Arizona Arkansas...
# 1  Alabama Alaska Arizona Arkansas California Col...
# 2  Alabama Alaska American Samoa Arizona Arkansas...
# 3  American Samoa Delaware Indiana Missouri Monta...
# 4  Augusta, GA Bakersfield, CA Baltimore, MD Bato...
#
#
#
# TABLE 22: ############################
#   vteNotable third party performances in United States elections  \
# 0                          Presidential (since 1832)
# 1                            Senatorial (since 1990)
# 2                         Gubernatorial (since 1990)
# 3  Portal:Politics Third party (United States) Th...
#
#   vteNotable third party performances in United States elections.1
# 0  1832 1848 1856 1860 1892 1912 1924 1948 1968 1...
# 1  Virginia 1990 Alaska 1992 Arizona 1992 Hawaii ...
# 2  Alaska 1990 Connecticut 1990 Kansas 1990 Maine...
# 3  Portal:Politics Third party (United States) Th...
#
#
#
# ================================================
# Wiki: SEN16_AZ
# ================================================
# TABLE 0: ############################
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...
#
#
#
# TABLE 1: ############################
#                                                    0  \
# 0                                                NaN
# 1           ← 2010 November 8, 2016 2020 (special) →
# 2                                             ← 2010
# 3  Nominee John McCain Ann Kirkpatrick Gary Swing...
# 4                                                NaN
#
#                                                    1                 2    3
# 0                                                NaN               NaN  NaN
# 1           ← 2010 November 8, 2016 2020 (special) →               NaN  NaN
# 2                                   November 8, 2016  2020 (special) →  NaN
# 3  Nominee John McCain Ann Kirkpatrick Gary Swing...               NaN  NaN
# 4                                                NaN               NaN  NaN
#
#
#
# TABLE 2: ############################
#         0                 1                 2
# 0  ← 2010  November 8, 2016  2020 (special) →
#
#
#
# TABLE 3: ############################
#               0            1                2           3
# 0           NaN          NaN              NaN         NaN
# 1       Nominee  John McCain  Ann Kirkpatrick  Gary Swing
# 2         Party   Republican       Democratic       Green
# 3  Popular vote      1359267          1031245      138634
# 4    Percentage        53.7%            40.8%        5.5%
#
#
#
# TABLE 4: ############################
#                                                    0  \
# 0  U.S. senator before election John McCain Repub...
#
#                                              1
# 0  Elected U.S. Senator John McCain Republican
#
#
#
# TABLE 5: ############################
#                                 Elections in Arizona
# 0  Federal government Presidential elections 1912...
# 1                             Presidential elections
# 2  1912 1916 1920 1924 1928 1932 1936 1940 1944 1...
# 3                             Presidential primaries
# 4  Democratic 2004 2008 2016 2020 Republican 2008...
#
#
#
# TABLE 6: ############################
#                               Presidential elections
# 0  1912 1916 1920 1924 1928 1932 1936 1940 1944 1...
# 1                             Presidential primaries
# 2  Democratic 2004 2008 2016 2020 Republican 2008...
# 3                              U.S. Senate elections
# 4  1912 1914 1916 1920 1922 1926 1928 1932 1934 1...
#
#
#
# TABLE 7: ############################
#                                      State elections
# 0                           2006 2010 2014 2016 2018
# 1                            Gubernatorial elections
# 2  1911 1914 1916 1918 1920 1922 1924 1926 1928 1...
# 3                                Ballot propositions
# 4  2000 203 2004 200 204 2006 107 207 2008 102 20...
#
#
#
# TABLE 8: ############################
#      Mayoral elections
# 0  2006 2010 2014 2018
#
#
#
# TABLE 9: ############################
#   Mayoral elections
# 0    2012 2016 2020
#
#
#
# TABLE 10: ############################
#   Mayoral elections
# 0    2012 2016 2020
#
#
#
# TABLE 11: ############################
#      Mayoral elections
# 0  2008 2012 2016 2020
#
#
#
# TABLE 12: ############################
#      Mayoral elections
# 0  2011 2015 2018–2019
#
#
#
# TABLE 13: ############################
#      Mayoral elections
# 0  2008 2012 2016 2020
#
#
#
# TABLE 14: ############################
#                          Mayoral elections
# 0  1991 1995 1999 2003 2007 2011 2015 2019
#
#
#
# TABLE 15: ############################
#                                          John McCain
# 0  Individuals Donald Trump, 45th President of th...
#
#
#
# TABLE 16: ############################
#                             Alex Meluskey (withdrew)
# 0  Individuals Robert Corbin, former President of...
#
#
#
# TABLE 17: ############################
#                                           Kelli Ward
# 0  Individuals Sylvia Allen, President pro tempor...
#
#
#
# TABLE 18: ############################
#                 Poll source            Date(s)administered  Samplesize  \
# 0     Public Policy Polling                  May 1–3, 2015         300
# 1  Behavior Research Center  October 24 – November 5, 2015         577
# 2  Behavior Research Center             January 6–17, 2016         398
# 3     Public Policy Polling                May 13–15, 2016         443
# 4     Public Policy Polling                May 13–15, 2016         443
#
#   Margin oferror JohnMcCain KelliWard Clair VanSteenwyk AlexMeluskey    Other  \
# 0         ± 5.7%        44%       31%                 —            —        —
# 1         ± 4.7%        41%       11%                2%           1%        —
# 2         ± 4.1%        47%       11%                1%           1%  1%[130]
# 3         ± 4.7%        39%       26%                2%           4%  3%[131]
# 4         ± 4.7%        41%       41%                 —            —        —
#
#   Undecided
# 0       25%
# 1       45%
# 2       39%
# 3       27%
# 4       17%
#
#
#
# TABLE 19: ############################
#                                 Hypothetical polling           Unnamed: 1  \
# 0  with Jan Brewer Poll source Date(s)administere...                  NaN
# 1                                        Poll source  Date(s)administered
# 2                                The Polling Company    April 11–12, 2014
# 3                                        Poll source  Date(s)administered
# 4                              Public Policy Polling        May 1–3, 2015
#
#    Unnamed: 2      Unnamed: 3  Unnamed: 4      Unnamed: 5 Unnamed: 6  \
# 0         NaN             NaN         NaN             NaN        NaN
# 1  Samplesize  Margin oferror  JohnMcCain       JanBrewer      Other
# 2         600          ± 4.1%         29%           47.7%          —
# 3  Samplesize  Margin oferror  JohnMcCain  ChristineJones      Other
# 4         300          ± 5.7%         48%             27%          —
#
#   Unnamed: 7
# 0        NaN
# 1  Undecided
# 2      23.3%
# 3  Undecided
# 4        25%
#
#
#
# TABLE 20: ############################
#            Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  The Polling Company   April 11–12, 2014         600         ± 4.1%
#
#   JohnMcCain JanBrewer Other Undecided
# 0        29%     47.7%     —     23.3%
#
#
#
# TABLE 21: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         300         ± 5.7%
#
#   JohnMcCain ChristineJones Other Undecided
# 0        48%            27%     —       25%
#
#
#
# TABLE 22: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0    The Polling Company   April 11–12, 2014         600         ± 4.1%
# 1  Public Policy Polling       May 1–3, 2015         300         ± 5.7%
#
#   JohnMcCain MattSalmon Other Undecided
# 0      30.3%      48.2%     —     21.5%
# 1        42%        40%     —       18%
#
#
#
# TABLE 23: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0    The Polling Company   April 11–12, 2014         600         ± 4.1%
# 1  Public Policy Polling       May 1–3, 2015         300         ± 5.7%
#
#   JohnMcCain DavidSchweikert Other Undecided
# 0      33.9%           40.1%     —       26%
# 1        40%             39%     —       20%
#
#
#
# TABLE 24: ############################
#            Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  The Polling Company   April 11–12, 2014         600         ± 4.1%
#
#   JohnMcCain A differentRepublican Other Undecided
# 0      30.5%                 60.7%     —      8.8%
#
#
#
# TABLE 25: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         300         ± 5.7%
#
#   JohnMcCain Someone moreconservative Other Undecided
# 0        37%                      51%     —       12%
#
#
#
# TABLE 26: ############################
#   Party     Party.1                Candidate   Votes      %
# 0   NaN  Republican              John McCain  302532  51.7%
# 1   NaN  Republican               Kelli Ward  235988  39.2%
# 2   NaN  Republican            Alex Meluskey   31159   5.5%
# 3   NaN  Republican       Clair Van Steenwyk   21476   3.6%
# 4   NaN  Republican  Sean Webster (Write-In)     175   0.0%
#
#
#
# TABLE 27: ############################
#                                      Ann Kirkpatrick
# 0  U.S. Senators Dennis DeConcini, Arizona (forme...
#
#
#
# TABLE 28: ############################
#          Party      Party.1              Candidate   Votes        %
# 0          NaN   Democratic        Ann Kirkpatrick  333586   99.85%
# 1          NaN   Democratic  Alex Bello (Write-In)     508    0.15%
# 2  Total votes  Total votes            Total votes  334094  100.00%
#
#
#
# TABLE 29: ############################
#          Party      Party.1              Candidate  Votes        %
# 0          NaN        Green  Gary Swing (Write-In)    238  100.00%
# 1  Total votes  Total votes            Total votes    238  100.00%
#
#
#
# TABLE 30: ############################
#          Party      Party.1                    Candidate  Votes        %
# 0          NaN  Libertarian  Merissa Hamilton (Write-In)   1286  100.00%
# 1  Total votes  Total votes                  Total votes   1286  100.00%
#
#
#
# TABLE 31: ############################
#                Date          Location       McCain  Kirkpatrick  \
# 0  October 10, 2016  Phoenix, Arizona  Participant  Participant
#
#                    Link
# 0  Full debate - C-SPAN
#
#
#
# TABLE 32: ############################
#                              Source   Ranking               As of
# 0    The Cook Political Report[145]    Lean R   September 9, 2016
# 1        Sabato's Crystal Ball[146]  Likely R    November 3, 2016
# 2  Rothenberg Political Report[147]    Lean R   September 2, 2016
# 3                    Daily Kos[148]    Lean R  September 16, 2016
# 4          Real Clear Politics[149]    Lean R    November 2, 2016
#
#
#
# TABLE 33: ############################
#      Poll source          Date(s)administered Samplesize Margin oferror  \
# 0   SurveyMonkey           November 1–7, 2016       2609         ± 4.6%
# 1  Insights West           November 4–6, 2016        392         ± 4.9%
# 2   Data Orbital           November 4–6, 2016        550         ± 4.1%
# 3   SurveyMonkey  October 31–November 6, 2016       2322         ± 4.6%
# 4   SurveyMonkey  October 28–November 3, 2016       1748         ± 4.6%
#
#   JohnMcCain (R) AnnKirkpatrick (D) Other Undecided
# 0            50%                45%     —        5%
# 1            50%                42%     —        9%
# 2            56%                44%     —        0%
# 3            50%                45%     —        5%
# 4            50%                45%     —        5%
#
#
#
# TABLE 34: ############################
#                                 Hypothetical polling  \
# 0  with John McCain Poll source Date(s)administer...
# 1                                        Poll source
# 2                              Public Policy Polling
# 3                              Public Policy Polling
# 4                                        Poll source
#
#                   Unnamed: 1  Unnamed: 2      Unnamed: 3      Unnamed: 4  \
# 0                        NaN         NaN             NaN             NaN
# 1        Date(s)administered  Samplesize  Margin oferror  JohnMcCain (R)
# 2              May 1–3, 2015         600            ± 4%             40%
# 3  February 28–March 2, 2014         870          ± 3.3%             35%
# 4        Date(s)administered  Samplesize  Margin oferror  JohnMcCain (R)
#
#            Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0                 NaN        NaN        NaN
# 1  RichardCarmona (D)      Other  Undecided
# 2                 34%          —        25%
# 3                 41%          —        24%
# 4       FredDuVal (D)      Other  Undecided
#
#
#
# TABLE 35: ############################
#              Poll source        Date(s)administered  Samplesize  \
# 0  Public Policy Polling              May 1–3, 2015         600
# 1  Public Policy Polling  February 28–March 2, 2014         870
#
#   Margin oferror JohnMcCain (R) RichardCarmona (D) Other Undecided
# 0           ± 4%            40%                34%     —       25%
# 1         ± 3.3%            35%                41%     —       24%
#
#
#
# TABLE 36: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         600           ± 4%
#
#   JohnMcCain (R) FredDuVal (D) Other Undecided
# 0            40%           36%     —       24%
#
#
#
# TABLE 37: ############################
#              Poll source        Date(s)administered  Samplesize  \
# 0  Public Policy Polling  February 28–March 2, 2014         870
#
#   Margin oferror JohnMcCain (R) GabrielleGiffords (D) Other Undecided
# 0         ± 3.3%            35%                   42%     —       23%
#
#
#
# TABLE 38: ############################
#              Poll source        Date(s)administered  Samplesize  \
# 0  Public Policy Polling  February 28–March 2, 2014         870
#
#   Margin oferror JohnMcCain (R) JanetNapolitano (D) Other Undecided
# 0         ± 3.3%            44%                 36%     —       19%
#
#
#
# TABLE 39: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         600           ± 4%
#
#   JohnMcCain (R) KyrstenSinema (D) Other Undecided
# 0            42%               36%     —       22%
#
#
#
# TABLE 40: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         600           ± 4%
#
#   ChristineJones (R) RichardCarmona (D) Other Undecided
# 0                36%                42%     —       22%
#
#
#
# TABLE 41: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         600           ± 4%
#
#   MattSalmon (R) RichardCarmona (D) Other Undecided
# 0            43%                35%     —       21%
#
#
#
# TABLE 42: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         600           ± 4%
#
#   DavidSchweikert (R) RichardCarmona (D) Other Undecided
# 0                 39%                39%     —       22%
#
#
#
# TABLE 43: ############################
#                   Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Breitbart/Gravis Marketing     August 27, 2016        1244         ± 2.8%
# 1       Public Policy Polling     May 13–15, 2016         896         ± 3.3%
# 2            Gravis Marketing  August 13–16, 2015        1433         ± 2.6%
#
#   KelliWard (R) AnnKirkpatrick (D) Other Undecided
# 0           53%                19%     —       29%
# 1           37%                35%     —       28%
# 2           43%                38%     —       19%
#
#
#
# TABLE 44: ############################
#              Poll source Date(s)administered  Samplesize Margin oferror  \
# 0  Public Policy Polling       May 1–3, 2015         600           ± 4%
#
#   KelliWard (R) RichardCarmona (D) Other Undecided
# 0           36%                39%     —       26%
#
#
#
# TABLE 45: ############################
#   Party      Party.1                   Candidate    Votes       %       ±
# 0   NaN   Republican     John McCain (incumbent)  1359267  53.71%  -5.33%
# 1   NaN   Democratic             Ann Kirkpatrick  1031245  40.75%  +5.99%
# 2   NaN        Green                  Gary Swing   138634   5.48%  +4.03%
# 3   NaN  Independent        Pat Quinn (write-in)      694   0.03%     NaN
# 4   NaN   Republican  Sydney Dudikoff (write-in)      494   0.02%     NaN
#
#
#
# TABLE 46: ############################
#                                       vteJohn McCain  \
# 0  U.S. Senator from Arizona (1987–2018) U.S. Con...
# 1                                               Life
# 2                                Politicalactivities
# 3                                          Elections
# 4                                              Media
#
#                                     vteJohn McCain.1  \
# 0  U.S. Senator from Arizona (1987–2018) U.S. Con...
# 1  Early life and military career Cultural and po...
# 2  House and Senate career, until 2000 The Keatin...
# 3  House elections 1982 1984 Senate elections 198...
# 4  Books authored Faith of My Fathers Worth the F...
#
#                                     vteJohn McCain.2
# 0  U.S. Senator from Arizona (1987–2018) U.S. Con...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#
#
# TABLE 47: ############################
#            0                                                  1
# 0  Elections  House elections 1982 1984 Senate elections 198...
#
#
#
# TABLE 48: ############################
#                 0                                                  1
# 0  Books authored  Faith of My Fathers Worth the Fighting For Why...
#
#
#
# TABLE 49: ############################
#   vte(2015 ←) 2016 United States elections (→ 2017)  \
# 0                                     U.S.President
# 1                                        U.S.Senate
# 2                                         U.S.House
# 3                                         Governors
# 4                                            Mayors
#
#   vte(2015 ←) 2016 United States elections (→ 2017).1
# 0  Alabama Alaska American Samoa Arizona Arkansas...
# 1  Alabama Alaska Arizona Arkansas California Col...
# 2  Alabama Alaska American Samoa Arizona Arkansas...
# 3  American Samoa Delaware Indiana Missouri Monta...
# 4  Augusta, GA Bakersfield, CA Baltimore, MD Bato...
#
#
#
# TABLE 50: ############################
#   vteNotable third party performances in United States elections  \
# 0                          Presidential (since 1832)
# 1                            Senatorial (since 1990)
# 2                         Gubernatorial (since 1990)
# 3  Portal:Politics Third party (United States) Th...
#
#   vteNotable third party performances in United States elections.1
# 0  1832 1848 1856 1860 1892 1912 1924 1948 1968 1...
# 1  Virginia 1990 Alaska 1992 Arizona 1992 Hawaii ...
# 2  Alaska 1990 Connecticut 1990 Kansas 1990 Maine...
# 3  Portal:Politics Third party (United States) Th...
#
#
#
# TABLE 51: ############################
#   vte Elections in Arizona                         vte Elections in Arizona.1
# 0                 Governor  1911 1914 1916 1918 1920 1922 1924 1926 1928 1...
# 1           U.S. President  1912 1916 1920 1924 1928 1932 1936 1940 1944 1...
# 2              U.S. Senate  Class 1 1912 1916 1922 1928 1934 1940 1946 195...
# 3                  Class 1  1912 1916 1922 1928 1934 1940 1946 1952 1958 1...
# 4                  Class 3  1912 1914 1920 1926 1932 1938 1944 1950 1956 1...
#
#
#
# TABLE 52: ############################
#          0                                                  1
# 0  Class 1  1912 1916 1922 1928 1934 1940 1946 1952 1958 1...
# 1  Class 3  1912 1914 1920 1926 1932 1938 1944 1950 1956 1...
#
#
#
# ================================================
# Wiki: SEN16_AR
# ================================================
# TABLE 0: ############################
#                                                    0  \
# 0                                                NaN
# 1                     ← 2010 November 8, 2016 2022 →
# 2                                             ← 2010
# 3  Nominee John Boozman Conner Eldridge Party Rep...
# 4                                                NaN
#
#                                                    1       2   3
# 0                                                NaN     NaN NaN
# 1                     ← 2010 November 8, 2016 2022 →     NaN NaN
# 2                                   November 8, 2016  2022 → NaN
# 3  Nominee John Boozman Conner Eldridge Party Rep...     NaN NaN
# 4                                                NaN     NaN NaN
#
#
#
# TABLE 1: ############################
#         0                 1       2
# 0  ← 2010  November 8, 2016  2022 →
#
#
#
# TABLE 2: ############################
#               0             1                2   3
# 0           NaN           NaN              NaN NaN
# 1       Nominee  John Boozman  Conner Eldridge NaN
# 2         Party    Republican       Democratic NaN
# 3  Popular vote        661984           400602 NaN
# 4    Percentage         59.8%            36.2% NaN
#
#
#
# TABLE 3: ############################
#                                                    0  \
# 0  U.S. senator before election John Boozman Repu...
#
#                                               1
# 0  Elected U.S. Senator John Boozman Republican
#
#
#
# TABLE 4: ############################
#                                Elections in Arkansas
# 0  Federal government Presidential elections 1836...
# 1                             Presidential elections
# 2  1836 1840 1844 1848 1852 1856 1860 1868 1872 1...
# 3                             Presidential primaries
# 4  .mw-parser-output .nobold{font-weight:normal}D...
#
#
#
# TABLE 5: ############################
#                               Presidential elections
# 0  1836 1840 1844 1848 1852 1856 1860 1868 1872 1...
# 1                             Presidential primaries
# 2  .mw-parser-output .nobold{font-weight:normal}D...
# 3                              U.S. Senate elections
# 4  1937 1942 1948 1954 1962 1966 1968 1972 1974 1...
#
#
#
# TABLE 6: ############################
#                              Gubernatorial elections
# 0  1912 1913 1930 1932 1958 1960 1962 1964 1966 1...
# 1                                    State elections
# 2       2000 2002 2004 2006 2008 2010 2012 2014 2018
#
#
#
# TABLE 7: ############################
#                     Mayoral elections
# 0  1994 1998 2002 2006 2010 2014 2018
#
#
#
# TABLE 8: ############################
#                      Poll source Date(s)administered  Samplesize  \
# 0  Talk Business/Hendrix College    February 4, 2016         457
#
#   Margin oferror JohnBoozman CurtisColeman Undecided
# 0         ± 4.6%         68%           23%        9%
#
#
#
# TABLE 9: ############################
#          Party      Party.1                 Candidate   Votes        %
# 0          NaN   Republican  John Boozman (incumbent)  298039   76.45%
# 1          NaN   Republican            Curtis Coleman   91795   23.55%
# 2  Total votes  Total votes               Total votes  389834  100.00%
#
#
#
# TABLE 10: ############################
#          Party      Party.1        Candidate   Votes        %
# 0          NaN   Democratic  Conner Eldridge  214228  100.00%
# 1  Total votes  Total votes      Total votes  214228  100.00%
#
#
#
# TABLE 11: ############################
#               Dates               Location      Boozman     Eldridge  \
# 0  October 12, 2016  Little Rock, Arkansas  Participant  Participant
#
#        Gilbert                  Link
# 0  Participant  Full debate - C-SPAN
#
#
#
# TABLE 12: ############################
#                            Source Ranking               As of
# 0    The Cook Political Report[6]  Safe R   September 9, 2016
# 1        Sabato's Crystal Ball[7]  Safe R  September 19, 2016
# 2  Rothenberg Political Report[8]  Safe R   September 2, 2016
# 3                    Daily Kos[9]  Safe R  September 16, 2016
# 4         Real Clear Politics[10]  Safe R  September 15, 2016
#
#
#
# TABLE 13: ############################
#     Poll source            Date(s)administered  Samplesize Margin oferror  \
# 0  SurveyMonkey             November 1–7, 2016         930         ± 4.6%
# 1  SurveyMonkey  October 31 – November 6, 2016         798         ± 4.6%
# 2  SurveyMonkey  October 28 – November 3, 2016         696         ± 4.6%
# 3  SurveyMonkey  October 27 – November 2, 2016         593         ± 4.6%
# 4  SurveyMonkey  October 26 – November 1, 2016         475         ± 4.6%
#
#   JohnBoozman (R) ConnerEldridge (D) FrankGilbert (L) Other Undecided
# 0             56%                41%                —     —        3%
# 1             55%                42%                —     —        3%
# 2             56%                43%                —     —        1%
# 3             54%                43%                —     —        3%
# 4             52%                46%                —     —        2%
#
#
#
# TABLE 14: ############################
#                                 Hypothetical polling             Unnamed: 1  \
# 0  with Mike Beebe Poll source Date(s)administere...                    NaN
# 1                                        Poll source    Date(s)administered
# 2                              Public Policy Polling       August 1–3, 2014
# 3                              Public Policy Polling  September 18–21, 2014
# 4                      Talk Business/Hendrix College        June 8–11, 2015
#
#    Unnamed: 2      Unnamed: 3       Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 0         NaN             NaN              NaN            NaN        NaN
# 1  Samplesize  Margin oferror  JohnBoozman (R)  MikeBeebe (D)      Other
# 2        1066            ± 3%              40%            46%          —
# 3        1453          ± 2.6%              39%            49%          —
# 4        1183         ± 1.84%              37%            45%          —
#
#   Unnamed: 7
# 0        NaN
# 1  Undecided
# 2        14%
# 3        12%
# 4        18%
#
#
#
# TABLE 15: ############################
#                      Poll source    Date(s)administered  Samplesize  \
# 0          Public Policy Polling       August 1–3, 2014        1066
# 1          Public Policy Polling  September 18–21, 2014        1453
# 2  Talk Business/Hendrix College        June 8–11, 2015        1183
#
#   Margin oferror JohnBoozman (R) MikeBeebe (D) Other Undecided
# 0           ± 3%             40%           46%     —       14%
# 1         ± 2.6%             39%           49%     —       12%
# 2        ± 1.84%             37%           45%     —       18%
#
#
#
# TABLE 16: ############################
#          Party      Party.1                 Candidate    Votes        %  \
# 0          NaN   Republican  John Boozman (incumbent)   661984   59.77%
# 1          NaN   Democratic           Conner Eldridge   400602   36.17%
# 2          NaN  Libertarian             Frank Gilbert    43866    3.96%
# 3          NaN     Write-in                  Write-in     1070    0.10%
# 4  Total votes  Total votes               Total votes  1107522  100.00%
#
#         ±
# 0  +1.87%
# 1  -0.78%
# 2  +0.72%
# 3     NaN
# 4     NaN
#
#
#
# TABLE 17: ############################
#   vte(2015 ←) 2016 United States elections (→ 2017)  \
# 0                                     U.S.President
# 1                                        U.S.Senate
# 2                                         U.S.House
# 3                                         Governors
# 4                                            Mayors
#
#   vte(2015 ←) 2016 United States elections (→ 2017).1
# 0  Alabama Alaska American Samoa Arizona Arkansas...
# 1  Alabama Alaska Arizona Arkansas California Col...
# 2  Alabama Alaska American Samoa Arizona Arkansas...
# 3  American Samoa Delaware Indiana Missouri Monta...
# 4  Augusta, GA Bakersfield, CA Baltimore, MD Bato...
#
#
#
# ================================================
# Wiki: SEN16_CA
# ================================================
# TABLE 0: ############################
#                                                    0  \
# 0                                                NaN
# 1                     ← 2010 November 8, 2016 2022 →
# 2                                             ← 2010
# 3  Candidate Kamala Harris Loretta Sanchez Party ...
# 4                                                NaN
#
#                                                    1       2
# 0                                                NaN     NaN
# 1                     ← 2010 November 8, 2016 2022 →     NaN
# 2                                   November 8, 2016  2022 →
# 3  Candidate Kamala Harris Loretta Sanchez Party ...     NaN
# 4                                                NaN     NaN
# TABLE 1: ############################
#         0                 1       2
# 0  ← 2010  November 8, 2016  2022 →
#
#
#
# TABLE 2: ############################
#               0              1                2
# 0           NaN            NaN              NaN
# 1     Candidate  Kamala Harris  Loretta Sanchez
# 2         Party     Democratic       Democratic
# 3  Popular vote        7542753          4701417
# ...
# 3                           State Assembly elections
# 4                                          2016 2018
#
#
#
# TABLE 7: ############################
#           Mayoral elections
# 0  2003 2007 2011 2015 2019
#
#
#
# TABLE 8: ############################
#                               Mayoral elections
# 0  1997 (special) 1999 2003 2007 2011 2015 2019
#
#
#
# TABLE 9: ############################
#           Mayoral elections
# 0  2004 2008 2012 2016 2020
#
#
#
# TABLE 10: ############################
#                                        Tammy Baldwin
# 0  U.S. Senators Bernie Sanders, U.S. Senator (I-...
#
#
#
# TABLE 11: ############################
#          Party      Party.1                  Candidate   Votes       %
# 0          NaN   Democratic  Tammy Baldwin (incumbent)  510812  99.64%
# 1          NaN     Write-in                   Write-in    1848   0.36%
# 2  Total votes  Total votes                Total votes  512660    100%
#
#
#
# TABLE 12: ############################
#                                      Kevin Nicholson
# 0  U.S. Senators Ted Cruz, U.S. Senator from Texa...
#
#
#
# TABLE 13: ############################
#                                          Leah Vukmir
# 0  Parties Republican Party of Wisconsin, State R...
#
#
#
# TABLE 14: ############################
#                               Poll source Date(s)administered  Samplesize  \
# 0                         Emerson College    July 26–28, 2018         238
# 1                          Marist College    July 15–19, 2018         355
# 2  Hodas & Associates (R-Restoration PAC)    July 12–16, 2018         600
# 3                    Marquette University    July 11–15, 2018         266
# 4                    Marquette University    June 13–17, 2018         274
#
#   Marginof error KevinNicholson LeahVukmir Other Undecided
# 0         ± 6.5%            35%        35%    3%       27%
# 1         ± 6.1%            38%        28%   <1%       34%
# 2         ± 3.0%            33%        20%     –       47%
# 3         ± 7.0%            32%        34%    2%       30%
# 4         ± 6.9%            37%        32%    1%       30%
#
#
#
# TABLE 15: ############################
#                                 Hypothetical polling            Unnamed: 1  \
# 0  Poll source Date(s)administered Samplesize Mar...                   NaN
# 1                                        Poll source   Date(s)administered
# 2                            Magellan Strategies (R)  February 15–16, 2017
#
#    Unnamed: 2      Unnamed: 3   Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0         NaN             NaN          NaN        NaN        NaN
# 1  Samplesize  Marginof error  DavidClarke  SeanDuffy  Undecided
# 2         300          ± 5.7%          32%        26%        42%
#
#
#
# TABLE 16: ############################
#                Poll source   Date(s)administered  Samplesize Marginof error  \
# 0  Magellan Strategies (R)  February 15–16, 2017         300         ± 5.7%
#
#   DavidClarke SeanDuffy Undecided
# 0         32%       26%       42%
#
#
#
# TABLE 17: ############################
#   Party     Party.1        Candidate   Votes       %
# 0   NaN  Republican      Leah Vukmir  217230  48.90%
# 1   NaN  Republican  Kevin Nicholson  191276  43.06%
# 2   NaN  Republican     George Lucia   18786   4.23%
# 3   NaN  Republican    Griffin Jones    8699   1.96%
# 4   NaN  Republican   Charles Barman    7959   1.79%
#
#
#
# TABLE 18: ############################
#                                      Leah Vukmir (R)
# 0  U.S. Executive Branch officials Donald Trump, ...
#
#
#
# TABLE 19: ############################
#                                    Tammy Baldwin (D)
# 0  Former U.S. Executive Branch officials Barack ...
#
#
#
# TABLE 20: ############################
#                            Source   Ranking             As of
# 0  The Cook Political Report[111]  Likely D  October 26, 2018
# 1           Inside Elections[112]    Safe D  November 1, 2018
# 2      Sabato's Crystal Ball[113]  Likely D  November 5, 2018
# 3                Fox News[114][a]  Likely D  November 5, 2018
# 4                        CNN[115]  Likely D  November 5, 2018
#
#
#
# TABLE 21: ############################
#             Poll source  Date(s)administered Samplesize Marginof error  \
# 0          Research Co.   November 1–3, 2018        450         ± 4.6%
# 1       Emerson College  October 29–31, 2018        604         ± 4.1%
# 2  Marquette University  October 24–28, 2018   1,154 LV         ± 3.2%
# 3  Marquette University  October 24–28, 2018   1,400 RV         ± 3.0%
# 4                 Ipsos  October 12–18, 2018       1193         ± 3.0%
#
#   TammyBaldwin (D) LeahVukmir (R) Other Undecided
# 0              50%            39%     –       11%
# 1              53%            44%     –        3%
# 2              54%            43%     –        1%
# 3              52%            42%     –        3%
# 4              54%            39%    3%        5%
#
#
#
# TABLE 22: ############################
#                                 Hypothetical polling              Unnamed: 1  \
# 0  with Kevin Nicholson Poll source Date(s)admini...                     NaN
# 1                                        Poll source     Date(s)administered
# 2                                    Emerson College        July 26–28, 2018
# 3                                     Marist College        July 15–19, 2018
# 4                                 SurveyMonkey/Axios  June 11 – July 2, 2018
#
#    Unnamed: 2      Unnamed: 3        Unnamed: 4          Unnamed: 5  \
# 0         NaN             NaN               NaN                 NaN
# 1  Samplesize  Marginof error  TammyBaldwin (D)  KevinNicholson (R)
# 2         632          ± 4.2%               49%                 40%
# 3         906          ± 3.8%               54%                 39%
# 4         968          ± 4.5%               55%                 42%
#
#   Unnamed: 6 Unnamed: 7
# 0        NaN        NaN
# 1      Other  Undecided
# 2         3%         9%
# 3         1%         6%
# 4          –         3%
#
#
#
# TABLE 23: ############################
#                                   Poll source     Date(s)administered  \
# 0                             Emerson College        July 26–28, 2018
# 1                              Marist College        July 15–19, 2018
# 2                          SurveyMonkey/Axios  June 11 – July 2, 2018
# 3                        Marquette University        June 13–17, 2018
# 4  Public Policy Polling (D-Protect Our Care)       March 15–16, 2018
#
#    Samplesize Marginof error TammyBaldwin (D) KevinNicholson (R) Other  \
# 0         632         ± 4.2%              49%                40%    3%
# 1         906         ± 3.8%              54%                39%    1%
# 2         968         ± 4.5%              55%                42%     –
# 3         800         ± 4.0%              50%                39%     –
# 4         910         ± 3.3%              51%                38%     –
#
#   Undecided
# 0        9%
# 1        6%
# 2        3%
# 3        7%
# 4       11%
#
#
#
# TABLE 24: ############################
#           Poll source          Date(s)administered  Samplesize Marginof error  \
# 0  SurveyMonkey/Axios  February 12 – March 5, 2018        1668         ± 3.6%
#
#   TammyBaldwin (D) GenericRepublican Undecided
# 0              49%               46%        5%
#
#
#
# TABLE 25: ############################
#                Poll source  Date(s)administered  Samplesize Marginof error  \
# 0  Magellan Strategies (R)  February 9–10, 2017         500         ± 4.4%
#
#   TammyBaldwin (D) DavidClarke (R) Other Undecided
# 0              49%             35%    2%       14%
#
#
#
# TABLE 26: ############################
#                Poll source  Date(s)administered  Samplesize Marginof error  \
# 0  Magellan Strategies (R)  February 9–10, 2017         500         ± 4.4%
#
#   TammyBaldwin (D) SeanDuffy (R) Other Undecided
# 0              49%           36%    2%       13%
#
#
#
# TABLE 27: ############################
#          Party          Party.1                  Candidate            Votes  \
# 0          NaN       Democratic  Tammy Baldwin (incumbent)          1472914
# 1          NaN       Republican                Leah Vukmir          1184885
# 2          NaN         Write-in                   Write-in             2964
# 3  Total votes      Total votes                Total votes          2660763
# 4          NaN  Democratic hold            Democratic hold  Democratic hold
#
#                  %                ±
# 0           55.36%           +3.95%
# 1           44.53%           -1.33%
# 2            0.11%              NaN
# 3          100.00%              NaN
# 4  Democratic hold  Democratic hold
#
#
#
# TABLE 28: ############################
#   vte(2017 ←) 2018 United States elections (→ 2019)  \
# 0                                       U.S. Senate
# 1                      U.S. House ofRepresentatives
# 2                                           General
# 3                                     Gubernatorial
# 4                                           Mayoral
#
#   vte(2017 ←) 2018 United States elections (→ 2019).1
# 0  Arizona California Connecticut Delaware Florid...
# 1  Alabama Alaska American Samoa Arizona 8th sp A...
# 2  Alabama Alaska American Samoa Arizona Arkansas...
# 3  Alabama Alaska Arizona Arkansas California Col...
# 4  Alexandria, VA Anaheim, CA Anchorage, AK Austi...
#
#
#
# ================================================
# Wiki: SEN18_WY
# ================================================
# TABLE 0: ############################
#                                                    0  \
# 0                                                NaN
# 1                     ← 2012 November 6, 2018 2024 →
# 2                                             ← 2012
# 3                                            Turnout
# 4  Nominee John Barrasso Gary Trauner Party Repub...
#
#                                                    1       2   3
# 0                                                NaN     NaN NaN
# 1                     ← 2012 November 6, 2018 2024 →     NaN NaN
# 2                                   November 6, 2018  2024 → NaN
# 3                                             77.43%     NaN NaN
# 4  Nominee John Barrasso Gary Trauner Party Repub...     NaN NaN
#
#
#
# TABLE 1: ############################
#         0                 1       2
# 0  ← 2012  November 6, 2018  2024 →
#
#
#
# TABLE 2: ############################
#               0              1             2   3
# 0           NaN            NaN           NaN NaN
# 1       Nominee  John Barrasso  Gary Trauner NaN
# 2         Party     Republican    Democratic NaN
# 3  Popular vote         136210         61227 NaN
# 4    Percentage          67.0%         30.1% NaN
#
#
#
# TABLE 3: ############################
#                                                    0  \
# 0  U.S. senator before election John Barrasso Rep...
#
#                                                1
# 0  Elected U.S. Senator John Barrasso Republican
#
#
#
# TABLE 4: ############################
#                                 Elections in Wyoming
# 0  Federal government President 1892 1896 1900 19...
# 1                                          President
# 2  1892 1896 1900 1904 1908 1912 1916 1920 1924 1...
# 3                                        U.S. Senate
# 4  1890 1895 1895 (sp) 1899 1901 1905 1907 1911 1...
#
#
#
# TABLE 5: ############################
#                                            President
# 0  1892 1896 1900 1904 1908 1912 1916 1920 1924 1...
# 1                                        U.S. Senate
# 2  1890 1895 1895 (sp) 1899 1901 1905 1907 1911 1...
# 3                                         U.S. House
# 4  1890 1892 1894 1896 1898 1900 1902 1904 1906 1...
#
#
#
# TABLE 6: ############################
#                                    General elections
# 0                                     2014 2016 2018
# 1                            Gubernatorial elections
# 2  1890 1892 1894 1898 1902 1904 1906 1910 1914 1...
# 3                       Secretary of State elections
# 4  1962 1970 1974 1978 1982 1986 1990 2010 2014 2018
#
#
#
# TABLE 7: ############################
#   Party     Party.1                   Candidate  Votes       %
# 0   NaN  Republican   John Barrasso (incumbent)  74292  64.76%
# 1   NaN  Republican                 Dave Dodson  32647  28.46%
# 2   NaN  Republican                  John Holtz   2981   2.60%
# 3   NaN  Republican   Charlie Hardy (withdrawn)   2377   2.07%
# 4   NaN  Republican  Roque "Rocky" De La Fuente   1280   1.16%
#
#
#
# TABLE 8: ############################
#          Party      Party.1     Candidate  Votes       %
# 0          NaN   Democratic  Gary Trauner  17562  98.90%
# 1          NaN     Write-in      Write-in    195   1.10%
# 2  Total votes  Total votes   Total votes  17757    100%
#
#
#
# TABLE 9: ############################
#                           Source    Ranking               As of
# 0  The Cook Political Report[13]    Solid R  September 29, 2017
# 1           Inside Elections[14]    Solid R  September 29, 2017
# 2      Sabato's Crystal Ball[15]     Safe R  September 27, 2017
# 3                   Fox News[16]  Likely R^        July 9, 2018
# 4                        CNN[17]     Safe R       July 12, 2018
#
#
#
# TABLE 10: ############################
#        Poll source Date(s)administered  Samplesize Marginof error  \
# 0  Change Research  November 2–4, 2018         858              –
#
#   JohnBarrasso (R) GaryTrauner (D) JosephPorambo (L) Undecided
# 0              60%             31%                6%         –
#
#
#
# TABLE 11: ############################
#                                    John Barrasso (R)
# 0  Executive branch officials Donald Trump, 45th ...
#
#
#
# TABLE 12: ############################
#                         Gary Trauner (D)
# 0  Organizations End Citizens United[19]
#
#
#
# TABLE 13: ############################
#          Party      Party.1                  Candidate   Votes       %       ±
# 0          NaN   Republican  John Barrasso (incumbent)  136210  66.96%  -8.70%
# 1          NaN   Democratic               Gary Trauner   61227  30.10%  +8.45%
# 2          NaN  Libertarian             Joseph Porambo    5658   2.78%     NaN
# 3          NaN     Write-in                   Write-in     325   0.16%     NaN
# 4  Total votes  Total votes                Total votes  203420    100%     NaN
#
#
#
# TABLE 14: ############################
#   Unnamed: 0_level_0 John BarrassoRepublican         Gary TraunerDemocrat  \
#               County                   Votes       %                Votes
# 0             Albany                    6366  44.15%                 7576
# 1           Big Horn                    3564  82.56%                  639
# 2           Campbell                   11020  84.44%                 1628
# 3             Carbon                    3673  70.72%                 1359
# 4           Converse                    3959  79.87%                  834
#
#           Joseph PoramboLibertarian        Write-Ins         Total
#         %                     Votes      %     Votes      %  Votes
# 0  52.54%                       442  3.07%        35  0.24%  14419
# 1  14.80%                       102  2.36%        12  0.28%   4317
# 2  12.47%                       387  2.97%        16  0.12%  13051
# 3  26.16%                       156  3.00%         6  0.12%   5194
# 4  16.82%                       153  3.09%        11  0.22%   4957
#
#
#
# TABLE 15: ############################
#   vte(2017 ←) 2018 United States elections (→ 2019)  \
# 0                                       U.S. Senate
# 1                      U.S. House ofRepresentatives
# 2                                           General
# 3                                     Gubernatorial
# 4                                           Mayoral
#
#   vte(2017 ←) 2018 United States elections (→ 2019).1
# 0  Arizona California Connecticut Delaware Florid...
# 1  Alabama Alaska American Samoa Arizona 8th sp A...
# 2  Alabama Alaska American Samoa Arizona Arkansas...
# 3  Alabama Alaska Arizona Arkansas California Col...
# 4  Alexandria, VA Anaheim, CA Anchorage, AK Austi...

# %%
# Manually gather found tabular election results
wiki_dfs = {}

# wiki_pres16_by_state = [{state_abv : table} for _______] # TODO

# has to be done manually because every wikipedia page is different

# wiki_dfs['PRES16_AL'] = wiki_pres16_by_state['AL']
# wiki_dfs['PRES16_AK'] = wiki_pres16_by_state['AK']
# wiki_dfs['PRES16_AZ'] = wiki_pres16_by_state['AZ']
# wiki_dfs['PRES16_AR'] = wiki_pres16_by_state['AR']
# wiki_dfs['PRES16_CA'] = wiki_pres16_by_state['CA']
# wiki_dfs['PRES16_CO'] = wiki_pres16_by_state['CO']
# wiki_dfs['PRES16_CT'] = wiki_pres16_by_state['CT']
# wiki_dfs['PRES16_DE'] = wiki_pres16_by_state['DE']
# wiki_dfs['PRES16_FL'] = wiki_pres16_by_state['FL']
# wiki_dfs['PRES16_GA'] = wiki_pres16_by_state['GA']
# wiki_dfs['PRES16_HI'] = wiki_pres16_by_state['HI']
# wiki_dfs['PRES16_ID'] = wiki_pres16_by_state['ID']
# wiki_dfs['PRES16_IL'] = wiki_pres16_by_state['IL']
# wiki_dfs['PRES16_IN'] = wiki_pres16_by_state['IN']
# wiki_dfs['PRES16_IA'] = wiki_pres16_by_state['IA']
# wiki_dfs['PRES16_KS'] = wiki_pres16_by_state['KS']
# wiki_dfs['PRES16_KY'] = wiki_pres16_by_state['KY']
# wiki_dfs['PRES16_LA'] = wiki_pres16_by_state['LA']
# wiki_dfs['PRES16_ME'] = wiki_pres16_by_state['ME']
# wiki_dfs['PRES16_MD'] = wiki_pres16_by_state['MD']
# wiki_dfs['PRES16_MA'] = wiki_pres16_by_state['MA']
# wiki_dfs['PRES16_MI'] = wiki_pres16_by_state['MI']
# wiki_dfs['PRES16_MN'] = wiki_pres16_by_state['MN']
# wiki_dfs['PRES16_MS'] = wiki_pres16_by_state['MS']
# wiki_dfs['PRES16_MO'] = wiki_pres16_by_state['MO']
# wiki_dfs['PRES16_MT'] = wiki_pres16_by_state['MT']
# wiki_dfs['PRES16_NE'] = wiki_pres16_by_state['NE']
# wiki_dfs['PRES16_NV'] = wiki_pres16_by_state['NV']
# wiki_dfs['PRES16_NH'] = wiki_pres16_by_state['NH']
# wiki_dfs['PRES16_NJ'] = wiki_pres16_by_state['NJ']
# wiki_dfs['PRES16_NM'] = wiki_pres16_by_state['NM']
# wiki_dfs['PRES16_NY'] = wiki_pres16_by_state['NY']
# wiki_dfs['PRES16_NC'] = wiki_pres16_by_state['NC']
# wiki_dfs['PRES16_ND'] = wiki_pres16_by_state['ND']
# wiki_dfs['PRES16_OH'] = wiki_pres16_by_state['OH']
# wiki_dfs['PRES16_OK'] = wiki_pres16_by_state['OK']
# wiki_dfs['PRES16_OR'] = wiki_pres16_by_state['OR']
# wiki_dfs['PRES16_PA'] = wiki_pres16_by_state['PA']
# wiki_dfs['PRES16_RI'] = wiki_pres16_by_state['RI']
# wiki_dfs['PRES16_SC'] = wiki_pres16_by_state['SC']
# wiki_dfs['PRES16_SD'] = wiki_pres16_by_state['SD']
# wiki_dfs['PRES16_TN'] = wiki_pres16_by_state['TN']
# wiki_dfs['PRES16_TX'] = wiki_pres16_by_state['TX']
# wiki_dfs['PRES16_UT'] = wiki_pres16_by_state['UT']
# wiki_dfs['PRES16_VT'] = wiki_pres16_by_state['VT']
# wiki_dfs['PRES16_VA'] = wiki_pres16_by_state['VA']
# wiki_dfs['PRES16_WA'] = wiki_pres16_by_state['WA']
# wiki_dfs['PRES16_WV'] = wiki_pres16_by_state['WV']
# wiki_dfs['PRES16_WI'] = wiki_pres16_by_state['WI']
# wiki_dfs['PRES16_WY'] = wiki_pres16_by_state['WY']

wiki_dfs['SEN16_AL'] = wiki_tables['SEN16_AL'][19]
wiki_dfs['SEN16_AK'] = wiki_tables['SEN16_AK'][20]
wiki_dfs['SEN16_AZ'] = wiki_tables['SEN16_AZ'][45]
wiki_dfs['SEN16_AR'] = wiki_tables['SEN16_AR'][16]
wiki_dfs['SEN16_CA'] = wiki_tables['SEN16_CA'][53]
wiki_dfs['SEN16_CO'] = wiki_tables['SEN16_CO'][25]
wiki_dfs['SEN16_CT'] = wiki_tables['SEN16_CT'][20]
wiki_dfs['SEN16_FL'] = wiki_tables['SEN16_FL'][64]
wiki_dfs['SEN16_GA'] = wiki_tables['SEN16_GA'][16]
wiki_dfs['SEN16_HI'] = wiki_tables['SEN16_HI'][18]
wiki_dfs['SEN16_ID'] = wiki_tables['SEN16_ID'][15]
wiki_dfs['SEN16_IL'] = wiki_tables['SEN16_IL'][29]
wiki_dfs['SEN16_IN'] = wiki_tables['SEN16_IN'][25]
wiki_dfs['SEN16_IA'] = wiki_tables['SEN16_IA'][20]
wiki_dfs['SEN16_KS'] = wiki_tables['SEN16_KS'][17]
wiki_dfs['SEN16_KY'] = wiki_tables['SEN16_KY'][22]
wiki_dfs['SEN16_LA'] = wiki_tables['SEN16_LA'][24]
wiki_dfs['SEN16_MD'] = wiki_tables['SEN16_MD'][29]
wiki_dfs['SEN16_MO'] = wiki_tables['SEN16_MO'][24]
wiki_dfs['SEN16_NV'] = wiki_tables['SEN16_NV'][32]
wiki_dfs['SEN16_NH'] = wiki_tables['SEN16_NH'][23]
wiki_dfs['SEN16_NY'] = wiki_tables['SEN16_NY'][15]
wiki_dfs['SEN16_NC'] = wiki_tables['SEN16_NC'][42]
wiki_dfs['SEN16_ND'] = wiki_tables['SEN16_ND'][14]
wiki_dfs['SEN16_OH'] = wiki_tables['SEN16_OH'][29]
wiki_dfs['SEN16_OK'] = wiki_tables['SEN16_OK'][12]
wiki_dfs['SEN16_OR'] = wiki_tables['SEN16_OR'][14]
wiki_dfs['SEN16_PA'] = wiki_tables['SEN16_PA'][38]
wiki_dfs['SEN16_SC'] = wiki_tables['SEN16_SC'][16]
wiki_dfs['SEN16_SD'] = wiki_tables['SEN16_SD'][9]
wiki_dfs['SEN16_UT'] = wiki_tables['SEN16_UT'][19]
wiki_dfs['SEN16_VT'] = wiki_tables['SEN16_VT'][12]
wiki_dfs['SEN16_WA'] = wiki_tables['SEN16_WA'][15]
wiki_dfs['SEN16_WI'] = wiki_tables['SEN16_WI'][21]

wiki_dfs['SEN18_AZ'] = wiki_tables['SEN18_AZ'][40]
# wiki_dfs['SEN18_CA'] = wiki_tables['SEN18_CA'][]
# wiki_dfs['SEN18_CT'] = wiki_tables['SEN18_CT'][]
# wiki_dfs['SEN18_DE'] = wiki_tables['SEN18_DE'][]
# wiki_dfs['SEN18_FL'] = wiki_tables['SEN18_FL'][]
# wiki_dfs['SEN18_HI'] = wiki_tables['SEN18_HI'][]
# wiki_dfs['SEN18_IN'] = wiki_tables['SEN18_IN'][]
# wiki_dfs['SEN18_ME'] = wiki_tables['SEN18_ME'][]
# wiki_dfs['SEN18_MD'] = wiki_tables['SEN18_MD'][]
# wiki_dfs['SEN18_MA'] = wiki_tables['SEN18_MA'][]
# wiki_dfs['SEN18_MI'] = wiki_tables['SEN18_MI'][]
# wiki_dfs['SEN18_MN'] = wiki_tables['SEN18_MN'][]
# wiki_dfs['SEN18_MS'] = wiki_tables['SEN18_MS'][]
# wiki_dfs['SEN18_MO'] = wiki_tables['SEN18_MO'][]
# wiki_dfs['SEN18_MT'] = wiki_tables['SEN18_MT'][]
# wiki_dfs['SEN18_NE'] = wiki_tables['SEN18_NE'][]
# wiki_dfs['SEN18_NV'] = wiki_tables['SEN18_NV'][]
# wiki_dfs['SEN18_NJ'] = wiki_tables['SEN18_NJ'][]
# wiki_dfs['SEN18_NM'] = wiki_tables['SEN18_NM'][]
# wiki_dfs['SEN18_NY'] = wiki_tables['SEN18_NY'][]
# wiki_dfs['SEN18_ND'] = wiki_tables['SEN18_ND'][]
# wiki_dfs['SEN18_OH'] = wiki_tables['SEN18_OH'][]
# wiki_dfs['SEN18_PA'] = wiki_tables['SEN18_PA'][]
# wiki_dfs['SEN18_RI'] = wiki_tables['SEN18_RI'][]
# wiki_dfs['SEN18_TN'] = wiki_tables['SEN18_TN'][]
# wiki_dfs['SEN18_TX'] = wiki_tables['SEN18_TX'][]
# wiki_dfs['SEN18_UT'] = wiki_tables['SEN18_UT'][]
# wiki_dfs['SEN18_VT'] = wiki_tables['SEN18_VT'][]
# wiki_dfs['SEN18_WA'] = wiki_tables['SEN18_WA'][]
# wiki_dfs['SEN18_WV'] = wiki_tables['SEN18_WV'][]
# wiki_dfs['SEN18_WI'] = wiki_tables['SEN18_WI'][]
# wiki_dfs['SEN18_WY'] = wiki_tables['SEN18_WY'][]

# %% [markdown]
# [Coming Soon] __Step 1.4.__ Gather Ballotpedia data for comparison purposes
#
# *Note:* Depending on response to API access, this step may need to be done manually

# %% [markdown]
# Step 2. Data wrangling
# ---------------------------

# %% [markdown]
# __Step 2.1.__ Wrangle MEDSL data

# %%
def pivot_medsl(medsl_dfs_dict: Dict[str, Union[pd.DataFrame, gpd.GeoDataFrame]]
        ) -> Dict[str, Union[pd.DataFrame, gpd.GeoDataFrame]]:
    for df in medsl_dfs_dict:
        medsl_pvt = medsl_dfs_dict[df].pivot_table(index='precinct',
                                                   columns=['office', 'party'],
                                                   values='votes')
        medsl_pvt.columns = [' '.join(col).strip() for col in medsl_pvt.columns.values]
        medsl_dfs_dict[df] = et.ExtractTable(medsl_pvt).extract()

# %%
# View available data
for df in medsl_dfs:
    print('--------{}--------'.format(df))
    print(medsl_dfs[df].head())

# %%
# Extract relevant MEDSL election data
medsl_18_dfs = {}
medsl_pres16_dfs = {}
medsl_sen16_dfs = {}
medsl_ush16_dfs = {}

for state in states:
    st, st_abv = state
    try:
        medsl_18_dfs[st] = et.ExtractTable(medsl_dfs['precinct_2018'], 
                                           column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_18:', e)
    
    try:
        medsl_pres16_dfs[st] = et.ExtractTable(medsl_dfs['2016-precinct-president'], 
                                               column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_pres16:', e)
    
    try:
        medsl_sen16_dfs[st] = et.ExtractTable(medsl_dfs['2016-precinct-senate'], 
                                               column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_sen16:', e)
    
    try:
        medsl_ush16_dfs[st] = et.ExtractTable(medsl_dfs['2016-precinct-house'], 
                                               column='state', value=st).extract()
    except Exception as e:
        print('Missing data in medsl_ush16:', e)

        
pivot_medsl(medsl_18_dfs)
pivot_medsl(medsl_pres16_dfs)
pivot_medsl(medsl_sen16_dfs)
pivot_medsl(medsl_ush16_dfs)

# %% [markdown]
# Step 3. Data standardization check of ``mggg-states``
# ---------------------------------------------------------------

# %% [markdown]
# __Step 3.1__ Generate naming conventions

# %%
with open('naming_convention.json') as json_file:
    standards_raw = json.load(json_file)
    
offices = dm.get_keys_by_category(standards_raw, 'offices')
parties = dm.get_keys_by_category(standards_raw, 'parties')
counts = dm.get_keys_by_category(standards_raw, 'counts')
others = dm.get_keys_by_category(standards_raw, 
            ['geographies', 'demographics', 'districts', 'other'])

elections = [office + format(year, '02') + party 
                 for office in offices
                 for year in range(0, 21)
                 for party in parties 
                 if not (office == 'PRES' and year % 4 != 0)]

counts = [count + format(year, '02') for count in counts 
                                     for year in range(0, 20)]

standards = elections + counts + others

# %% [markdown]
# __Step 3.2.__ Check ``mggg-states`` data compliance with naming conventions

# %%
naming_check = {}

for gdf in mggg_gdfs:
      naming_check[gdf] = dq.compare_column_names(mggg_gdfs[gdf], standards)

# %%
matched_columns = {}

# Print results
for gdf in naming_check:
    print('=========================================')
    print('Dataset: {}'.format(gdf))
    print('=========================================')
    
    (matches, diffs) = naming_check[gdf]
    matched_columns[gdf] = matches
    
    diffs = list(diffs)
    diffs.sort()
    
    print('Discrepancies from naming convention:')
    print(diffs)
    print()

# %% [markdown]
# Step 4. Compare ``mggg-states`` data with external sources
# ----------------------------------------------------------

# %%
available_mggg_states = []
for state in states:
    state_name, state_abv = state
    
    # messy name matching because file naming isn't standardized
    mggg_gdf_names = [gdf_name for gdf_name in list(mggg_gdfs) 
                               if gdf_name.startswith(state_abv.lower() + '_') or
                                  gdf_name.startswith(state_abv + '_') or
                                  gdf_name.startswith(state_name.lower() + '_') or
                                  gdf_name.startswith(state_name.upper() + '_') or
                                  gdf_name.startswith(state_name + '_') or
                                  gdf_name.startswith(
                                      state_name.replace(' ', '_').lower() + '_') or
                                  gdf_name.startswith(
                                      state_name.replace(' ', '_').upper() + '_') or
                                  gdf_name.startswith(
                                      state_name.replace(' ', '_') + '_')]
                      
    available_mggg_states.append((state_name, mggg_gdf_names))

# %%
# View available columns
for state in available_mggg_states:
    st, gdf_names = state
    if gdf_names:
        print('======== {} ========'.format(st))
        for name in gdf_names:
            print('{} --------'.format(name))
            print(sorted(list(matched_columns[name])))
            print()
        print()

# %% [markdown]
# __Step 4.1.__ Compare against MEDSL

# %%
# Generate Naming Convention Translations between MGGG and MEDSL
pres16_cols = [
    ('PRES16D', 'US President democratic'), 
    ('PRES16G', 'US President green'), 
    ('PRES16L', 'US President libertarian'), 
    ('PRES16R', 'US President republican')
]

sen16_cols = [
    ('SEN16D', 'US Senate democrat'),
    ('SEN16G', 'US Senate green'),
    ('SEN16L', 'US Senate libertarian'),
    ('SEN16R', 'US Senate republican')
]

ush16_cols = [
    ('USH16D', 'US House democratic'),
    ('USH16G', 'US House green'),
    ('USH16L', 'US House libertarian'),
    ('USH16R', 'US House republican')
]

fed18_cols = [
    ('SEN18D', 'US Senate democratic'),
    ('SEN18G', 'US Senate green'),
    ('SEN18L', 'US Senate libertarian'),
    ('SEN18R', 'US Senate republican'),
    ('USH18D', 'US House democrat'),
    ('USH18G', 'US House green'),
    ('USH18L', 'US House libertarian'),
    ('USH18R', 'US House republican')
]

# %%
def bulk_compare(bulk_results: Dict[str, List[Tuple[Hashable, Any]]], 
                 st: str, 
                 mggg_names: List[str], 
                 medsls: List[pd.DataFrame], 
                 cols: Tuple[str, str]
        ) -> NoReturn: # Returns bulk_results by reference
    """
    Returns, by reference, a dict containing state names as keys and a value of a 
    dict containing mggg_gdf names as keys and the results of dm.compare_column_sums
    as values.
    
    """
    if st in medsls:
        try:
            mggg_results = bulk_results[st]
        except Exception:
            mggg_results = {}
        for mggg_name in mggg_names:
            x = []
            y = []
            for mggg_col, medsl_col in cols:
                if (mggg_col in list(mggg_gdfs[mggg_name]) and 
                    medsl_col in list(medsls[st])):
                    x.append(mggg_col)
                    y.append(medsl_col)
                
            if x:
                try:
                    # append results
                    mggg_results[mggg_name] += dq.compare_column_sums(
                                                    mggg_gdfs[mggg_name], 
                                                    medsls[st], x, y)
                except Exception as e:
                    try: # if results don't already exist
                        mggg_results[mggg_name] = dq.compare_column_sums(
                                                    mggg_gdfs[mggg_name], 
                                                    medsls[st], x, y)
                    except Exception as z:
                        print("Unable to compare {} and {} in {}. {}".format(
                                    x, y, mggg_name, z))
            else:
                mggg_results[mggg_name] = []
        
            bulk_results[st] = mggg_results
            

results = {}

for state in available_mggg_states:
    st, mggg_names = state
    
    if mggg_names:
        bulk_compare(results, st, mggg_names, medsl_pres16_dfs, pres16_cols)
        bulk_compare(results, st, mggg_names, medsl_sen16_dfs, sen16_cols)
        bulk_compare(results, st, mggg_names, medsl_ush16_dfs, ush16_cols)
        bulk_compare(results, st, mggg_names, medsl_18_dfs, fed18_cols)

# %%
# Print comparison results
print("============================================================================")
print("Results of State-level Aggregation comparisons between mggg-states and MEDSL")
print("============================================================================")
print()
print('{:37} : {}'.format('mggg-states column [vs] MEDSL column', 'difference in sums'))
print('----------------------------------------------------------------------------')

for st in results:
    print("######## {} ########".format(st))
    for mggg_name in results[st]:
        print("{} ========".format(mggg_name))
        if results[st][mggg_name]:
            for col_v_col, diff in results[st][mggg_name]:
                print('{:37} : {}'.format(col_v_col, diff))
        else:
            print("No comparable columns found.")
        print()
    print()

# %% [markdown]
# __Don't panic just yet -- potential explanations for differences:__
#
# - MGGG data may have columns with mixed datatypes. Some columns contain strings, when they should contain numbers
# - Some shapefiles use VTDs and towns, which may differ from precincts
# - Undercounts may be the result of excluding absentee ballots in the count
# - Sums should be spot-checked manually in addition to the automated checks
# - The comparisons are conducted on the intersection between mggg-states and MEDSL datasets and are limited to 2016 and 2018 data
# - MEDSL float values indicate proration -- to investigate
# - I also haven't rigourously examined the MEDSL data :P

# %% [markdown]
# [Coming Soon] __Step 4.2.__ Compare against Wikipedia

# %% [markdown]
# [Coming Soon] __Step 4.3.__ Compare against Ballotpedia

# %% [markdown]
# __Step 4.4__ Data summation for manual checks against external sources

# %%
# Print MGGG summation results
print("============================================================================")
print("Results of State-level Aggregations - mggg-states")
print("============================================================================")
print()
print('{:11} : {:10}\t\t{}'.format('mggg-states column', 'sum', 'dtype'))
print('----------------------------------------------------------------------------')

for st, gdf_names in available_mggg_states:
    if gdf_names:
        print('######## {} ########'.format(st))
        for gdf_name in gdf_names:
            print("{} ========".format(gdf_name))

            cols_to_sum = [col for col in matched_columns[gdf_name] if col != 'geometry']
            col_sums = dq.sum_column_values(mggg_gdfs[gdf_name], cols_to_sum)

            for result in col_sums:
                col_name, col_sum = result
                if col_name in matched_columns[gdf_name]:
                    if isinstance(col_sum, str):
                        col_sum = "{} is a str".format(col_name)
                    print('{:11} : {:10}\t\t{}'.format(col_name, col_sum, str(type(col_sum))))
            print('\n\n')

# %%
# Print MEDSL summation results
def print_medsl_sums(st: str, 
                     medsl_name: str, 
                     medsls: Dict[str, Union[pd.DataFrame, gpd.GeoDataFrame]]
        ) -> NoReturn:
    if st in medsls:
        print("######## {} : {} ########".format(st, medsl_name))
        
        cols_to_sum = [col for col in list(medsls[st]) if col != 'geometry']
        try:
            col_sums = dq.sum_column_values(medsls[st], cols_to_sum)
        except Exception as e:
            pass
        
        for result in col_sums:
            col_name, col_sum = result
            print('{:65} : {}\t{}'.format(col_name, col_sum, str(type(col_sum))))

        print('\n\n')

        
print("============================================================================")
print("Results of State-level Aggregations - MEDSL")
print("============================================================================")
print()
print('{:65} : {}\t{}'.format('MEDSL column', 'sum', 'dtype'))
print('----------------------------------------------------------------------------')

for st, st_abv in states:
    print_medsl_sums(st, 'MEDSL 2018', medsl_18_dfs)
    print_medsl_sums(st, 'MEDSL PRES16', medsl_pres16_dfs)
    print_medsl_sums(st, 'MEDSL SEN16', medsl_sen16_dfs)
    print_medsl_sums(st, 'MEDSL USH16', medsl_ush16_dfs)

# %% [markdown]
# Step 5. Check topological soundness of ``mggg-states`` data
# -----------------------------------------------------------------------
#
# __Step 5.1.__ Check for empty geometries

# %%
topological_warnings = []
for gdf in mggg_gdfs:
    if any(mggg_gdfs[gdf]['geometry'].isna()):
        topological_warnings.append('{} has missing geometries.'.format(gdf))
        
    if any(mggg_gdfs[gdf]['geometry'].is_empty):
        topological_warnings.append('{} has empty geometries.')

if len(topological_warnings) == 0:
    print("No missing or empty geometries.")
else:
    [print(msg) for msg in topological_warnings]
# Out:
# No missing or empty geometries.

# %% [markdown]
# Step 6. Cleanup
# -------------------

# %%
# # Remove cloned repos
# dm.remove_repos('qafiles/')

# %%
# # Delete output dump directory
# !echo y | rm -rf ./qafiles

# %%
# # Uninstall installed python packages
# !echo y | pip3 uninstall numpy
# !echo y | pip3 uninstall pandas
# !echo y | pip3 uninstall geopandas
# !echo y | pip3 uninstall wikipedia

# !echo y | pip3 uninstall gdutils

# %%
# # Reset Jupyter Notebook IPython Kernel
# from IPython.core.display import HTML
# HTML("<script>Jupyter.notebook.kernel.restart()</script>")

# %% [markdown]
# Next Steps
# -------------
#
# __Data Standardization__
#
# - Manually evaluate column naming discrepancies to determine if changes are needed
# - Manually evaluate column datatypes to determine if changes are needed
#
# __Data Comparison__
#
# - Manually investigate large differences found through comparing ``mggg-states`` data with external sources (e.g. Are absentee ballots counted? Are the precinct counts accurate? etc.)
# - For more accurate comparisons, compare ``mggg-states`` data with those in each States' Secretary of State website
#
# __Topological Soundness__
#
# - Manually examine shapefiles for gaps and overlaps. *Note:* although gaps and overlaps are not necessarily indicators of inaccurate data (because some counties have precinct islands), they do mean that the data cannot be for chain runs.
#
# __Data Documentation__
#
# - Do the READMEs provide data sources?
# - Do the READMEs describe what aggregation/disaggregation processes were used?
# - Do the READMEs discuss discrepancies/caveats in the data?
# - Do the READMEs provide scripts used and/or discuss the data wrangling/processing process?
